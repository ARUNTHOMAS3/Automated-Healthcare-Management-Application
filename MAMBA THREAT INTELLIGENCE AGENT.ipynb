# %%
import os
for root, dirs, files in os.walk('/kaggle/input'):
    for f in files:
        if 'unsw' in f.lower() or 'nb15' in f.lower():
            print(os.path.join(root, f))
# Out:
# /kaggle/input/datasets/mrwellsdavid/unsw-nb15/UNSW_NB15_testing-set.csv
# /kaggle/input/datasets/mrwellsdavid/unsw-nb15/UNSW-NB15_1.csv
# /kaggle/input/datasets/mrwellsdavid/unsw-nb15/UNSW_NB15_training-set.csv
# /kaggle/input/datasets/mrwellsdavid/unsw-nb15/UNSW-NB15_LIST_EVENTS.csv
# /kaggle/input/datasets/mrwellsdavid/unsw-nb15/UNSW-NB15_4.csv
# /kaggle/input/datasets/mrwellsdavid/unsw-nb15/UNSW-NB15_3.csv
# /kaggle/input/datasets/mrwellsdavid/unsw-nb15/UNSW-NB15_2.csv
# /kaggle/input/datasets/mrwellsdavid/unsw-nb15/NUSW-NB15_features.csv

# %%
# !git clone https://github.com/ARUNTHOMAS3/The-Mamba-Powered-Real-time-Threat-Intelligence-Agent.git /kaggle/working/mamba
# %cd /kaggle/working/mamba
# !git pull
# Out:
# Cloning into '/kaggle/working/mamba'...
# remote: Enumerating objects: 148, done.
# remote: Counting objects: 100% (148/148), done.
# remote: Compressing objects: 100% (110/110), done.
# remote: Total 148 (delta 41), reused 136 (delta 29), pack-reused 0 (from 0)
# Receiving objects: 100% (148/148), 193.75 KiB | 6.25 MiB/s, done.
# Resolving deltas: 100% (41/41), done.
# /kaggle/working/mamba
# Already up to date.

# %%
# CICIDS2017
# !mkdir -p data/raw/CICIDS2017
# !cp /kaggle/input/datasets/kk0105/cicids2017/MachineLearningCSV/MachineLearningCSV/MachineLearningCVE/*.csv data/raw/CICIDS2017/

# UNSW-NB15
# !mkdir -p data/raw/UNSW-NB15
# !cp /kaggle/input/datasets/mrwellsdavid/unsw-nb15/*.csv data/raw/UNSW-NB15/

# Verify
# !ls data/raw/CICIDS2017/
# !ls data/raw/UNSW-NB15/
# Out:
# Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv
# Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv
# Friday-WorkingHours-Morning.pcap_ISCX.csv
# Monday-WorkingHours.pcap_ISCX.csv
# Thursday-WorkingHours-Afternoon-Infilteration.pcap_ISCX.csv
# Thursday-WorkingHours-Morning-WebAttacks.pcap_ISCX.csv
# Tuesday-WorkingHours.pcap_ISCX.csv
# Wednesday-workingHours.pcap_ISCX.csv
# NUSW-NB15_features.csv	UNSW-NB15_3.csv		   UNSW_NB15_testing-set.csv
# UNSW-NB15_1.csv		UNSW-NB15_4.csv		   UNSW_NB15_training-set.csv
# UNSW-NB15_2.csv		UNSW-NB15_LIST_EVENTS.csv

# %%
# !python -u kaggle_dual_gpu.py
# Out:
# 🔍 Detected 2 GPU(s):
#    GPU 0: Tesla T4 (15.6 GB)
#    GPU 1: Tesla T4 (15.6 GB)
#
# 🚀 Running on 2 GPUs in parallel!
#    GPU 0: Seeds [42, 123]  — CICIDS2017 + UNSW-NB15 (200K samples)
#    GPU 1: Seed  [456]      — CICIDS2017 + UNSW-NB15 (200K samples)
# ============================================================
# ✅ GPU 0 started (PID 75) — seeds [42, 123]
# ✅ GPU 1 started (PID 76) — seed [456]
#
# ⏳ Both GPUs training in parallel — live output below:
#
# [GPU 0] ======================================================================
# [GPU 0] COMPREHENSIVE IDS BENCHMARK
# [GPU 0] ======================================================================
# [GPU 0] Datasets:  ['CICIDS2017', 'UNSW-NB15']
# [GPU 0] Models:    ['Mamba', 'LSTM', 'GRU', 'CNN-LSTM']
# [GPU 0] Seeds:     [42, 123]
# [GPU 0] Device:    cuda
# [GPU 0] Epochs:    30
# [GPU 0] Batch:     128
# [GPU 0] Seq Len:   50
# [GPU 0] d_model:   128
# [GPU 0] n_layers:  2
# [GPU 0] ======================================================================
# [GPU 0]
# [GPU 0] [1/16] Running experiment...
# [GPU 0]
# [GPU 0] ======================================================================
# [GPU 0]   Dataset: CICIDS2017 | Model: Mamba | Seed: 42
# [GPU 0] ======================================================================
# [GPU 0] [Reproducibility] Setting all random seeds to 42
# [GPU 1] ======================================================================
# [GPU 1] COMPREHENSIVE IDS BENCHMARK
# [GPU 1] ======================================================================
# [GPU 1] Datasets:  ['CICIDS2017', 'UNSW-NB15']
# [GPU 1] Models:    ['Mamba', 'LSTM', 'GRU', 'CNN-LSTM']
# [GPU 1] Seeds:     [456]
# [GPU 1] Device:    cuda
# [GPU 1] Epochs:    30
# [GPU 1] Batch:     128
# [GPU 1] Seq Len:   50
# [GPU 1] d_model:   128
# [GPU 1] n_layers:  2
# [GPU 1] ======================================================================
# [GPU 1]
# [GPU 1] [1/8] Running experiment...
# [GPU 1]
# [GPU 1] ======================================================================
# [GPU 1]   Dataset: CICIDS2017 | Model: Mamba | Seed: 456
# [GPU 1] ======================================================================
# [GPU 1] [Reproducibility] Setting all random seeds to 456
# [GPU 1] [Reproducibility] [OK] All seeds set and deterministic mode enabled
# [GPU 1] [1/5] Loading CICIDS2017 dataset...
# [GPU 0] [Reproducibility] [OK] All seeds set and deterministic mode enabled
# [GPU 0] [1/5] Loading CICIDS2017 dataset...
# [GPU 0] [TRAIN] No cache found, parsing CSVs (this only happens once)...
# [GPU 1] [TRAIN] No cache found, parsing CSVs (this only happens once)...
# [GPU 0] [TRAIN] Loading CICIDS2017 (4 files)...
# [GPU 0] Files: ['Monday-WorkingHours.pcap_ISCX.csv', 'Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv', 'Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv', 'Friday-WorkingHours-Morning.pcap_ISCX.csv']
# [GPU 0]  -> Processing Monday-WorkingHours.pcap_ISCX.csv...
# [GPU 1] [TRAIN] Loading CICIDS2017 (4 files)...
# [GPU 1] Files: ['Monday-WorkingHours.pcap_ISCX.csv', 'Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv', 'Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv', 'Friday-WorkingHours-Morning.pcap_ISCX.csv']
# [GPU 1]  -> Processing Monday-WorkingHours.pcap_ISCX.csv...
# [GPU 0]  -> Processing Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv...
# [GPU 1]  -> Processing Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv...
# [GPU 0]  -> Processing Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv...
# [GPU 1]  -> Processing Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv...
# [GPU 0]  -> Processing Friday-WorkingHours-Morning.pcap_ISCX.csv...
# [GPU 1]  -> Processing Friday-WorkingHours-Morning.pcap_ISCX.csv...
# [GPU 0] Concatenating chunks...
# [GPU 0] Loaded 1233163 total rows.
# [GPU 0] Processing Labels...
# [GPU 1] Concatenating chunks...
# [GPU 1] Loaded 1233163 total rows.
# [GPU 1] Processing Labels...
# [GPU 0] Class Distribution: Benign=944240, Attack=288923
# [GPU 0] Converting to numpy arrays...
# [GPU 1] Class Distribution: Benign=944240, Attack=288923
# [GPU 0] Cleaning NaN/Inf values...
# [GPU 1] Converting to numpy arrays...
# [GPU 0] Total samples: 1233163
# [GPU 0] Train: 0-863214, Val: 863214-986530, Test: 986530-1233163
# [GPU 0] Saving cache to outputs/cache/cicids2017_train.npz...
# [GPU 1] Cleaning NaN/Inf values...
# [GPU 1] Total samples: 1233163
# [GPU 1] Train: 0-863214, Val: 863214-986530, Test: 986530-1233163
# [GPU 1] Saving cache to outputs/cache/cicids2017_train.npz...
# [GPU 0] [TRAIN] Raw shape (before windowing): (863214, 77)
# [GPU 0] [TRAIN] Raw shape (before windowing): (863214, 77)
# [GPU 0] Fitting StandardScaler on Train split...
# [GPU 1] [TRAIN] Raw shape (before windowing): (863214, 77)
# [GPU 1] [TRAIN] Raw shape (before windowing): (863214, 77)
# [GPU 1] Fitting StandardScaler on Train split...
# [GPU 0] Saved scaler to outputs/scaler_cicids.pkl
# [GPU 0] [OK] Will generate 863165 windows lazily during training
# [GPU 0] [VAL] No cache found, parsing CSVs (this only happens once)...
# [GPU 0] [VAL] Loading CICIDS2017 (4 files)...
# [GPU 0] Files: ['Monday-WorkingHours.pcap_ISCX.csv', 'Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv', 'Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv', 'Friday-WorkingHours-Morning.pcap_ISCX.csv']
# [GPU 0]  -> Processing Monday-WorkingHours.pcap_ISCX.csv...
# [GPU 1] Saved scaler to outputs/scaler_cicids.pkl
# [GPU 1] [OK] Will generate 863165 windows lazily during training
# [GPU 1] [VAL] No cache found, parsing CSVs (this only happens once)...
# [GPU 1] [VAL] Loading CICIDS2017 (4 files)...
# [GPU 1] Files: ['Monday-WorkingHours.pcap_ISCX.csv', 'Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv', 'Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv', 'Friday-WorkingHours-Morning.pcap_ISCX.csv']
# [GPU 1]  -> Processing Monday-WorkingHours.pcap_ISCX.csv...
# [GPU 0]  -> Processing Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv...
# [GPU 1]  -> Processing Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv...
# [GPU 0]  -> Processing Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv...
# [GPU 1]  -> Processing Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv...
# [GPU 0]  -> Processing Friday-WorkingHours-Morning.pcap_ISCX.csv...
# [GPU 1]  -> Processing Friday-WorkingHours-Morning.pcap_ISCX.csv...
# [GPU 0] Concatenating chunks...
# [GPU 0] Loaded 1233163 total rows.
# [GPU 0] Processing Labels...
# [GPU 1] Concatenating chunks...
# [GPU 1] Loaded 1233163 total rows.
# [GPU 1] Processing Labels...
# [GPU 0] Class Distribution: Benign=944240, Attack=288923
# [GPU 0] Converting to numpy arrays...
# [GPU 1] Class Distribution: Benign=944240, Attack=288923
# [GPU 0] Cleaning NaN/Inf values...
# [GPU 1] Converting to numpy arrays...
# [GPU 0] Total samples: 1233163
# [GPU 0] Train: 0-863214, Val: 863214-986530, Test: 986530-1233163
# [GPU 0] Saving cache to outputs/cache/cicids2017_val.npz...
# [GPU 1] Cleaning NaN/Inf values...
# [GPU 1] Total samples: 1233163
# [GPU 1] Train: 0-863214, Val: 863214-986530, Test: 986530-1233163
# [GPU 1] Saving cache to outputs/cache/cicids2017_val.npz...
# [GPU 0] [VAL] Raw shape (before windowing): (123316, 77)
# [GPU 0] [VAL] Raw shape (before windowing): (123316, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 123267 windows lazily during training
# [GPU 0] [TEST] No cache found, parsing CSVs (this only happens once)...
# [GPU 0] [TEST] Loading CICIDS2017 (4 files)...
# [GPU 0] Files: ['Monday-WorkingHours.pcap_ISCX.csv', 'Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv', 'Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv', 'Friday-WorkingHours-Morning.pcap_ISCX.csv']
# [GPU 0]  -> Processing Monday-WorkingHours.pcap_ISCX.csv...
# [GPU 1] [VAL] Raw shape (before windowing): (123316, 77)
# [GPU 1] [VAL] Raw shape (before windowing): (123316, 77)
# [GPU 1] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 1] [OK] Will generate 123267 windows lazily during training
# [GPU 1] [TEST] No cache found, parsing CSVs (this only happens once)...
# [GPU 1] [TEST] Loading CICIDS2017 (4 files)...
# [GPU 1] Files: ['Monday-WorkingHours.pcap_ISCX.csv', 'Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv', 'Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv', 'Friday-WorkingHours-Morning.pcap_ISCX.csv']
# [GPU 1]  -> Processing Monday-WorkingHours.pcap_ISCX.csv...
# [GPU 0]  -> Processing Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv...
# [GPU 1]  -> Processing Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv...
# [GPU 0]  -> Processing Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv...
# [GPU 1]  -> Processing Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv...
# [GPU 0]  -> Processing Friday-WorkingHours-Morning.pcap_ISCX.csv...
# [GPU 1]  -> Processing Friday-WorkingHours-Morning.pcap_ISCX.csv...
# [GPU 0] Concatenating chunks...
# [GPU 0] Loaded 1233163 total rows.
# [GPU 0] Processing Labels...
# [GPU 1] Concatenating chunks...
# [GPU 1] Loaded 1233163 total rows.
# [GPU 1] Processing Labels...
# [GPU 0] Class Distribution: Benign=944240, Attack=288923
# [GPU 0] Converting to numpy arrays...
# [GPU 1] Class Distribution: Benign=944240, Attack=288923
# [GPU 0] Cleaning NaN/Inf values...
# [GPU 1] Converting to numpy arrays...
# [GPU 0] Total samples: 1233163
# [GPU 0] Train: 0-863214, Val: 863214-986530, Test: 986530-1233163
# [GPU 0] Saving cache to outputs/cache/cicids2017_test.npz...
# [GPU 1] Cleaning NaN/Inf values...
# [GPU 1] Total samples: 1233163
# [GPU 1] Train: 0-863214, Val: 863214-986530, Test: 986530-1233163
# [GPU 1] Saving cache to outputs/cache/cicids2017_test.npz...
# [GPU 0] [TEST] Raw shape (before windowing): (246633, 77)
# [GPU 0] [TEST] Raw shape (before windowing): (246633, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 246584 windows lazily during training
# [GPU 0]   Limiting (strided): train 863165 -> 200000, val 123267 -> 25000, test 246584 -> 50000
# [GPU 0]   Features: 77, Train: 200000, Val: 25000, Test: 50000
# [GPU 0] [2/5] Initializing Mamba (d_model=128, n_layers=2)...
# [GPU 1] [TEST] Raw shape (before windowing): (246633, 77)
# [GPU 1] [TEST] Raw shape (before windowing): (246633, 77)
# [GPU 1] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 1] [OK] Will generate 246584 windows lazily during training
# [GPU 1]   Limiting (strided): train 863165 -> 200000, val 123267 -> 25000, test 246584 -> 50000
# [GPU 1]   Features: 77, Train: 200000, Val: 25000, Test: 50000
# [GPU 1] [2/5] Initializing Mamba (d_model=128, n_layers=2)...
# [GPU 0]   Parameters: 387,073
# [GPU 0] [3/5] Training Mamba...
# [GPU 0]   LR: 0.000300 (base=0.001 × 0.3 for Mamba), grad_clip=0.5
# [GPU 1]   Parameters: 387,073
# [GPU 1] [3/5] Training Mamba...
# [GPU 1]   LR: 0.000300 (base=0.001 × 0.3 for Mamba), grad_clip=0.5
# [GPU 0]   Using class-weighted loss (pos_weight=1.00)
# [GPU 1]   Using class-weighted loss (pos_weight=1.00)
# [GPU 1]   Epoch   1/30 | TrLoss: 0.0830 | VlLoss: 0.0530 | VlAcc: 0.9852 | VlF1: 0.9924 *
# [GPU 0]   Epoch   1/30 | TrLoss: 0.0621 | VlLoss: 0.1166 | VlAcc: 0.9697 | VlF1: 0.9845 *
# [GPU 1]   Epoch   2/30 | TrLoss: 0.0548 | VlLoss: 0.0587 | VlAcc: 0.9879 | VlF1: 0.9937 *
# [GPU 0]   Epoch   2/30 | TrLoss: 0.0549 | VlLoss: 0.0934 | VlAcc: 0.9832 | VlF1: 0.9913 *
# [GPU 1]   Epoch   3/30 | TrLoss: 0.0360 | VlLoss: 0.0422 | VlAcc: 0.9904 | VlF1: 0.9950 *
# [GPU 0]   Epoch   3/30 | TrLoss: 0.0646 | VlLoss: 0.0355 | VlAcc: 0.9910 | VlF1: 0.9953 *
# [GPU 1]   Epoch   4/30 | TrLoss: 0.0256 | VlLoss: 0.0290 | VlAcc: 0.9928 | VlF1: 0.9963 *
# [GPU 0]   Epoch   4/30 | TrLoss: 0.0118 | VlLoss: 0.0280 | VlAcc: 0.9939 | VlF1: 0.9968 *
# [GPU 1]   Epoch   5/30 | TrLoss: 0.0098 | VlLoss: 0.0195 | VlAcc: 0.9939 | VlF1: 0.9968 *
# [GPU 0]   Epoch   5/30 | TrLoss: 0.0243 | VlLoss: 0.0697 | VlAcc: 0.9793 | VlF1: 0.9893
# [GPU 1]   Epoch   6/30 | TrLoss: 0.0038 | VlLoss: 0.0191 | VlAcc: 0.9955 | VlF1: 0.9977 *
# [GPU 0]   Epoch   6/30 | TrLoss: 0.0103 | VlLoss: 0.0451 | VlAcc: 0.9900 | VlF1: 0.9948
# [GPU 1]   Epoch   7/30 | TrLoss: 0.0046 | VlLoss: 0.0213 | VlAcc: 0.9965 | VlF1: 0.9982 *
# [GPU 0]   Epoch   7/30 | TrLoss: 0.0371 | VlLoss: 0.0277 | VlAcc: 0.9936 | VlF1: 0.9967
# [GPU 1]   Epoch   8/30 | TrLoss: 0.0031 | VlLoss: 0.0256 | VlAcc: 0.9941 | VlF1: 0.9969
# [GPU 0]   Epoch   8/30 | TrLoss: 0.0032 | VlLoss: 0.0712 | VlAcc: 0.9765 | VlF1: 0.9877
# [GPU 1]   Epoch   9/30 | TrLoss: 0.0029 | VlLoss: 0.0239 | VlAcc: 0.9950 | VlF1: 0.9974
# [GPU 0]   Epoch   9/30 | TrLoss: 0.0027 | VlLoss: 0.0320 | VlAcc: 0.9924 | VlF1: 0.9961
# [GPU 0]   Early stopping at epoch 9 (patience=5)
# [GPU 0]   Best Val F1: 0.9968 (9 epochs, 6071.9s)
# [GPU 0]   💾 Model saved to: outputs/checkpoints/CICIDS2017_Mamba_seed42.pt
# [GPU 0] [4/5] Evaluating on test set...
# [GPU 0]   Test Acc: 0.9560 | Prec: 0.6900 | Rec: 0.9197 | F1: 0.7885 | AUC: 0.9742
# [GPU 0] [5/5] Measuring efficiency...
# [GPU 0]   Latency: 10.44ms | Throughput: 2973/s | Memory: 1.48MB
# [GPU 0]   Attack types analyzed: 2
# [GPU 0]
# [GPU 0] [2/16] Running experiment...
# [GPU 0]
# [GPU 0] ======================================================================
# [GPU 0]   Dataset: CICIDS2017 | Model: LSTM | Seed: 42
# [GPU 0] ======================================================================
# [GPU 0] [Reproducibility] Setting all random seeds to 42
# [GPU 0] [Reproducibility] [OK] All seeds set and deterministic mode enabled
# [GPU 0] [1/5] Loading CICIDS2017 dataset...
# [GPU 0] [TRAIN] Loading from cache: outputs/cache/cicids2017_train.npz
# [GPU 0]   Cached shape: (863214, 77), labels: 863214
# [GPU 0] [TRAIN] Raw shape (before windowing): (863214, 77)
# [GPU 0] Fitting StandardScaler on Train split...
# [GPU 0] Saved scaler to outputs/scaler_cicids.pkl
# [GPU 0] [OK] Will generate 863165 windows lazily during training
# [GPU 0] [VAL] Loading from cache: outputs/cache/cicids2017_val.npz
# [GPU 0]   Cached shape: (123316, 77), labels: 123316
# [GPU 0] [VAL] Raw shape (before windowing): (123316, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 123267 windows lazily during training
# [GPU 0] [TEST] Loading from cache: outputs/cache/cicids2017_test.npz
# [GPU 0]   Cached shape: (246633, 77), labels: 246633
# [GPU 0] [TEST] Raw shape (before windowing): (246633, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 246584 windows lazily during training
# [GPU 0]   Limiting (strided): train 863165 -> 200000, val 123267 -> 25000, test 246584 -> 50000
# [GPU 0]   Features: 77, Train: 200000, Val: 25000, Test: 50000
# [GPU 0] [2/5] Initializing LSTM (d_model=128, n_layers=2)...
# [GPU 0]   Parameters: 423,169
# [GPU 0] [3/5] Training LSTM...
# [GPU 0]   LR: 0.001000 (base=0.001 × 1.0 for LSTM), grad_clip=1.0
# [GPU 0]   Using class-weighted loss (pos_weight=1.00)
# [GPU 0]   Epoch   1/30 | TrLoss: 0.1139 | VlLoss: 0.2069 | VlAcc: 0.9645 | VlF1: 0.9819 *
# [GPU 0]   Epoch   2/30 | TrLoss: 0.1133 | VlLoss: 0.2043 | VlAcc: 0.9645 | VlF1: 0.9819
# [GPU 0]   Epoch   3/30 | TrLoss: 0.0867 | VlLoss: 0.2323 | VlAcc: 0.9645 | VlF1: 0.9819
# [GPU 0]   Epoch   4/30 | TrLoss: 0.1056 | VlLoss: 0.2176 | VlAcc: 0.9645 | VlF1: 0.9819
# [GPU 0]   Epoch   5/30 | TrLoss: 0.1368 | VlLoss: 0.1580 | VlAcc: 0.9646 | VlF1: 0.9820 *
# [GPU 0]   Epoch   6/30 | TrLoss: 0.0675 | VlLoss: 0.1703 | VlAcc: 0.9645 | VlF1: 0.9819
# [GPU 0]   Epoch   7/30 | TrLoss: 0.0425 | VlLoss: 0.1626 | VlAcc: 0.9651 | VlF1: 0.9822 *
# [GPU 0]   Epoch   8/30 | TrLoss: 0.0598 | VlLoss: 0.1764 | VlAcc: 0.9645 | VlF1: 0.9819
# [GPU 0]   Epoch   9/30 | TrLoss: 0.1165 | VlLoss: 0.1341 | VlAcc: 0.9646 | VlF1: 0.9820
# [GPU 0]   Epoch  10/30 | TrLoss: 0.0287 | VlLoss: 0.0798 | VlAcc: 0.9841 | VlF1: 0.9918 *
# [GPU 0]   Epoch  11/30 | TrLoss: 0.0057 | VlLoss: 0.0783 | VlAcc: 0.9891 | VlF1: 0.9944 *
# [GPU 0]   Epoch  12/30 | TrLoss: 0.0033 | VlLoss: 0.0195 | VlAcc: 0.9949 | VlF1: 0.9973 *
# [GPU 0]   Epoch  13/30 | TrLoss: 0.0018 | VlLoss: 0.0233 | VlAcc: 0.9938 | VlF1: 0.9968
# [GPU 0]   Epoch  14/30 | TrLoss: 0.0017 | VlLoss: 0.0248 | VlAcc: 0.9923 | VlF1: 0.9960
# [GPU 0]   Epoch  15/30 | TrLoss: 0.0014 | VlLoss: 0.0274 | VlAcc: 0.9926 | VlF1: 0.9962
# [GPU 0]   Epoch  16/30 | TrLoss: 0.0014 | VlLoss: 0.0317 | VlAcc: 0.9932 | VlF1: 0.9964
# [GPU 0]   Epoch  17/30 | TrLoss: 0.0013 | VlLoss: 0.0355 | VlAcc: 0.9930 | VlF1: 0.9964
# [GPU 0]   Early stopping at epoch 17 (patience=5)
# [GPU 0]   Best Val F1: 0.9973 (17 epochs, 341.7s)
# [GPU 0]   💾 Model saved to: outputs/checkpoints/CICIDS2017_LSTM_seed42.pt
# [GPU 0] [4/5] Evaluating on test set...
# [GPU 0]   Test Acc: 0.9912 | Prec: 0.9980 | Rec: 0.9031 | F1: 0.9482 | AUC: 0.9929
# [GPU 0] [5/5] Measuring efficiency...
# [GPU 0]   Latency: 0.75ms | Throughput: 30738/s | Memory: 1.61MB
# [GPU 0]   Attack types analyzed: 2
# [GPU 0]
# [GPU 0] [3/16] Running experiment...
# [GPU 0]
# [GPU 0] ======================================================================
# [GPU 0]   Dataset: CICIDS2017 | Model: GRU | Seed: 42
# [GPU 0] ======================================================================
# [GPU 0] [Reproducibility] Setting all random seeds to 42
# [GPU 0] [Reproducibility] [OK] All seeds set and deterministic mode enabled
# [GPU 0] [1/5] Loading CICIDS2017 dataset...
# [GPU 0] [TRAIN] Loading from cache: outputs/cache/cicids2017_train.npz
# [GPU 0]   Cached shape: (863214, 77), labels: 863214
# [GPU 0] [TRAIN] Raw shape (before windowing): (863214, 77)
# [GPU 0] Fitting StandardScaler on Train split...
# [GPU 0] Saved scaler to outputs/scaler_cicids.pkl
# [GPU 0] [OK] Will generate 863165 windows lazily during training
# [GPU 0] [VAL] Loading from cache: outputs/cache/cicids2017_val.npz
# [GPU 0]   Cached shape: (123316, 77), labels: 123316
# [GPU 0] [VAL] Raw shape (before windowing): (123316, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 123267 windows lazily during training
# [GPU 0] [TEST] Loading from cache: outputs/cache/cicids2017_test.npz
# [GPU 0]   Cached shape: (246633, 77), labels: 246633
# [GPU 0] [TEST] Raw shape (before windowing): (246633, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 246584 windows lazily during training
# [GPU 0]   Limiting (strided): train 863165 -> 200000, val 123267 -> 25000, test 246584 -> 50000
# [GPU 0]   Features: 77, Train: 200000, Val: 25000, Test: 50000
# [GPU 0] [2/5] Initializing GRU (d_model=128, n_layers=2)...
# [GPU 0]   Parameters: 373,505
# [GPU 0] [3/5] Training GRU...
# [GPU 0]   LR: 0.001000 (base=0.001 × 1.0 for GRU), grad_clip=0.5
# [GPU 0]   Using class-weighted loss (pos_weight=1.00)
# [GPU 0]   Epoch   1/30 | TrLoss: 0.2909 | VlLoss: 0.1885 | VlAcc: 0.9645 | VlF1: 0.9819 *
# [GPU 0]   Epoch   2/30 | TrLoss: 0.4081 | VlLoss: 0.1929 | VlAcc: 0.9645 | VlF1: 0.9819
# [GPU 0]   Epoch   3/30 | TrLoss: 0.1858 | VlLoss: 0.2011 | VlAcc: 0.9625 | VlF1: 0.9809
# [GPU 0]   Epoch   4/30 | TrLoss: 0.1291 | VlLoss: 0.2179 | VlAcc: 0.9645 | VlF1: 0.9819
# [GPU 0]   Epoch   5/30 | TrLoss: 0.1273 | VlLoss: 0.1667 | VlAcc: 0.9645 | VlF1: 0.9819
# [GPU 0]   Epoch   6/30 | TrLoss: 0.1034 | VlLoss: 0.1293 | VlAcc: 0.9741 | VlF1: 0.9867 *
# [GPU 0]   Epoch   7/30 | TrLoss: 0.0132 | VlLoss: 0.1001 | VlAcc: 0.9749 | VlF1: 0.9871 *
# [GPU 0]   Epoch   8/30 | TrLoss: 0.0067 | VlLoss: 0.1329 | VlAcc: 0.9614 | VlF1: 0.9799
# [GPU 0]   Epoch   9/30 | TrLoss: 0.0056 | VlLoss: 0.0815 | VlAcc: 0.9786 | VlF1: 0.9889 *
# [GPU 0]   Epoch  10/30 | TrLoss: 0.0047 | VlLoss: 0.0697 | VlAcc: 0.9847 | VlF1: 0.9921 *
# [GPU 0]   Epoch  11/30 | TrLoss: 0.0043 | VlLoss: 0.0625 | VlAcc: 0.9885 | VlF1: 0.9941 *
# [GPU 0]   Epoch  12/30 | TrLoss: 0.0030 | VlLoss: 0.0478 | VlAcc: 0.9875 | VlF1: 0.9935
# [GPU 0]   Epoch  13/30 | TrLoss: 0.0016 | VlLoss: 0.0212 | VlAcc: 0.9921 | VlF1: 0.9959 *
# [GPU 0]   Epoch  14/30 | TrLoss: 0.0013 | VlLoss: 0.0402 | VlAcc: 0.9898 | VlF1: 0.9947
# [GPU 0]   Epoch  15/30 | TrLoss: 0.0014 | VlLoss: 0.0261 | VlAcc: 0.9930 | VlF1: 0.9964 *
# [GPU 0]   Epoch  16/30 | TrLoss: 0.0020 | VlLoss: 0.0204 | VlAcc: 0.9944 | VlF1: 0.9971 *
# [GPU 0]   Epoch  17/30 | TrLoss: 0.0008 | VlLoss: 0.0192 | VlAcc: 0.9956 | VlF1: 0.9977 *
# [GPU 1]   Epoch  10/30 | TrLoss: 0.0021 | VlLoss: 0.0186 | VlAcc: 0.9968 | VlF1: 0.9983 *
# [GPU 0]   Epoch  18/30 | TrLoss: 0.0011 | VlLoss: 0.0380 | VlAcc: 0.9907 | VlF1: 0.9951
# [GPU 0]   Epoch  19/30 | TrLoss: 0.0007 | VlLoss: 0.0483 | VlAcc: 0.9904 | VlF1: 0.9950
# [GPU 0]   Epoch  20/30 | TrLoss: 0.0008 | VlLoss: 0.0675 | VlAcc: 0.9839 | VlF1: 0.9916
# [GPU 0]   Epoch  21/30 | TrLoss: 0.0008 | VlLoss: 0.0381 | VlAcc: 0.9916 | VlF1: 0.9956
# [GPU 0]   Epoch  22/30 | TrLoss: 0.0006 | VlLoss: 0.0471 | VlAcc: 0.9911 | VlF1: 0.9954
# [GPU 0]   Early stopping at epoch 22 (patience=5)
# [GPU 0]   Best Val F1: 0.9977 (22 epochs, 372.1s)
# [GPU 0]   💾 Model saved to: outputs/checkpoints/CICIDS2017_GRU_seed42.pt
# [GPU 0] [4/5] Evaluating on test set...
# [GPU 0]   Test Acc: 0.9913 | Prec: 0.9983 | Rec: 0.9040 | F1: 0.9488 | AUC: 0.9884
# [GPU 0] [5/5] Measuring efficiency...
# [GPU 0]   Latency: 0.51ms | Throughput: 43641/s | Memory: 1.42MB
# [GPU 0]   Attack types analyzed: 2
# [GPU 0]
# [GPU 0] [4/16] Running experiment...
# [GPU 0]
# [GPU 0] ======================================================================
# [GPU 0]   Dataset: CICIDS2017 | Model: CNN-LSTM | Seed: 42
# [GPU 0] ======================================================================
# [GPU 0] [Reproducibility] Setting all random seeds to 42
# [GPU 0] [Reproducibility] [OK] All seeds set and deterministic mode enabled
# [GPU 0] [1/5] Loading CICIDS2017 dataset...
# [GPU 0] [TRAIN] Loading from cache: outputs/cache/cicids2017_train.npz
# [GPU 0]   Cached shape: (863214, 77), labels: 863214
# [GPU 0] [TRAIN] Raw shape (before windowing): (863214, 77)
# [GPU 0] Fitting StandardScaler on Train split...
# [GPU 0] Saved scaler to outputs/scaler_cicids.pkl
# [GPU 0] [OK] Will generate 863165 windows lazily during training
# [GPU 0] [VAL] Loading from cache: outputs/cache/cicids2017_val.npz
# [GPU 0]   Cached shape: (123316, 77), labels: 123316
# [GPU 0] [VAL] Raw shape (before windowing): (123316, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 123267 windows lazily during training
# [GPU 0] [TEST] Loading from cache: outputs/cache/cicids2017_test.npz
# [GPU 0]   Cached shape: (246633, 77), labels: 246633
# [GPU 0] [TEST] Raw shape (before windowing): (246633, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 246584 windows lazily during training
# [GPU 0]   Limiting (strided): train 863165 -> 200000, val 123267 -> 25000, test 246584 -> 50000
# [GPU 0]   Features: 77, Train: 200000, Val: 25000, Test: 50000
# [GPU 0] [2/5] Initializing CNN-LSTM (d_model=128, n_layers=2)...
# [GPU 0]   Parameters: 409,601
# [GPU 0] [3/5] Training CNN-LSTM...
# [GPU 0]   LR: 0.000500 (base=0.001 × 0.5 for CNN-LSTM), grad_clip=0.5
# [GPU 0]   Using class-weighted loss (pos_weight=1.00)
# [GPU 0]   Epoch   1/30 | TrLoss: 0.1814 | VlLoss: 0.1702 | VlAcc: 0.9645 | VlF1: 0.9819 *
# [GPU 0]   Epoch   2/30 | TrLoss: 0.1341 | VlLoss: 0.1535 | VlAcc: 0.9645 | VlF1: 0.9819
# [GPU 0]   Epoch   3/30 | TrLoss: 0.0727 | VlLoss: 0.1922 | VlAcc: 0.9645 | VlF1: 0.9819
# [GPU 0]   Epoch   4/30 | TrLoss: 0.0212 | VlLoss: 0.0792 | VlAcc: 0.9744 | VlF1: 0.9868 *
# [GPU 0]   Epoch   5/30 | TrLoss: 0.0073 | VlLoss: 0.0577 | VlAcc: 0.9764 | VlF1: 0.9878 *
# [GPU 0]   Epoch   6/30 | TrLoss: 0.0047 | VlLoss: 0.0390 | VlAcc: 0.9886 | VlF1: 0.9941 *
# [GPU 0]   Epoch   7/30 | TrLoss: 0.0039 | VlLoss: 0.0308 | VlAcc: 0.9905 | VlF1: 0.9951 *
# [GPU 0]   Epoch   8/30 | TrLoss: 0.0037 | VlLoss: 0.0282 | VlAcc: 0.9926 | VlF1: 0.9962 *
# [GPU 0]   Epoch   9/30 | TrLoss: 0.0032 | VlLoss: 0.0420 | VlAcc: 0.9912 | VlF1: 0.9954
# [GPU 0]   Epoch  10/30 | TrLoss: 0.0023 | VlLoss: 0.0934 | VlAcc: 0.9906 | VlF1: 0.9951
# [GPU 0]   Epoch  11/30 | TrLoss: 0.0023 | VlLoss: 0.0180 | VlAcc: 0.9955 | VlF1: 0.9977 *
# [GPU 0]   Epoch  12/30 | TrLoss: 0.0022 | VlLoss: 0.4084 | VlAcc: 0.6875 | VlF1: 0.8072
# [GPU 0]   Epoch  13/30 | TrLoss: 0.0023 | VlLoss: 0.0256 | VlAcc: 0.9904 | VlF1: 0.9950
# [GPU 0]   Epoch  14/30 | TrLoss: 0.0016 | VlLoss: 0.0746 | VlAcc: 0.9823 | VlF1: 0.9908
# [GPU 0]   Epoch  15/30 | TrLoss: 0.0017 | VlLoss: 0.0396 | VlAcc: 0.9923 | VlF1: 0.9960
# [GPU 0]   Epoch  16/30 | TrLoss: 0.0014 | VlLoss: 0.0465 | VlAcc: 0.9939 | VlF1: 0.9968
# [GPU 0]   Early stopping at epoch 16 (patience=5)
# [GPU 0]   Best Val F1: 0.9977 (16 epochs, 323.4s)
# [GPU 0]   💾 Model saved to: outputs/checkpoints/CICIDS2017_CNN-LSTM_seed42.pt
# [GPU 0] [4/5] Evaluating on test set...
# [GPU 0]   Test Acc: 0.9533 | Prec: 0.6685 | Rec: 0.9460 | F1: 0.7834 | AUC: 0.9746
# [GPU 0] [5/5] Measuring efficiency...
# [GPU 0]   Latency: 0.86ms | Throughput: 33414/s | Memory: 1.56MB
# [GPU 0]   Attack types analyzed: 2
# [GPU 0]
# [GPU 0] [5/16] Running experiment...
# [GPU 0]
# [GPU 0] ======================================================================
# [GPU 0]   Dataset: CICIDS2017 | Model: Mamba | Seed: 123
# [GPU 0] ======================================================================
# [GPU 0] [Reproducibility] Setting all random seeds to 123
# [GPU 0] [Reproducibility] [OK] All seeds set and deterministic mode enabled
# [GPU 0] [1/5] Loading CICIDS2017 dataset...
# [GPU 0] [TRAIN] Loading from cache: outputs/cache/cicids2017_train.npz
# [GPU 0]   Cached shape: (863214, 77), labels: 863214
# [GPU 0] [TRAIN] Raw shape (before windowing): (863214, 77)
# [GPU 0] Fitting StandardScaler on Train split...
# [GPU 0] Saved scaler to outputs/scaler_cicids.pkl
# [GPU 0] [OK] Will generate 863165 windows lazily during training
# [GPU 0] [VAL] Loading from cache: outputs/cache/cicids2017_val.npz
# [GPU 0]   Cached shape: (123316, 77), labels: 123316
# [GPU 0] [VAL] Raw shape (before windowing): (123316, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 123267 windows lazily during training
# [GPU 0] [TEST] Loading from cache: outputs/cache/cicids2017_test.npz
# [GPU 0]   Cached shape: (246633, 77), labels: 246633
# [GPU 0] [TEST] Raw shape (before windowing): (246633, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 246584 windows lazily during training
# [GPU 0]   Limiting (strided): train 863165 -> 200000, val 123267 -> 25000, test 246584 -> 50000
# [GPU 0]   Features: 77, Train: 200000, Val: 25000, Test: 50000
# [GPU 0] [2/5] Initializing Mamba (d_model=128, n_layers=2)...
# [GPU 0]   Parameters: 387,073
# [GPU 0] [3/5] Training Mamba...
# [GPU 0]   LR: 0.000300 (base=0.001 × 0.3 for Mamba), grad_clip=0.5
# [GPU 0]   Using class-weighted loss (pos_weight=1.00)
# [GPU 1]   Epoch  11/30 | TrLoss: 0.0025 | VlLoss: 0.0233 | VlAcc: 0.9966 | VlF1: 0.9982
# [GPU 0]   Epoch   1/30 | TrLoss: 0.0682 | VlLoss: 0.1109 | VlAcc: 0.9792 | VlF1: 0.9893 *
# [GPU 1]   Epoch  12/30 | TrLoss: 0.0021 | VlLoss: 0.0315 | VlAcc: 0.9956 | VlF1: 0.9977
# [GPU 0]   Epoch   2/30 | TrLoss: 0.0245 | VlLoss: 0.1883 | VlAcc: 0.9649 | VlF1: 0.9821
# [GPU 1]   Epoch  13/30 | TrLoss: 0.0114 | VlLoss: 0.0381 | VlAcc: 0.9799 | VlF1: 0.9895
# [GPU 0]   Epoch   3/30 | TrLoss: 0.0698 | VlLoss: 0.0568 | VlAcc: 0.9904 | VlF1: 0.9950 *
# [GPU 1]   Epoch  14/30 | TrLoss: 0.0019 | VlLoss: 0.0262 | VlAcc: 0.9954 | VlF1: 0.9976
# [GPU 0]   Epoch   4/30 | TrLoss: 0.0299 | VlLoss: 0.0346 | VlAcc: 0.9902 | VlF1: 0.9949
# [GPU 1]   Epoch  15/30 | TrLoss: 0.0013 | VlLoss: 0.0246 | VlAcc: 0.9960 | VlF1: 0.9979
# [GPU 1]   Early stopping at epoch 15 (patience=5)
# [GPU 1]   Best Val F1: 0.9983 (15 epochs, 10113.2s)
# [GPU 1]   💾 Model saved to: outputs/checkpoints/CICIDS2017_Mamba_seed456.pt
# [GPU 1] [4/5] Evaluating on test set...
# [GPU 1]   Test Acc: 0.9911 | Prec: 0.9993 | Rec: 0.9004 | F1: 0.9473 | AUC: 0.9840
# [GPU 1] [5/5] Measuring efficiency...
# [GPU 1]   Latency: 9.80ms | Throughput: 3171/s | Memory: 1.48MB
# [GPU 1]   Attack types analyzed: 2
# [GPU 1]
# [GPU 1] [2/8] Running experiment...
# [GPU 1]
# [GPU 1] ======================================================================
# [GPU 1]   Dataset: CICIDS2017 | Model: LSTM | Seed: 456
# [GPU 1] ======================================================================
# [GPU 1] [Reproducibility] Setting all random seeds to 456
# [GPU 1] [Reproducibility] [OK] All seeds set and deterministic mode enabled
# [GPU 1] [1/5] Loading CICIDS2017 dataset...
# [GPU 1] [TRAIN] Loading from cache: outputs/cache/cicids2017_train.npz
# [GPU 1]   Cached shape: (863214, 77), labels: 863214
# [GPU 1] [TRAIN] Raw shape (before windowing): (863214, 77)
# [GPU 1] Fitting StandardScaler on Train split...
# [GPU 1] Saved scaler to outputs/scaler_cicids.pkl
# [GPU 1] [OK] Will generate 863165 windows lazily during training
# [GPU 1] [VAL] Loading from cache: outputs/cache/cicids2017_val.npz
# [GPU 1]   Cached shape: (123316, 77), labels: 123316
# [GPU 1] [VAL] Raw shape (before windowing): (123316, 77)
# [GPU 1] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 1] [OK] Will generate 123267 windows lazily during training
# [GPU 1] [TEST] Loading from cache: outputs/cache/cicids2017_test.npz
# [GPU 1]   Cached shape: (246633, 77), labels: 246633
# [GPU 1] [TEST] Raw shape (before windowing): (246633, 77)
# [GPU 1] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 1] [OK] Will generate 246584 windows lazily during training
# [GPU 1]   Limiting (strided): train 863165 -> 200000, val 123267 -> 25000, test 246584 -> 50000
# [GPU 1]   Features: 77, Train: 200000, Val: 25000, Test: 50000
# [GPU 1] [2/5] Initializing LSTM (d_model=128, n_layers=2)...
# [GPU 1]   Parameters: 423,169
# [GPU 1] [3/5] Training LSTM...
# [GPU 1]   LR: 0.001000 (base=0.001 × 1.0 for LSTM), grad_clip=1.0
# [GPU 1]   Using class-weighted loss (pos_weight=1.00)
# [GPU 1]   Epoch   1/30 | TrLoss: 0.0771 | VlLoss: 0.2076 | VlAcc: 0.9645 | VlF1: 0.9819 *
# [GPU 1]   Epoch   2/30 | TrLoss: 0.1070 | VlLoss: 0.2407 | VlAcc: 0.9645 | VlF1: 0.9819
# [GPU 1]   Epoch   3/30 | TrLoss: 0.1119 | VlLoss: 0.2318 | VlAcc: 0.9645 | VlF1: 0.9819
# [GPU 1]   Epoch   4/30 | TrLoss: 0.0934 | VlLoss: 0.1905 | VlAcc: 0.9645 | VlF1: 0.9819
# [GPU 1]   Epoch   5/30 | TrLoss: 0.1453 | VlLoss: 0.1875 | VlAcc: 0.9645 | VlF1: 0.9819
# [GPU 1]   Epoch   6/30 | TrLoss: 0.1273 | VlLoss: 0.2071 | VlAcc: 0.9645 | VlF1: 0.9819
# [GPU 1]   Early stopping at epoch 6 (patience=5)
# [GPU 1]   Best Val F1: 0.9819 (6 epochs, 118.7s)
# [GPU 1]   💾 Model saved to: outputs/checkpoints/CICIDS2017_LSTM_seed456.pt
# [GPU 1] [4/5] Evaluating on test set...
# [GPU 1]   Test Acc: 0.0892 | Prec: 0.0892 | Rec: 1.0000 | F1: 0.1638 | AUC: 0.4379
# [GPU 1] [5/5] Measuring efficiency...
# [GPU 1]   Latency: 0.76ms | Throughput: 30726/s | Memory: 1.61MB
# [GPU 1]   Attack types analyzed: 2
# [GPU 1]
# [GPU 1] [3/8] Running experiment...
# [GPU 1]
# [GPU 1] ======================================================================
# [GPU 1]   Dataset: CICIDS2017 | Model: GRU | Seed: 456
# [GPU 1] ======================================================================
# [GPU 1] [Reproducibility] Setting all random seeds to 456
# [GPU 1] [Reproducibility] [OK] All seeds set and deterministic mode enabled
# [GPU 1] [1/5] Loading CICIDS2017 dataset...
# [GPU 1] [TRAIN] Loading from cache: outputs/cache/cicids2017_train.npz
# [GPU 1]   Cached shape: (863214, 77), labels: 863214
# [GPU 1] [TRAIN] Raw shape (before windowing): (863214, 77)
# [GPU 1] Fitting StandardScaler on Train split...
# [GPU 1] Saved scaler to outputs/scaler_cicids.pkl
# [GPU 1] [OK] Will generate 863165 windows lazily during training
# [GPU 1] [VAL] Loading from cache: outputs/cache/cicids2017_val.npz
# [GPU 1]   Cached shape: (123316, 77), labels: 123316
# [GPU 1] [VAL] Raw shape (before windowing): (123316, 77)
# [GPU 1] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 1] [OK] Will generate 123267 windows lazily during training
# [GPU 1] [TEST] Loading from cache: outputs/cache/cicids2017_test.npz
# [GPU 1]   Cached shape: (246633, 77), labels: 246633
# [GPU 1] [TEST] Raw shape (before windowing): (246633, 77)
# [GPU 1] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 1] [OK] Will generate 246584 windows lazily during training
# [GPU 1]   Limiting (strided): train 863165 -> 200000, val 123267 -> 25000, test 246584 -> 50000
# [GPU 1]   Features: 77, Train: 200000, Val: 25000, Test: 50000
# [GPU 1] [2/5] Initializing GRU (d_model=128, n_layers=2)...
# [GPU 1]   Parameters: 373,505
# [GPU 1] [3/5] Training GRU...
# [GPU 1]   LR: 0.001000 (base=0.001 × 1.0 for GRU), grad_clip=0.5
# [GPU 1]   Using class-weighted loss (pos_weight=1.00)
# [GPU 1]   Epoch   1/30 | TrLoss: 0.1657 | VlLoss: 0.1540 | VlAcc: 0.9645 | VlF1: 0.9819 *
# [GPU 1]   Epoch   2/30 | TrLoss: 0.1257 | VlLoss: 0.2087 | VlAcc: 0.9645 | VlF1: 0.9819
# [GPU 1]   Epoch   3/30 | TrLoss: 0.1202 | VlLoss: 0.2155 | VlAcc: 0.9645 | VlF1: 0.9819
# [GPU 1]   Epoch   4/30 | TrLoss: 0.1330 | VlLoss: 0.2313 | VlAcc: 0.9645 | VlF1: 0.9819
# [GPU 1]   Epoch   5/30 | TrLoss: 0.1722 | VlLoss: 0.2010 | VlAcc: 0.9645 | VlF1: 0.9819
# [GPU 1]   Epoch   6/30 | TrLoss: 0.1261 | VlLoss: 0.1646 | VlAcc: 0.9645 | VlF1: 0.9819
# [GPU 1]   Early stopping at epoch 6 (patience=5)
# [GPU 1]   Best Val F1: 0.9819 (6 epochs, 99.1s)
# [GPU 1]   💾 Model saved to: outputs/checkpoints/CICIDS2017_GRU_seed456.pt
# [GPU 1] [4/5] Evaluating on test set...
# [GPU 1]   Test Acc: 0.0892 | Prec: 0.0892 | Rec: 1.0000 | F1: 0.1638 | AUC: 0.2991
# [GPU 1] [5/5] Measuring efficiency...
# [GPU 1]   Latency: 0.49ms | Throughput: 44286/s | Memory: 1.42MB
# [GPU 1]   Attack types analyzed: 2
# [GPU 1]
# [GPU 1] [4/8] Running experiment...
# [GPU 1]
# [GPU 1] ======================================================================
# [GPU 1]   Dataset: CICIDS2017 | Model: CNN-LSTM | Seed: 456
# [GPU 1] ======================================================================
# [GPU 1] [Reproducibility] Setting all random seeds to 456
# [GPU 1] [Reproducibility] [OK] All seeds set and deterministic mode enabled
# [GPU 1] [1/5] Loading CICIDS2017 dataset...
# [GPU 1] [TRAIN] Loading from cache: outputs/cache/cicids2017_train.npz
# [GPU 1]   Cached shape: (863214, 77), labels: 863214
# [GPU 1] [TRAIN] Raw shape (before windowing): (863214, 77)
# [GPU 1] Fitting StandardScaler on Train split...
# [GPU 1] Saved scaler to outputs/scaler_cicids.pkl
# [GPU 1] [OK] Will generate 863165 windows lazily during training
# [GPU 1] [VAL] Loading from cache: outputs/cache/cicids2017_val.npz
# [GPU 1]   Cached shape: (123316, 77), labels: 123316
# [GPU 1] [VAL] Raw shape (before windowing): (123316, 77)
# [GPU 1] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 1] [OK] Will generate 123267 windows lazily during training
# [GPU 1] [TEST] Loading from cache: outputs/cache/cicids2017_test.npz
# [GPU 1]   Cached shape: (246633, 77), labels: 246633
# [GPU 1] [TEST] Raw shape (before windowing): (246633, 77)
# [GPU 1] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 1] [OK] Will generate 246584 windows lazily during training
# [GPU 1]   Limiting (strided): train 863165 -> 200000, val 123267 -> 25000, test 246584 -> 50000
# [GPU 1]   Features: 77, Train: 200000, Val: 25000, Test: 50000
# [GPU 1] [2/5] Initializing CNN-LSTM (d_model=128, n_layers=2)...
# [GPU 1]   Parameters: 409,601
# [GPU 1] [3/5] Training CNN-LSTM...
# [GPU 1]   LR: 0.000500 (base=0.001 × 0.5 for CNN-LSTM), grad_clip=0.5
# [GPU 1]   Using class-weighted loss (pos_weight=1.00)
# [GPU 1]   Epoch   1/30 | TrLoss: 0.2540 | VlLoss: 0.1720 | VlAcc: 0.9645 | VlF1: 0.9819 *
# [GPU 1]   Epoch   2/30 | TrLoss: 0.1506 | VlLoss: 0.1412 | VlAcc: 0.9645 | VlF1: 0.9819
# [GPU 1]   Epoch   3/30 | TrLoss: 0.1005 | VlLoss: 0.1441 | VlAcc: 0.9649 | VlF1: 0.9821 *
# [GPU 1]   Epoch   4/30 | TrLoss: 0.0432 | VlLoss: 0.1432 | VlAcc: 0.9649 | VlF1: 0.9821 *
# [GPU 1]   Epoch   5/30 | TrLoss: 0.0113 | VlLoss: 0.1662 | VlAcc: 0.9723 | VlF1: 0.9855 *
# [GPU 1]   Epoch   6/30 | TrLoss: 0.0062 | VlLoss: 0.0796 | VlAcc: 0.9822 | VlF1: 0.9908 *
# [GPU 1]   Epoch   7/30 | TrLoss: 0.0056 | VlLoss: 0.0594 | VlAcc: 0.9900 | VlF1: 0.9948 *
# [GPU 0]   Epoch   5/30 | TrLoss: 0.0073 | VlLoss: 0.0320 | VlAcc: 0.9877 | VlF1: 0.9936
# [GPU 1]   Epoch   8/30 | TrLoss: 0.0043 | VlLoss: 0.0449 | VlAcc: 0.9922 | VlF1: 0.9960 *
# [GPU 1]   Epoch   9/30 | TrLoss: 0.0035 | VlLoss: 0.0464 | VlAcc: 0.9923 | VlF1: 0.9960 *
# [GPU 1]   Epoch  10/30 | TrLoss: 0.0026 | VlLoss: 0.0288 | VlAcc: 0.9925 | VlF1: 0.9961 *
# [GPU 1]   Epoch  11/30 | TrLoss: 0.0025 | VlLoss: 0.3548 | VlAcc: 0.7896 | VlF1: 0.8777
# [GPU 1]   Epoch  12/30 | TrLoss: 0.0027 | VlLoss: 0.0404 | VlAcc: 0.9903 | VlF1: 0.9949
# [GPU 1]   Epoch  13/30 | TrLoss: 0.0025 | VlLoss: 0.0271 | VlAcc: 0.9920 | VlF1: 0.9959
# [GPU 1]   Epoch  14/30 | TrLoss: 0.0017 | VlLoss: 0.0442 | VlAcc: 0.9915 | VlF1: 0.9956
# [GPU 1]   Epoch  15/30 | TrLoss: 0.0014 | VlLoss: 0.0508 | VlAcc: 0.9900 | VlF1: 0.9948
# [GPU 1]   Early stopping at epoch 15 (patience=5)
# [GPU 1]   Best Val F1: 0.9961 (15 epochs, 299.9s)
# [GPU 1]   💾 Model saved to: outputs/checkpoints/CICIDS2017_CNN-LSTM_seed456.pt
# [GPU 1] [4/5] Evaluating on test set...
# [GPU 1]   Test Acc: 0.9624 | Prec: 0.7196 | Rec: 0.9478 | F1: 0.8181 | AUC: 0.9698
# [GPU 1] [5/5] Measuring efficiency...
# [GPU 1]   Latency: 0.90ms | Throughput: 33301/s | Memory: 1.56MB
# [GPU 1]   Attack types analyzed: 2
# [GPU 1]
# [GPU 1] [5/8] Running experiment...
# [GPU 1]
# [GPU 1] ======================================================================
# [GPU 1]   Dataset: UNSW-NB15 | Model: Mamba | Seed: 456
# [GPU 1] ======================================================================
# [GPU 1] [Reproducibility] Setting all random seeds to 456
# [GPU 1] [Reproducibility] [OK] All seeds set and deterministic mode enabled
# [GPU 1] [1/5] Loading UNSW-NB15 dataset...
# [GPU 1] [TRAIN] Loading UNSW-NB15...
# [GPU 1] Files: ['UNSW-NB15_1.csv', 'UNSW-NB15_2.csv', 'UNSW-NB15_3.csv', 'UNSW-NB15_4.csv']
# [GPU 1]   -> Processing UNSW-NB15_1.csv...
# [GPU 1]   -> Processing UNSW-NB15_2.csv...
# [GPU 1]   -> Processing UNSW-NB15_3.csv...
# [GPU 1]   -> Processing UNSW-NB15_4.csv...
# [GPU 1] Loaded 2540043 total rows.
# [GPU 1] Class Distribution: Benign=0, Attack=2540043
# [GPU 1] Total samples: 2540043
# [GPU 1] Train: 0-1778030, Val: 1778030-2032034, Test: 2032034-2540043
# [GPU 1] Saved scaler to outputs/scaler_unswnb15.pkl
# [GPU 1] [TRAIN] Raw shape: (1778030, 140)
# [GPU 1] [OK] Will generate 1777981 windows lazily
# [GPU 1] [VAL] Loading UNSW-NB15...
# [GPU 1] Files: ['UNSW-NB15_1.csv', 'UNSW-NB15_2.csv', 'UNSW-NB15_3.csv', 'UNSW-NB15_4.csv']
# [GPU 1]   -> Processing UNSW-NB15_1.csv...
# [GPU 1]   -> Processing UNSW-NB15_2.csv...
# [GPU 1]   -> Processing UNSW-NB15_3.csv...
# [GPU 1]   -> Processing UNSW-NB15_4.csv...
# [GPU 1] Loaded 2540043 total rows.
# [GPU 1] Class Distribution: Benign=0, Attack=2540043
# [GPU 1] Total samples: 2540043
# [GPU 1] Train: 0-1778030, Val: 1778030-2032034, Test: 2032034-2540043
# [GPU 1] [VAL] Raw shape: (254004, 140)
# [GPU 1] [OK] Will generate 253955 windows lazily
# [GPU 1] [TEST] Loading UNSW-NB15...
# [GPU 1] Files: ['UNSW-NB15_1.csv', 'UNSW-NB15_2.csv', 'UNSW-NB15_3.csv', 'UNSW-NB15_4.csv']
# [GPU 1]   -> Processing UNSW-NB15_1.csv...
# [GPU 1]   -> Processing UNSW-NB15_2.csv...
# [GPU 1]   -> Processing UNSW-NB15_3.csv...
# [GPU 1]   -> Processing UNSW-NB15_4.csv...
# [GPU 1] Loaded 2540043 total rows.
# [GPU 1] Class Distribution: Benign=0, Attack=2540043
# [GPU 1] Total samples: 2540043
# [GPU 1] Train: 0-1778030, Val: 1778030-2032034, Test: 2032034-2540043
# [GPU 1] [TEST] Raw shape: (508009, 140)
# [GPU 1] [OK] Will generate 507960 windows lazily
# [GPU 1]   Limiting (strided): train 1777981 -> 200000, val 253955 -> 25000, test 507960 -> 50000
# [GPU 1]   Features: 140, Train: 200000, Val: 25000, Test: 50000
# [GPU 1] [2/5] Initializing Mamba (d_model=128, n_layers=2)...
# [GPU 1]   Parameters: 403,201
# [GPU 1] [3/5] Training Mamba...
# [GPU 1]   LR: 0.000300 (base=0.001 × 0.3 for Mamba), grad_clip=0.5
# [GPU 1]   Using class-weighted loss (pos_weight=1.00)
# [GPU 0]   Epoch   6/30 | TrLoss: 0.0041 | VlLoss: 0.6175 | VlAcc: 0.7836 | VlF1: 0.8737
# [GPU 1]   Epoch   1/30 | TrLoss: 0.0086 | VlLoss: 0.0001 | VlAcc: 1.0000 | VlF1: 1.0000 *
# [GPU 0]   Epoch   7/30 | TrLoss: 0.0031 | VlLoss: 2.2397 | VlAcc: 0.3558 | VlF1: 0.4986
# [GPU 1]   Epoch   2/30 | TrLoss: 0.0001 | VlLoss: 0.0000 | VlAcc: 1.0000 | VlF1: 1.0000
# [GPU 0]   Epoch   8/30 | TrLoss: 0.0024 | VlLoss: 1.5735 | VlAcc: 0.3887 | VlF1: 0.5362
# [GPU 0]   Early stopping at epoch 8 (patience=5)
# [GPU 0]   Best Val F1: 0.9950 (8 epochs, 5391.2s)
# [GPU 0]   💾 Model saved to: outputs/checkpoints/CICIDS2017_Mamba_seed123.pt
# [GPU 0] [4/5] Evaluating on test set...
# [GPU 0]   Test Acc: 0.9350 | Prec: 0.5876 | Rec: 0.9090 | F1: 0.7138 | AUC: 0.9697
# [GPU 0] [5/5] Measuring efficiency...
# [GPU 0]   Latency: 11.18ms | Throughput: 2967/s | Memory: 1.48MB
# [GPU 0]   Attack types analyzed: 2
# [GPU 0]
# [GPU 0] [6/16] Running experiment...
# [GPU 0]
# [GPU 0] ======================================================================
# [GPU 0]   Dataset: CICIDS2017 | Model: LSTM | Seed: 123
# [GPU 0] ======================================================================
# [GPU 0] [Reproducibility] Setting all random seeds to 123
# [GPU 0] [Reproducibility] [OK] All seeds set and deterministic mode enabled
# [GPU 0] [1/5] Loading CICIDS2017 dataset...
# [GPU 0] [TRAIN] Loading from cache: outputs/cache/cicids2017_train.npz
# [GPU 0]   Cached shape: (863214, 77), labels: 863214
# [GPU 0] [TRAIN] Raw shape (before windowing): (863214, 77)
# [GPU 0] Fitting StandardScaler on Train split...
# [GPU 0] Saved scaler to outputs/scaler_cicids.pkl
# [GPU 0] [OK] Will generate 863165 windows lazily during training
# [GPU 0] [VAL] Loading from cache: outputs/cache/cicids2017_val.npz
# [GPU 0]   Cached shape: (123316, 77), labels: 123316
# [GPU 0] [VAL] Raw shape (before windowing): (123316, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 123267 windows lazily during training
# [GPU 0] [TEST] Loading from cache: outputs/cache/cicids2017_test.npz
# [GPU 0]   Cached shape: (246633, 77), labels: 246633
# [GPU 0] [TEST] Raw shape (before windowing): (246633, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 246584 windows lazily during training
# [GPU 0]   Limiting (strided): train 863165 -> 200000, val 123267 -> 25000, test 246584 -> 50000
# [GPU 0]   Features: 77, Train: 200000, Val: 25000, Test: 50000
# [GPU 0] [2/5] Initializing LSTM (d_model=128, n_layers=2)...
# [GPU 0]   Parameters: 423,169
# [GPU 0] [3/5] Training LSTM...
# [GPU 0]   LR: 0.001000 (base=0.001 × 1.0 for LSTM), grad_clip=1.0
# [GPU 0]   Using class-weighted loss (pos_weight=1.00)
# [GPU 0]   Epoch   1/30 | TrLoss: 0.0890 | VlLoss: 0.2251 | VlAcc: 0.9645 | VlF1: 0.9819 *
# [GPU 0]   Epoch   2/30 | TrLoss: 0.1117 | VlLoss: 0.2314 | VlAcc: 0.9645 | VlF1: 0.9819
# [GPU 0]   Epoch   3/30 | TrLoss: 0.1109 | VlLoss: 0.2769 | VlAcc: 0.9645 | VlF1: 0.9819
# [GPU 0]   Epoch   4/30 | TrLoss: 0.1095 | VlLoss: 0.2341 | VlAcc: 0.9645 | VlF1: 0.9819
# [GPU 0]   Epoch   5/30 | TrLoss: 0.1478 | VlLoss: 0.1775 | VlAcc: 0.9645 | VlF1: 0.9819
# [GPU 0]   Epoch   6/30 | TrLoss: 0.1217 | VlLoss: 0.1470 | VlAcc: 0.9645 | VlF1: 0.9819
# [GPU 0]   Early stopping at epoch 6 (patience=5)
# [GPU 0]   Best Val F1: 0.9819 (6 epochs, 121.1s)
# [GPU 0]   💾 Model saved to: outputs/checkpoints/CICIDS2017_LSTM_seed123.pt
# [GPU 0] [4/5] Evaluating on test set...
# [GPU 0]   Test Acc: 0.0892 | Prec: 0.0892 | Rec: 1.0000 | F1: 0.1638 | AUC: 0.6120
# [GPU 0] [5/5] Measuring efficiency...
# [GPU 0]   Latency: 0.77ms | Throughput: 30748/s | Memory: 1.61MB
# [GPU 0]   Attack types analyzed: 2
# [GPU 0]
# [GPU 0] [7/16] Running experiment...
# [GPU 0]
# [GPU 0] ======================================================================
# [GPU 0]   Dataset: CICIDS2017 | Model: GRU | Seed: 123
# [GPU 0] ======================================================================
# [GPU 0] [Reproducibility] Setting all random seeds to 123
# [GPU 0] [Reproducibility] [OK] All seeds set and deterministic mode enabled
# [GPU 0] [1/5] Loading CICIDS2017 dataset...
# [GPU 0] [TRAIN] Loading from cache: outputs/cache/cicids2017_train.npz
# [GPU 0]   Cached shape: (863214, 77), labels: 863214
# [GPU 0] [TRAIN] Raw shape (before windowing): (863214, 77)
# [GPU 0] Fitting StandardScaler on Train split...
# [GPU 0] Saved scaler to outputs/scaler_cicids.pkl
# [GPU 0] [OK] Will generate 863165 windows lazily during training
# [GPU 0] [VAL] Loading from cache: outputs/cache/cicids2017_val.npz
# [GPU 0]   Cached shape: (123316, 77), labels: 123316
# [GPU 0] [VAL] Raw shape (before windowing): (123316, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 123267 windows lazily during training
# [GPU 0] [TEST] Loading from cache: outputs/cache/cicids2017_test.npz
# [GPU 0]   Cached shape: (246633, 77), labels: 246633
# [GPU 0] [TEST] Raw shape (before windowing): (246633, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 246584 windows lazily during training
# [GPU 0]   Limiting (strided): train 863165 -> 200000, val 123267 -> 25000, test 246584 -> 50000
# [GPU 0]   Features: 77, Train: 200000, Val: 25000, Test: 50000
# [GPU 0] [2/5] Initializing GRU (d_model=128, n_layers=2)...
# [GPU 0]   Parameters: 373,505
# [GPU 0] [3/5] Training GRU...
# [GPU 0]   LR: 0.001000 (base=0.001 × 1.0 for GRU), grad_clip=0.5
# [GPU 0]   Using class-weighted loss (pos_weight=1.00)
# [GPU 0]   Epoch   1/30 | TrLoss: 0.1609 | VlLoss: 0.1740 | VlAcc: 0.9645 | VlF1: 0.9819 *
# [GPU 0]   Epoch   2/30 | TrLoss: 0.1283 | VlLoss: 0.2171 | VlAcc: 0.9645 | VlF1: 0.9819
# [GPU 0]   Epoch   3/30 | TrLoss: 0.1253 | VlLoss: 0.2381 | VlAcc: 0.9645 | VlF1: 0.9819
# [GPU 0]   Epoch   4/30 | TrLoss: 0.1265 | VlLoss: 0.2214 | VlAcc: 0.9645 | VlF1: 0.9819
# [GPU 0]   Epoch   5/30 | TrLoss: 0.1823 | VlLoss: 0.1608 | VlAcc: 0.9645 | VlF1: 0.9819
# [GPU 0]   Epoch   6/30 | TrLoss: 0.1205 | VlLoss: 0.2646 | VlAcc: 0.9645 | VlF1: 0.9819
# [GPU 0]   Early stopping at epoch 6 (patience=5)
# [GPU 0]   Best Val F1: 0.9819 (6 epochs, 102.0s)
# [GPU 0]   💾 Model saved to: outputs/checkpoints/CICIDS2017_GRU_seed123.pt
# [GPU 0] [4/5] Evaluating on test set...
# [GPU 0]   Test Acc: 0.0892 | Prec: 0.0892 | Rec: 1.0000 | F1: 0.1638 | AUC: 0.2927
# [GPU 0] [5/5] Measuring efficiency...
# [GPU 0]   Latency: 0.51ms | Throughput: 44548/s | Memory: 1.42MB
# [GPU 0]   Attack types analyzed: 2
# [GPU 0]
# [GPU 0] [8/16] Running experiment...
# [GPU 0]
# [GPU 0] ======================================================================
# [GPU 0]   Dataset: CICIDS2017 | Model: CNN-LSTM | Seed: 123
# [GPU 0] ======================================================================
# [GPU 0] [Reproducibility] Setting all random seeds to 123
# [GPU 0] [Reproducibility] [OK] All seeds set and deterministic mode enabled
# [GPU 0] [1/5] Loading CICIDS2017 dataset...
# [GPU 0] [TRAIN] Loading from cache: outputs/cache/cicids2017_train.npz
# [GPU 0]   Cached shape: (863214, 77), labels: 863214
# [GPU 0] [TRAIN] Raw shape (before windowing): (863214, 77)
# [GPU 0] Fitting StandardScaler on Train split...
# [GPU 0] Saved scaler to outputs/scaler_cicids.pkl
# [GPU 0] [OK] Will generate 863165 windows lazily during training
# [GPU 0] [VAL] Loading from cache: outputs/cache/cicids2017_val.npz
# [GPU 0]   Cached shape: (123316, 77), labels: 123316
# [GPU 0] [VAL] Raw shape (before windowing): (123316, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 123267 windows lazily during training
# [GPU 0] [TEST] Loading from cache: outputs/cache/cicids2017_test.npz
# [GPU 0]   Cached shape: (246633, 77), labels: 246633
# [GPU 0] [TEST] Raw shape (before windowing): (246633, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 246584 windows lazily during training
# [GPU 0]   Limiting (strided): train 863165 -> 200000, val 123267 -> 25000, test 246584 -> 50000
# [GPU 0]   Features: 77, Train: 200000, Val: 25000, Test: 50000
# [GPU 0] [2/5] Initializing CNN-LSTM (d_model=128, n_layers=2)...
# [GPU 0]   Parameters: 409,601
# [GPU 0] [3/5] Training CNN-LSTM...
# [GPU 0]   LR: 0.000500 (base=0.001 × 0.5 for CNN-LSTM), grad_clip=0.5
# [GPU 0]   Using class-weighted loss (pos_weight=1.00)
# [GPU 1]   Epoch   3/30 | TrLoss: 0.0000 | VlLoss: 0.0000 | VlAcc: 1.0000 | VlF1: 1.0000
# [GPU 0]   Epoch   1/30 | TrLoss: 0.2437 | VlLoss: 0.1800 | VlAcc: 0.9645 | VlF1: 0.9819 *
# [GPU 0]   Epoch   2/30 | TrLoss: 0.1091 | VlLoss: 0.2013 | VlAcc: 0.9645 | VlF1: 0.9819 *
# [GPU 0]   Epoch   3/30 | TrLoss: 0.0890 | VlLoss: 0.1210 | VlAcc: 0.9729 | VlF1: 0.9860 *
# [GPU 0]   Epoch   4/30 | TrLoss: 0.0088 | VlLoss: 0.1339 | VlAcc: 0.9683 | VlF1: 0.9838
# ...
# [GPU 0] [TRAIN] Loading UNSW-NB15...
# [GPU 0] Files: ['UNSW-NB15_1.csv', 'UNSW-NB15_2.csv', 'UNSW-NB15_3.csv', 'UNSW-NB15_4.csv']
# [GPU 0]   -> Processing UNSW-NB15_1.csv...
# [GPU 0]   -> Processing UNSW-NB15_2.csv...
# [GPU 0]   -> Processing UNSW-NB15_3.csv...
# [GPU 0]   -> Processing UNSW-NB15_4.csv...
# [GPU 0] Loaded 2540043 total rows.
# [GPU 0] Class Distribution: Benign=0, Attack=2540043
# [GPU 0] Total samples: 2540043
# [GPU 0] Train: 0-1778030, Val: 1778030-2032034, Test: 2032034-2540043
# [GPU 0] Saved scaler to outputs/scaler_unswnb15.pkl
# [GPU 0] [TRAIN] Raw shape: (1778030, 140)
# [GPU 0] [OK] Will generate 1777981 windows lazily
# [GPU 0] [VAL] Loading UNSW-NB15...
# [GPU 0] Files: ['UNSW-NB15_1.csv', 'UNSW-NB15_2.csv', 'UNSW-NB15_3.csv', 'UNSW-NB15_4.csv']
# [GPU 0]   -> Processing UNSW-NB15_1.csv...
# [GPU 0]   -> Processing UNSW-NB15_2.csv...
# [GPU 0]   -> Processing UNSW-NB15_3.csv...
# [GPU 0]   -> Processing UNSW-NB15_4.csv...
# [GPU 0] Loaded 2540043 total rows.
# [GPU 0] Class Distribution: Benign=0, Attack=2540043
# [GPU 0] Total samples: 2540043
# [GPU 0] Train: 0-1778030, Val: 1778030-2032034, Test: 2032034-2540043
# [GPU 0] [VAL] Raw shape: (254004, 140)
# [GPU 0] [OK] Will generate 253955 windows lazily
# [GPU 0] [TEST] Loading UNSW-NB15...
# [GPU 0] Files: ['UNSW-NB15_1.csv', 'UNSW-NB15_2.csv', 'UNSW-NB15_3.csv', 'UNSW-NB15_4.csv']
# [GPU 0]   -> Processing UNSW-NB15_1.csv...
# [GPU 0]   -> Processing UNSW-NB15_2.csv...
# [GPU 0]   -> Processing UNSW-NB15_3.csv...
# [GPU 0]   -> Processing UNSW-NB15_4.csv...
# [GPU 0] Loaded 2540043 total rows.
# [GPU 0] Class Distribution: Benign=0, Attack=2540043
# [GPU 0] Total samples: 2540043
# [GPU 0] Train: 0-1778030, Val: 1778030-2032034, Test: 2032034-2540043
# [GPU 0] [TEST] Raw shape: (508009, 140)
# [GPU 0] [OK] Will generate 507960 windows lazily
# [GPU 0]   Limiting (strided): train 1777981 -> 200000, val 253955 -> 25000, test 507960 -> 50000
# [GPU 0]   Features: 140, Train: 200000, Val: 25000, Test: 50000
# [GPU 0] [2/5] Initializing LSTM (d_model=128, n_layers=2)...
# [GPU 0]   Parameters: 431,233
# [GPU 0] [3/5] Training LSTM...
# [GPU 0]   LR: 0.001000 (base=0.001 × 1.0 for LSTM), grad_clip=1.0
# [GPU 0]   Using class-weighted loss (pos_weight=1.00)
# [GPU 0]   Epoch   1/30 | TrLoss: 0.0012 | VlLoss: 0.0000 | VlAcc: 1.0000 | VlF1: 1.0000 *
# [GPU 0]   Epoch   2/30 | TrLoss: 0.0000 | VlLoss: 0.0000 | VlAcc: 1.0000 | VlF1: 1.0000
# [GPU 0]   Epoch   3/30 | TrLoss: 0.0000 | VlLoss: 0.0000 | VlAcc: 1.0000 | VlF1: 1.0000
# [GPU 0]   Epoch   4/30 | TrLoss: 0.0000 | VlLoss: 0.0000 | VlAcc: 1.0000 | VlF1: 1.0000
# [GPU 0]   Epoch   5/30 | TrLoss: 0.0000 | VlLoss: 0.0000 | VlAcc: 1.0000 | VlF1: 1.0000
# [GPU 0]   Epoch   6/30 | TrLoss: 0.0000 | VlLoss: 0.0000 | VlAcc: 1.0000 | VlF1: 1.0000
# [GPU 0]   Early stopping at epoch 6 (patience=5)
# [GPU 0]   Best Val F1: 1.0000 (6 epochs, 128.8s)
# [GPU 0]   💾 Model saved to: outputs/checkpoints/UNSW-NB15_LSTM_seed123.pt
# [GPU 0] [4/5] Evaluating on test set...
# [GPU 0] /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
# [GPU 0]   warnings.warn(
# [GPU 0]   Test Acc: 1.0000 | Prec: 1.0000 | Rec: 1.0000 | F1: 1.0000 | AUC: nan
# [GPU 0] [5/5] Measuring efficiency...
# [GPU 0]   Latency: 0.77ms | Throughput: 30431/s | Memory: 1.65MB
# [GPU 0]   Attack types analyzed: 1
# [GPU 0]
# [GPU 0] [15/16] Running experiment...
# [GPU 0]
# [GPU 0] ======================================================================
# [GPU 0]   Dataset: UNSW-NB15 | Model: GRU | Seed: 123
# [GPU 0] ======================================================================
# [GPU 0] [Reproducibility] Setting all random seeds to 123
# [GPU 0] [Reproducibility] [OK] All seeds set and deterministic mode enabled
# [GPU 0] [1/5] Loading UNSW-NB15 dataset...
# [GPU 0] [TRAIN] Loading UNSW-NB15...
# [GPU 0] Files: ['UNSW-NB15_1.csv', 'UNSW-NB15_2.csv', 'UNSW-NB15_3.csv', 'UNSW-NB15_4.csv']
# [GPU 0]   -> Processing UNSW-NB15_1.csv...
# [GPU 0]   -> Processing UNSW-NB15_2.csv...
# [GPU 0]   -> Processing UNSW-NB15_3.csv...
# [GPU 0]   -> Processing UNSW-NB15_4.csv...
# [GPU 0] Loaded 2540043 total rows.
# [GPU 0] Class Distribution: Benign=0, Attack=2540043
# [GPU 0] Total samples: 2540043
# [GPU 0] Train: 0-1778030, Val: 1778030-2032034, Test: 2032034-2540043
# [GPU 0] Saved scaler to outputs/scaler_unswnb15.pkl
# [GPU 0] [TRAIN] Raw shape: (1778030, 140)
# [GPU 0] [OK] Will generate 1777981 windows lazily
# [GPU 0] [VAL] Loading UNSW-NB15...
# [GPU 0] Files: ['UNSW-NB15_1.csv', 'UNSW-NB15_2.csv', 'UNSW-NB15_3.csv', 'UNSW-NB15_4.csv']
# [GPU 0]   -> Processing UNSW-NB15_1.csv...
# [GPU 0]   -> Processing UNSW-NB15_2.csv...
# [GPU 0]   -> Processing UNSW-NB15_3.csv...
# [GPU 0]   -> Processing UNSW-NB15_4.csv...
# [GPU 0] Loaded 2540043 total rows.
# [GPU 0] Class Distribution: Benign=0, Attack=2540043
# [GPU 0] Total samples: 2540043
# [GPU 0] Train: 0-1778030, Val: 1778030-2032034, Test: 2032034-2540043
# [GPU 0] [VAL] Raw shape: (254004, 140)
# [GPU 0] [OK] Will generate 253955 windows lazily
# [GPU 0] [TEST] Loading UNSW-NB15...
# [GPU 0] Files: ['UNSW-NB15_1.csv', 'UNSW-NB15_2.csv', 'UNSW-NB15_3.csv', 'UNSW-NB15_4.csv']
# [GPU 0]   -> Processing UNSW-NB15_1.csv...
# [GPU 0]   -> Processing UNSW-NB15_2.csv...
# [GPU 0]   -> Processing UNSW-NB15_3.csv...
# [GPU 0]   -> Processing UNSW-NB15_4.csv...
# [GPU 0] Loaded 2540043 total rows.
# [GPU 0] Class Distribution: Benign=0, Attack=2540043
# [GPU 0] Total samples: 2540043
# [GPU 0] Train: 0-1778030, Val: 1778030-2032034, Test: 2032034-2540043
# [GPU 0] [TEST] Raw shape: (508009, 140)
# [GPU 0] [OK] Will generate 507960 windows lazily
# [GPU 0]   Limiting (strided): train 1777981 -> 200000, val 253955 -> 25000, test 507960 -> 50000
# [GPU 0]   Features: 140, Train: 200000, Val: 25000, Test: 50000
# [GPU 0] [2/5] Initializing GRU (d_model=128, n_layers=2)...
# [GPU 0]   Parameters: 381,569
# [GPU 0] [3/5] Training GRU...
# [GPU 0]   LR: 0.001000 (base=0.001 × 1.0 for GRU), grad_clip=0.5
# [GPU 0]   Using class-weighted loss (pos_weight=1.00)
# [GPU 0]   Epoch   1/30 | TrLoss: 0.0096 | VlLoss: 0.0000 | VlAcc: 1.0000 | VlF1: 1.0000 *
# [GPU 0]   Epoch   2/30 | TrLoss: 0.0000 | VlLoss: 0.0000 | VlAcc: 1.0000 | VlF1: 1.0000
# [GPU 0]   Epoch   3/30 | TrLoss: 0.0000 | VlLoss: 0.0000 | VlAcc: 1.0000 | VlF1: 1.0000
# [GPU 0]   Epoch   4/30 | TrLoss: 0.0000 | VlLoss: 0.0000 | VlAcc: 1.0000 | VlF1: 1.0000
# [GPU 0]   Epoch   5/30 | TrLoss: 0.0000 | VlLoss: 0.0000 | VlAcc: 1.0000 | VlF1: 1.0000
# [GPU 0]   Epoch   6/30 | TrLoss: 0.0000 | VlLoss: 0.0000 | VlAcc: 1.0000 | VlF1: 1.0000
# [GPU 0]   Early stopping at epoch 6 (patience=5)
# [GPU 0]   Best Val F1: 1.0000 (6 epochs, 110.2s)
# [GPU 0]   💾 Model saved to: outputs/checkpoints/UNSW-NB15_GRU_seed123.pt
# [GPU 0] [4/5] Evaluating on test set...
# [GPU 0] /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
# [GPU 0]   warnings.warn(
# [GPU 0]   Test Acc: 1.0000 | Prec: 1.0000 | Rec: 1.0000 | F1: 1.0000 | AUC: nan
# [GPU 0] [5/5] Measuring efficiency...
# [GPU 0]   Latency: 0.58ms | Throughput: 43107/s | Memory: 1.46MB
# [GPU 0]   Attack types analyzed: 1
# [GPU 0]
# [GPU 0] [16/16] Running experiment...
# [GPU 0]
# [GPU 0] ======================================================================
# [GPU 0]   Dataset: UNSW-NB15 | Model: CNN-LSTM | Seed: 123
# [GPU 0] ======================================================================
# [GPU 0] [Reproducibility] Setting all random seeds to 123
# [GPU 0] [Reproducibility] [OK] All seeds set and deterministic mode enabled
# [GPU 0] [1/5] Loading UNSW-NB15 dataset...
# [GPU 0] [TRAIN] Loading UNSW-NB15...
# [GPU 0] Files: ['UNSW-NB15_1.csv', 'UNSW-NB15_2.csv', 'UNSW-NB15_3.csv', 'UNSW-NB15_4.csv']
# [GPU 0]   -> Processing UNSW-NB15_1.csv...
# [GPU 0]   -> Processing UNSW-NB15_2.csv...
# [GPU 0]   -> Processing UNSW-NB15_3.csv...
# [GPU 0]   -> Processing UNSW-NB15_4.csv...
# [GPU 0] Loaded 2540043 total rows.
# [GPU 0] Class Distribution: Benign=0, Attack=2540043
# [GPU 0] Total samples: 2540043
# [GPU 0] Train: 0-1778030, Val: 1778030-2032034, Test: 2032034-2540043
# [GPU 0] Saved scaler to outputs/scaler_unswnb15.pkl
# [GPU 0] [TRAIN] Raw shape: (1778030, 140)
# [GPU 0] [OK] Will generate 1777981 windows lazily
# [GPU 0] [VAL] Loading UNSW-NB15...
# [GPU 0] Files: ['UNSW-NB15_1.csv', 'UNSW-NB15_2.csv', 'UNSW-NB15_3.csv', 'UNSW-NB15_4.csv']
# [GPU 0]   -> Processing UNSW-NB15_1.csv...
# [GPU 0]   -> Processing UNSW-NB15_2.csv...
# [GPU 0]   -> Processing UNSW-NB15_3.csv...
# [GPU 0]   -> Processing UNSW-NB15_4.csv...
# [GPU 0] Loaded 2540043 total rows.
# [GPU 0] Class Distribution: Benign=0, Attack=2540043
# [GPU 0] Total samples: 2540043
# [GPU 0] Train: 0-1778030, Val: 1778030-2032034, Test: 2032034-2540043
# [GPU 0] [VAL] Raw shape: (254004, 140)
# [GPU 0] [OK] Will generate 253955 windows lazily
# [GPU 0] [TEST] Loading UNSW-NB15...
# [GPU 0] Files: ['UNSW-NB15_1.csv', 'UNSW-NB15_2.csv', 'UNSW-NB15_3.csv', 'UNSW-NB15_4.csv']
# [GPU 0]   -> Processing UNSW-NB15_1.csv...
# [GPU 0]   -> Processing UNSW-NB15_2.csv...
# [GPU 0]   -> Processing UNSW-NB15_3.csv...
# [GPU 0]   -> Processing UNSW-NB15_4.csv...
# [GPU 0] Loaded 2540043 total rows.
# [GPU 0] Class Distribution: Benign=0, Attack=2540043
# [GPU 0] Total samples: 2540043
# [GPU 0] Train: 0-1778030, Val: 1778030-2032034, Test: 2032034-2540043
# [GPU 0] [TEST] Raw shape: (508009, 140)
# [GPU 0] [OK] Will generate 507960 windows lazily
# [GPU 0]   Limiting (strided): train 1777981 -> 200000, val 253955 -> 25000, test 507960 -> 50000
# [GPU 0]   Features: 140, Train: 200000, Val: 25000, Test: 50000
# [GPU 0] [2/5] Initializing CNN-LSTM (d_model=128, n_layers=2)...
# [GPU 0]   Parameters: 433,793
# [GPU 0] [3/5] Training CNN-LSTM...
# [GPU 0]   LR: 0.000500 (base=0.001 × 0.5 for CNN-LSTM), grad_clip=0.5
# [GPU 0]   Using class-weighted loss (pos_weight=1.00)
# [GPU 0]   Epoch   1/30 | TrLoss: 0.0013 | VlLoss: 0.0000 | VlAcc: 1.0000 | VlF1: 1.0000 *
# [GPU 0]   Epoch   2/30 | TrLoss: 0.0000 | VlLoss: 0.0000 | VlAcc: 1.0000 | VlF1: 1.0000
# [GPU 0]   Epoch   3/30 | TrLoss: 0.0000 | VlLoss: 0.0000 | VlAcc: 1.0000 | VlF1: 1.0000
# [GPU 0]   Epoch   4/30 | TrLoss: 0.0000 | VlLoss: 0.0000 | VlAcc: 1.0000 | VlF1: 1.0000
# [GPU 0]   Epoch   5/30 | TrLoss: 0.0000 | VlLoss: 0.0000 | VlAcc: 1.0000 | VlF1: 1.0000
# [GPU 0]   Epoch   6/30 | TrLoss: 0.0000 | VlLoss: 0.0000 | VlAcc: 1.0000 | VlF1: 1.0000
# [GPU 0]   Early stopping at epoch 6 (patience=5)
# [GPU 0]   Best Val F1: 1.0000 (6 epochs, 132.1s)
# [GPU 0]   💾 Model saved to: outputs/checkpoints/UNSW-NB15_CNN-LSTM_seed123.pt
# [GPU 0] [4/5] Evaluating on test set...
# [GPU 0] /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
# [GPU 0]   warnings.warn(
# [GPU 0]   Test Acc: 1.0000 | Prec: 1.0000 | Rec: 1.0000 | F1: 1.0000 | AUC: nan
# [GPU 0] [5/5] Measuring efficiency...
# [GPU 0]   Latency: 0.96ms | Throughput: 31753/s | Memory: 1.65MB
# [GPU 0]   Attack types analyzed: 1
# [GPU 0]
# [GPU 0]
# [GPU 0] ======================================================================
# [GPU 0] BENCHMARK SUMMARY
# [GPU 0] ======================================================================
# [GPU 0]
# [GPU 0] 📊 CICIDS2017
# [GPU 0] Model                Acc     Prec      Rec       F1      AUC  Lat(ms)     Params
# [GPU 0] -----------------------------------------------------------------------------------
# [GPU 0] Mamba           0.9455  0.6388  0.9143  0.7511  0.9719   10.81     387,073
# [GPU 0] LSTM            0.5402  0.5436  0.9516  0.5560  0.8025    0.76     423,169
# [GPU 0] GRU             0.5403  0.5437  0.9520  0.5563  0.6406    0.51     373,505
# [GPU 0] CNN-LSTM        0.9707  0.7977  0.9433  0.8585  0.9727    0.86     409,601
# [GPU 0]
# [GPU 0] 📊 UNSW-NB15
# [GPU 0] Model                Acc     Prec      Rec       F1      AUC  Lat(ms)     Params
# [GPU 0] -----------------------------------------------------------------------------------
# [GPU 0] Mamba           0.1337  1.0000  0.1337  0.2359  0.0000   10.66     403,201
# [GPU 0] LSTM            1.0000  1.0000  1.0000  1.0000  nan    0.76     431,233
# [GPU 0] GRU             0.9798  1.0000  0.9798  0.9897  nan    0.58     381,569
# [GPU 0] CNN-LSTM        1.0000  1.0000  1.0000  1.0000  nan    0.90     433,793
# [GPU 0]
# [GPU 0] ✅ Results saved to: outputs/benchmark_results/
# [GPU 0]    Run 'python generate_tables.py' to generate publication tables.
#
# ✅ GPU 0 finished (exit=0)
# ✅ GPU 1 finished (exit=0)
# ⏱️  Total time: 6h 26m
#
# ============================================================
# 🏁 All done! Total time: 6h 26m
# ============================================================
#
# 📊 Merging results from both GPUs...
#    ✅ Merged 24 experiments from 24 files into all_results.json
# 📋 Generating publication tables...
# Loaded 24 experiment results.
#
# ## Table 1: Classification Results — CICIDS2017
# *Mean ± std across 3 seeds*
#
# | Model | Accuracy | Precision | Recall | F1-Score | AUC-ROC |
# |-------|----------|-----------|--------|----------|---------|
# | CNN-LSTM | 96.79 ± 1.47 | 77.17 ± 11.17 | 94.48 ± 0.30 | 84.51 ± 6.42 | 97.17 ± 0.20 |
# | Mamba | 96.07 ± 2.31 | 75.90 ± 17.50 | 90.97 ± 0.79 | 81.65 ± 9.74 | 97.59 ± 0.60 |
# | GRU | 38.99 ± 42.52 | 39.22 ± 42.85 | 96.80 ± 4.52 | 42.55 ± 37.01 | 52.67 ± 32.64 |
# | LSTM | 38.99 ± 42.52 | 39.21 ± 42.84 | 96.77 ± 4.57 | 42.53 ± 36.98 | 68.09 ± 23.18 |
#
# ## Table 1: Classification Results — UNSW-NB15
# *Mean ± std across 3 seeds*
#
# | Model | Accuracy | Precision | Recall | F1-Score | AUC-ROC |
# |-------|----------|-----------|--------|----------|---------|
# | CNN-LSTM | 100.00 ± 0.00 | 100.00 ± 0.00 | 100.00 ± 0.00 | 100.00 ± 0.00 | nan ± nan |
# | LSTM | 100.00 ± 0.00 | 100.00 ± 0.00 | 100.00 ± 0.00 | 100.00 ± 0.00 | nan ± nan |
# | GRU | 98.65 ± 1.91 | 100.00 ± 0.00 | 98.65 ± 1.91 | 99.31 ± 0.97 | nan ± nan |
# | Mamba | 13.37 ± 0.00 | 100.00 ± 0.00 | 13.37 ± 0.00 | 23.59 ± 0.00 | 0.00 ± 0.00 |
#
# ## Table 2: Efficiency Comparison — CICIDS2017
#
# | Model | Params | Memory (MB) | Latency (ms) | Throughput (/s) | Train Time (s) |
# |-------|--------|-------------|--------------|-----------------|----------------|
# | GRU | 373,505 | 1.42 | 0.50 ± 0.01 | 44158 | 191.1 |
# | LSTM | 423,169 | 1.61 | 0.76 ± 0.01 | 30737 | 193.8 |
# | CNN-LSTM | 409,601 | 1.56 | 0.87 ± 0.02 | 33481 | 368.4 |
# | Mamba | 387,073 | 1.48 | 10.47 ± 0.56 | 3037 | 7192.1 |
#
# ## Table 2: Efficiency Comparison — UNSW-NB15
#
# | Model | Params | Memory (MB) | Latency (ms) | Throughput (/s) | Train Time (s) |
# |-------|--------|-------------|--------------|-----------------|----------------|
# | GRU | 381,569 | 1.46 | 0.57 ± 0.02 | 43786 | 109.7 |
# | LSTM | 431,233 | 1.65 | 0.76 ± 0.01 | 30613 | 127.5 |
# | CNN-LSTM | 433,793 | 1.65 | 0.90 ± 0.05 | 31941 | 129.9 |
# | Mamba | 403,201 | 1.54 | 10.68 ± 0.09 | 2910 | 4052.3 |
#
# ## Table 3: Per-Attack-Type F1 (%) — CICIDS2017
#
# | Model | BENIGN | PortScan |
# |-------|--------|----------|
# | CNN-LSTM | 89.5 | 16.0 |
# | GRU | 49.0 | 0.3 |
# | LSTM | 48.9 | 0.3 |
# | Mamba | 87.2 | 1.1 |
#
# ## Table 3: Per-Attack-Type F1 (%) — UNSW-NB15
#
# | Model | Unknown |
# |-------|---------|
# | CNN-LSTM | 100.0 |
# | GRU | 99.3 |
# | LSTM | 100.0 |
# | Mamba | 23.6 |
#
# ## Table 4: Statistical Significance (Wilcoxon) — CICIDS2017
#
# | Model A | Model B | p-value | Significant (p<0.05) |
# |---------|---------|---------|----------------------|
# | CNN-LSTM | GRU | N/A | N/A |
# | CNN-LSTM | LSTM | N/A | N/A |
# | CNN-LSTM | Mamba | N/A | N/A |
# | GRU | LSTM | N/A | N/A |
# | GRU | Mamba | N/A | N/A |
# | LSTM | Mamba | N/A | N/A |
#
# ## Table 4: Statistical Significance (Wilcoxon) — UNSW-NB15
#
# | Model A | Model B | p-value | Significant (p<0.05) |
# |---------|---------|---------|----------------------|
# | CNN-LSTM | GRU | N/A | N/A |
# | CNN-LSTM | LSTM | N/A | N/A |
# | CNN-LSTM | Mamba | N/A | N/A |
# | GRU | LSTM | N/A | N/A |
# | GRU | Mamba | N/A | N/A |
# | LSTM | Mamba | N/A | N/A |
#
#
# ✅ Tables saved to outputs/benchmark_results/benchmark_tables.md
#
# ✅ Results saved to outputs/benchmark_results/
