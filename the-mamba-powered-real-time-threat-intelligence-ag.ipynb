# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/datasets/kk0105/cicids2017/Week_filtered.csv
# /kaggle/input/datasets/kk0105/cicids2017/MachineLearningCSV/MachineLearningCSV/MachineLearningCVE/Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv
# /kaggle/input/datasets/kk0105/cicids2017/MachineLearningCSV/MachineLearningCSV/MachineLearningCVE/Thursday-WorkingHours-Morning-WebAttacks.pcap_ISCX.csv
# /kaggle/input/datasets/kk0105/cicids2017/MachineLearningCSV/MachineLearningCSV/MachineLearningCVE/Tuesday-WorkingHours.pcap_ISCX.csv
# /kaggle/input/datasets/kk0105/cicids2017/MachineLearningCSV/MachineLearningCSV/MachineLearningCVE/Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv
# /kaggle/input/datasets/kk0105/cicids2017/MachineLearningCSV/MachineLearningCSV/MachineLearningCVE/Monday-WorkingHours.pcap_ISCX.csv
# /kaggle/input/datasets/kk0105/cicids2017/MachineLearningCSV/MachineLearningCSV/MachineLearningCVE/Friday-WorkingHours-Morning.pcap_ISCX.csv
# /kaggle/input/datasets/kk0105/cicids2017/MachineLearningCSV/MachineLearningCSV/MachineLearningCVE/Thursday-WorkingHours-Afternoon-Infilteration.pcap_ISCX.csv
# /kaggle/input/datasets/kk0105/cicids2017/MachineLearningCSV/MachineLearningCSV/MachineLearningCVE/Wednesday-workingHours.pcap_ISCX.csv

# %%
# !git clone https://github.com/ARUNTHOMAS3/The-Mamba-Powered-Real-time-Threat-Intelligence-Agent.git /kaggle/working/mamba
# %cd /kaggle/working/mamba
# !git pull
# !mkdir -p data/raw/CICIDS2017
# !cp /kaggle/input/datasets/kk0105/cicids2017/MachineLearningCSV/MachineLearningCSV/MachineLearningCVE/*.csv data/raw/CICIDS2017/
# !python -u kaggle_dual_gpu.py
# Out:
# Cloning into '/kaggle/working/mamba'...
# remote: Enumerating objects: 119, done.
# remote: Counting objects: 100% (119/119), done.
# remote: Compressing objects: 100% (90/90), done.
# remote: Total 119 (delta 23), reused 116 (delta 20), pack-reused 0 (from 0)
# Receiving objects: 100% (119/119), 124.32 KiB | 2.49 MiB/s, done.
# Resolving deltas: 100% (23/23), done.
# /kaggle/working/mamba
# Already up to date.
# 🔍 Detected 2 GPU(s):
#    GPU 0: Tesla T4 (15.6 GB)
#    GPU 1: Tesla T4 (15.6 GB)
#
# 🚀 Running on 2 GPUs in parallel!
#    GPU 0: Seeds [42, 123, 456]
#    GPU 1: Seeds [789, 1024]
# ============================================================
# ✅ GPU 0 started (PID 76) — seeds [42, 123, 456]
# ✅ GPU 1 started (PID 77) — seeds [789, 1024]
#
# ⏳ Both GPUs training in parallel — live output below:
#
# [GPU 0] ======================================================================
# [GPU 0] COMPREHENSIVE IDS BENCHMARK
# [GPU 0] ======================================================================
# [GPU 0] Datasets:  ['CICIDS2017']
# [GPU 0] Models:    ['Mamba', 'LSTM', 'GRU', 'Transformer', 'CNN-LSTM', 'TCN']
# [GPU 0] Seeds:     [42, 123, 456]
# [GPU 0] Device:    cuda
# [GPU 0] Epochs:    30
# [GPU 0] Batch:     128
# [GPU 0] Seq Len:   50
# [GPU 0] d_model:   128
# [GPU 0] n_layers:  2
# [GPU 0] ======================================================================
# [GPU 0]
# [GPU 0] [1/18] Running experiment...
# [GPU 0]
# [GPU 0] ======================================================================
# [GPU 0]   Dataset: CICIDS2017 | Model: Mamba | Seed: 42
# [GPU 0] ======================================================================
# [GPU 0] [Reproducibility] Setting all random seeds to 42
# [GPU 0] [Reproducibility] [OK] All seeds set and deterministic mode enabled
# [GPU 0] [1/5] Loading CICIDS2017 dataset...
# [GPU 1] ======================================================================
# [GPU 1] COMPREHENSIVE IDS BENCHMARK
# [GPU 1] ======================================================================
# [GPU 1] Datasets:  ['CICIDS2017']
# [GPU 1] Models:    ['Mamba', 'LSTM', 'GRU', 'Transformer', 'CNN-LSTM', 'TCN']
# [GPU 1] Seeds:     [789, 1024]
# [GPU 1] Device:    cuda
# [GPU 1] Epochs:    30
# [GPU 1] Batch:     128
# [GPU 1] Seq Len:   50
# [GPU 1] d_model:   128
# [GPU 1] n_layers:  2
# [GPU 0] [TRAIN] No cache found, parsing CSVs (this only happens once)...
# [GPU 1] ======================================================================
# [GPU 0] [TRAIN] Loading CICIDS2017 (4 files)...
# [GPU 1]
# [GPU 1] [1/12] Running experiment...
# [GPU 0] Files: ['Monday-WorkingHours.pcap_ISCX.csv', 'Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv', 'Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv', 'Friday-WorkingHours-Morning.pcap_ISCX.csv']
# [GPU 1]
# [GPU 1] ======================================================================
# [GPU 1]   Dataset: CICIDS2017 | Model: Mamba | Seed: 789
# [GPU 1] ======================================================================
# [GPU 1] [Reproducibility] Setting all random seeds to 789
# [GPU 0]  -> Processing Monday-WorkingHours.pcap_ISCX.csv...
# [GPU 1] [Reproducibility] [OK] All seeds set and deterministic mode enabled
# [GPU 1] [1/5] Loading CICIDS2017 dataset...
# [GPU 1] [TRAIN] No cache found, parsing CSVs (this only happens once)...
# [GPU 1] [TRAIN] Loading CICIDS2017 (4 files)...
# [GPU 1] Files: ['Monday-WorkingHours.pcap_ISCX.csv', 'Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv', 'Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv', 'Friday-WorkingHours-Morning.pcap_ISCX.csv']
# [GPU 1]  -> Processing Monday-WorkingHours.pcap_ISCX.csv...
# [GPU 1]  -> Processing Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv...
# [GPU 0]  -> Processing Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv...
# [GPU 1]  -> Processing Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv...
# [GPU 0]  -> Processing Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv...
# [GPU 1]  -> Processing Friday-WorkingHours-Morning.pcap_ISCX.csv...
# [GPU 0]  -> Processing Friday-WorkingHours-Morning.pcap_ISCX.csv...
# [GPU 1] Concatenating chunks...
# [GPU 1] Loaded 1233163 total rows.
# [GPU 1] Processing Labels...
# [GPU 0] Concatenating chunks...
# [GPU 0] Loaded 1233163 total rows.
# [GPU 0] Processing Labels...
# [GPU 1] Class Distribution: Benign=944240, Attack=288923
# [GPU 1] Converting to numpy arrays...
# [GPU 0] Class Distribution: Benign=944240, Attack=288923
# [GPU 1] Cleaning NaN/Inf values...
# [GPU 0] Converting to numpy arrays...
# [GPU 1] Total samples: 1233163
# [GPU 1] Train: 0-863214, Val: 863214-986530, Test: 986530-1233163
# [GPU 1] Saving cache to outputs/cache/cicids2017_train.npz...
# [GPU 0] Cleaning NaN/Inf values...
# [GPU 0] Total samples: 1233163
# [GPU 0] Train: 0-863214, Val: 863214-986530, Test: 986530-1233163
# [GPU 0] Saving cache to outputs/cache/cicids2017_train.npz...
# [GPU 1] [TRAIN] Raw shape (before windowing): (863214, 77)
# [GPU 1] [TRAIN] Raw shape (before windowing): (863214, 77)
# [GPU 1] Fitting StandardScaler on Train split...
# [GPU 0] [TRAIN] Raw shape (before windowing): (863214, 77)
# [GPU 0] [TRAIN] Raw shape (before windowing): (863214, 77)
# [GPU 0] Fitting StandardScaler on Train split...
# [GPU 1] Saved scaler to outputs/scaler_cicids.pkl
# [GPU 1] [OK] Will generate 863165 windows lazily during training
# [GPU 1] [VAL] No cache found, parsing CSVs (this only happens once)...
# [GPU 1] [VAL] Loading CICIDS2017 (4 files)...
# [GPU 1] Files: ['Monday-WorkingHours.pcap_ISCX.csv', 'Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv', 'Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv', 'Friday-WorkingHours-Morning.pcap_ISCX.csv']
# [GPU 1]  -> Processing Monday-WorkingHours.pcap_ISCX.csv...
# [GPU 0] Saved scaler to outputs/scaler_cicids.pkl
# [GPU 0] [OK] Will generate 863165 windows lazily during training
# [GPU 0] [VAL] No cache found, parsing CSVs (this only happens once)...
# [GPU 0] [VAL] Loading CICIDS2017 (4 files)...
# [GPU 0] Files: ['Monday-WorkingHours.pcap_ISCX.csv', 'Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv', 'Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv', 'Friday-WorkingHours-Morning.pcap_ISCX.csv']
# [GPU 0]  -> Processing Monday-WorkingHours.pcap_ISCX.csv...
# [GPU 1]  -> Processing Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv...
# [GPU 0]  -> Processing Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv...
# [GPU 1]  -> Processing Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv...
# [GPU 0]  -> Processing Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv...
# [GPU 1]  -> Processing Friday-WorkingHours-Morning.pcap_ISCX.csv...
# [GPU 0]  -> Processing Friday-WorkingHours-Morning.pcap_ISCX.csv...
# [GPU 1] Concatenating chunks...
# [GPU 1] Loaded 1233163 total rows.
# [GPU 1] Processing Labels...
# [GPU 0] Concatenating chunks...
# [GPU 1] Class Distribution: Benign=944240, Attack=288923
# [GPU 0] Loaded 1233163 total rows.
# [GPU 0] Processing Labels...
# [GPU 1] Converting to numpy arrays...
# [GPU 1] Cleaning NaN/Inf values...
# [GPU 0] Class Distribution: Benign=944240, Attack=288923
# [GPU 1] Total samples: 1233163
# [GPU 1] Train: 0-863214, Val: 863214-986530, Test: 986530-1233163
# [GPU 1] Saving cache to outputs/cache/cicids2017_val.npz...
# [GPU 0] Converting to numpy arrays...
# [GPU 0] Cleaning NaN/Inf values...
# [GPU 1] [VAL] Raw shape (before windowing): (123316, 77)
# [GPU 1] [VAL] Raw shape (before windowing): (123316, 77)
# [GPU 1] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 1] [OK] Will generate 123267 windows lazily during training
# [GPU 1] [TEST] No cache found, parsing CSVs (this only happens once)...
# [GPU 1] [TEST] Loading CICIDS2017 (4 files)...
# [GPU 1] Files: ['Monday-WorkingHours.pcap_ISCX.csv', 'Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv', 'Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv', 'Friday-WorkingHours-Morning.pcap_ISCX.csv']
# [GPU 1]  -> Processing Monday-WorkingHours.pcap_ISCX.csv...
# [GPU 0] Total samples: 1233163
# [GPU 0] Train: 0-863214, Val: 863214-986530, Test: 986530-1233163
# [GPU 0] Saving cache to outputs/cache/cicids2017_val.npz...
# [GPU 0] [VAL] Raw shape (before windowing): (123316, 77)
# [GPU 0] [VAL] Raw shape (before windowing): (123316, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 123267 windows lazily during training
# [GPU 0] [TEST] No cache found, parsing CSVs (this only happens once)...
# [GPU 0] [TEST] Loading CICIDS2017 (4 files)...
# [GPU 0] Files: ['Monday-WorkingHours.pcap_ISCX.csv', 'Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv', 'Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv', 'Friday-WorkingHours-Morning.pcap_ISCX.csv']
# [GPU 0]  -> Processing Monday-WorkingHours.pcap_ISCX.csv...
# [GPU 1]  -> Processing Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv...
# [GPU 0]  -> Processing Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv...
# [GPU 1]  -> Processing Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv...
# [GPU 0]  -> Processing Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv...
# [GPU 1]  -> Processing Friday-WorkingHours-Morning.pcap_ISCX.csv...
# [GPU 0]  -> Processing Friday-WorkingHours-Morning.pcap_ISCX.csv...
# [GPU 1] Concatenating chunks...
# [GPU 1] Loaded 1233163 total rows.
# [GPU 1] Processing Labels...
# [GPU 0] Concatenating chunks...
# [GPU 0] Loaded 1233163 total rows.
# [GPU 0] Processing Labels...
# [GPU 1] Class Distribution: Benign=944240, Attack=288923
# [GPU 1] Converting to numpy arrays...
# [GPU 0] Class Distribution: Benign=944240, Attack=288923
# [GPU 1] Cleaning NaN/Inf values...
# [GPU 1] Total samples: 1233163
# [GPU 1] Train: 0-863214, Val: 863214-986530, Test: 986530-1233163
# [GPU 0] Converting to numpy arrays...
# [GPU 1] Saving cache to outputs/cache/cicids2017_test.npz...
# [GPU 0] Cleaning NaN/Inf values...
# [GPU 0] Total samples: 1233163
# [GPU 0] Train: 0-863214, Val: 863214-986530, Test: 986530-1233163
# [GPU 0] Saving cache to outputs/cache/cicids2017_test.npz...
# [GPU 1] [TEST] Raw shape (before windowing): (246633, 77)
# [GPU 1] [TEST] Raw shape (before windowing): (246633, 77)
# [GPU 1] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 1] [OK] Will generate 246584 windows lazily during training
# [GPU 1]   Features: 77, Train: 863165, Val: 123267, Test: 246584
# [GPU 1] [2/5] Initializing Mamba (d_model=128, n_layers=2)...
# [GPU 1]   Parameters: 387,073
# [GPU 0] [TEST] Raw shape (before windowing): (246633, 77)
# [GPU 0] [TEST] Raw shape (before windowing): (246633, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 1] [3/5] Training Mamba...
# [GPU 0] [OK] Will generate 246584 windows lazily during training
# [GPU 0]   Features: 77, Train: 863165, Val: 123267, Test: 246584
# [GPU 0] [2/5] Initializing Mamba (d_model=128, n_layers=2)...
# [GPU 0]   Parameters: 387,073
# [GPU 0] [3/5] Training Mamba...
# [GPU 1]   Using class-weighted loss (pos_weight=1.00)
# [GPU 0]   Using class-weighted loss (pos_weight=1.00)
# [GPU 1]   Epoch   1/30 | TrLoss: 0.1562 | VlLoss: 0.1865 | VlAcc: 0.9642 | VlF1: 0.9818 *
# [GPU 0]   Epoch   1/30 | TrLoss: 0.0624 | VlLoss: 0.1726 | VlAcc: 0.9649 | VlF1: 0.9821 *
# [GPU 1]   Epoch   2/30 | TrLoss: 0.0381 | VlLoss: 0.1742 | VlAcc: 0.9642 | VlF1: 0.9818 *
# [GPU 0]   Epoch   2/30 | TrLoss: 0.0466 | VlLoss: 0.0287 | VlAcc: 0.9943 | VlF1: 0.9971 *
# [GPU 1]   Epoch   3/30 | TrLoss: 0.1098 | VlLoss: 0.1818 | VlAcc: 0.9643 | VlF1: 0.9818 *
# [GPU 0]   Epoch   3/30 | TrLoss: 0.0316 | VlLoss: 0.0329 | VlAcc: 0.9926 | VlF1: 0.9961
# [GPU 1]   Epoch   4/30 | TrLoss: 0.0477 | VlLoss: 0.1715 | VlAcc: 0.9660 | VlF1: 0.9826 *
# [GPU 0]   Epoch   4/30 | TrLoss: 0.0092 | VlLoss: 0.0151 | VlAcc: 0.9960 | VlF1: 0.9979 *
# [GPU 1]   Epoch   5/30 | TrLoss: 0.0368 | VlLoss: 0.1361 | VlAcc: 0.9641 | VlF1: 0.9817
# [GPU 0]   Epoch   5/30 | TrLoss: 0.0058 | VlLoss: 0.0971 | VlAcc: 0.9715 | VlF1: 0.9853
# [GPU 0]   Epoch   6/30 | TrLoss: nan | VlLoss: nan | VlAcc: 0.0358 | VlF1: 0.0000
# [GPU 1]   Epoch   6/30 | TrLoss: 0.0368 | VlLoss: 0.1752 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 0]   Epoch   7/30 | TrLoss: nan | VlLoss: nan | VlAcc: 0.0358 | VlF1: 0.0000
# [GPU 1]   Epoch   7/30 | TrLoss: 0.1821 | VlLoss: 0.1727 | VlAcc: 0.9645 | VlF1: 0.9819
# [GPU 0]   Epoch   8/30 | TrLoss: nan | VlLoss: nan | VlAcc: 0.0358 | VlF1: 0.0000
# [GPU 1]   Epoch   8/30 | TrLoss: nan | VlLoss: nan | VlAcc: 0.0358 | VlF1: 0.0000
# [GPU 0]   Epoch   9/30 | TrLoss: nan | VlLoss: nan | VlAcc: 0.0358 | VlF1: 0.0000
# [GPU 0]   Early stopping at epoch 9 (patience=5)
# [GPU 0]   Best Val F1: 0.9979 (9 epochs, 5938.1s)
# [GPU 0]   💾 Model saved to: outputs/checkpoints/CICIDS2017_Mamba_seed42.pt
# [GPU 0] [4/5] Evaluating on test set...
# [GPU 1]   Epoch   9/30 | TrLoss: nan | VlLoss: nan | VlAcc: 0.0358 | VlF1: 0.0000
# [GPU 1]   Early stopping at epoch 9 (patience=5)
# [GPU 1]   Best Val F1: 0.9826 (9 epochs, 5940.6s)
# [GPU 1]   💾 Model saved to: outputs/checkpoints/CICIDS2017_Mamba_seed789.pt
# [GPU 1] [4/5] Evaluating on test set...
# [GPU 0]   Test Acc: 0.9877 | Prec: 0.9472 | Rec: 0.9136 | F1: 0.9301 | AUC: 0.9823
# [GPU 0] [5/5] Measuring efficiency...
# [GPU 1]   Test Acc: 0.1711 | Prec: 0.0969 | Rec: 0.9953 | F1: 0.1767 | AUC: 0.3791
# [GPU 1] [5/5] Measuring efficiency...
# [GPU 0]   Latency: 14.00ms | Throughput: 2246/s | Memory: 1.48MB
# [GPU 1]   Latency: 14.78ms | Throughput: 2143/s | Memory: 1.48MB
# [GPU 0]   Attack types analyzed: 3
# [GPU 0]
# [GPU 0] [2/18] Running experiment...
# [GPU 0]
# [GPU 0] ======================================================================
# [GPU 0]   Dataset: CICIDS2017 | Model: LSTM | Seed: 42
# [GPU 0] ======================================================================
# [GPU 0] [Reproducibility] Setting all random seeds to 42
# [GPU 0] [Reproducibility] [OK] All seeds set and deterministic mode enabled
# [GPU 0] [1/5] Loading CICIDS2017 dataset...
# [GPU 0] [TRAIN] Loading from cache: outputs/cache/cicids2017_train.npz
# [GPU 0]   Cached shape: (863214, 77), labels: 863214
# [GPU 0] [TRAIN] Raw shape (before windowing): (863214, 77)
# [GPU 0] Fitting StandardScaler on Train split...
# [GPU 1]   Attack types analyzed: 3
# [GPU 1]
# [GPU 1] [2/12] Running experiment...
# [GPU 1]
# [GPU 1] ======================================================================
# [GPU 1]   Dataset: CICIDS2017 | Model: LSTM | Seed: 789
# [GPU 1] ======================================================================
# [GPU 1] [Reproducibility] Setting all random seeds to 789
# [GPU 1] [Reproducibility] [OK] All seeds set and deterministic mode enabled
# [GPU 1] [1/5] Loading CICIDS2017 dataset...
# [GPU 1] [TRAIN] Loading from cache: outputs/cache/cicids2017_train.npz
# [GPU 0] Saved scaler to outputs/scaler_cicids.pkl
# [GPU 0] [OK] Will generate 863165 windows lazily during training
# [GPU 0] [VAL] Loading from cache: outputs/cache/cicids2017_val.npz
# [GPU 0]   Cached shape: (123316, 77), labels: 123316
# [GPU 0] [VAL] Raw shape (before windowing): (123316, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 123267 windows lazily during training
# [GPU 0] [TEST] Loading from cache: outputs/cache/cicids2017_test.npz
# [GPU 0]   Cached shape: (246633, 77), labels: 246633
# [GPU 0] [TEST] Raw shape (before windowing): (246633, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 246584 windows lazily during training
# [GPU 0]   Features: 77, Train: 863165, Val: 123267, Test: 246584
# [GPU 0] [2/5] Initializing LSTM (d_model=128, n_layers=2)...
# [GPU 0]   Parameters: 423,169
# [GPU 0] [3/5] Training LSTM...
# [GPU 0]   Using class-weighted loss (pos_weight=1.00)
# [GPU 1]   Cached shape: (863214, 77), labels: 863214
# [GPU 1] [TRAIN] Raw shape (before windowing): (863214, 77)
# [GPU 1] Fitting StandardScaler on Train split...
# [GPU 1] Saved scaler to outputs/scaler_cicids.pkl
# [GPU 1] [OK] Will generate 863165 windows lazily during training
# [GPU 1] [VAL] Loading from cache: outputs/cache/cicids2017_val.npz
# [GPU 1]   Cached shape: (123316, 77), labels: 123316
# [GPU 1] [VAL] Raw shape (before windowing): (123316, 77)
# [GPU 1] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 1] [OK] Will generate 123267 windows lazily during training
# [GPU 1] [TEST] Loading from cache: outputs/cache/cicids2017_test.npz
# [GPU 1]   Cached shape: (246633, 77), labels: 246633
# [GPU 1] [TEST] Raw shape (before windowing): (246633, 77)
# [GPU 1] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 1] [OK] Will generate 246584 windows lazily during training
# [GPU 1]   Features: 77, Train: 863165, Val: 123267, Test: 246584
# [GPU 1] [2/5] Initializing LSTM (d_model=128, n_layers=2)...
# [GPU 1]   Parameters: 423,169
# [GPU 1] [3/5] Training LSTM...
# [GPU 1]   Using class-weighted loss (pos_weight=1.00)
# [GPU 0]   Epoch   1/30 | TrLoss: 0.1729 | VlLoss: 0.1867 | VlAcc: 0.9642 | VlF1: 0.9818 *
# [GPU 1]   Epoch   1/30 | TrLoss: 0.0509 | VlLoss: 0.1827 | VlAcc: 0.9642 | VlF1: 0.9818 *
# [GPU 0]   Epoch   2/30 | TrLoss: 0.0347 | VlLoss: 0.1805 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 1]   Epoch   2/30 | TrLoss: 0.0345 | VlLoss: 0.1805 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 0]   Epoch   3/30 | TrLoss: 0.0398 | VlLoss: 0.1834 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 1]   Epoch   3/30 | TrLoss: 0.0336 | VlLoss: 0.1782 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 1]   Epoch   4/30 | TrLoss: 0.0418 | VlLoss: 0.1709 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 0]   Epoch   4/30 | TrLoss: 0.0391 | VlLoss: 0.1789 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 1]   Epoch   5/30 | TrLoss: 0.0290 | VlLoss: 0.1869 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 0]   Epoch   5/30 | TrLoss: 0.0375 | VlLoss: 0.0728 | VlAcc: 0.9831 | VlF1: 0.9913 *
# [GPU 1]   Epoch   6/30 | TrLoss: 0.0243 | VlLoss: 0.0575 | VlAcc: 0.9886 | VlF1: 0.9941 *
# [GPU 0]   Epoch   6/30 | TrLoss: 0.0082 | VlLoss: 0.0321 | VlAcc: 0.9932 | VlF1: 0.9965 *
# [GPU 1]   Epoch   7/30 | TrLoss: 0.0053 | VlLoss: 0.0221 | VlAcc: 0.9957 | VlF1: 0.9978 *
# [GPU 0]   Epoch   7/30 | TrLoss: 0.0045 | VlLoss: 0.0210 | VlAcc: 0.9956 | VlF1: 0.9977 *
# [GPU 1]   Epoch   8/30 | TrLoss: 0.0020 | VlLoss: 0.0191 | VlAcc: 0.9965 | VlF1: 0.9982 *
# [GPU 0]   Epoch   8/30 | TrLoss: 0.0026 | VlLoss: 0.0155 | VlAcc: 0.9969 | VlF1: 0.9984 *
# [GPU 1]   Epoch   9/30 | TrLoss: 0.0014 | VlLoss: 0.0158 | VlAcc: 0.9967 | VlF1: 0.9983 *
# [GPU 0]   Epoch   9/30 | TrLoss: 0.0017 | VlLoss: 0.0181 | VlAcc: 0.9963 | VlF1: 0.9981
# [GPU 1]   Epoch  10/30 | TrLoss: 0.0013 | VlLoss: 0.0170 | VlAcc: 0.9960 | VlF1: 0.9979
# [GPU 0]   Epoch  10/30 | TrLoss: 0.0014 | VlLoss: 0.0193 | VlAcc: 0.9952 | VlF1: 0.9975
# [GPU 1]   Epoch  11/30 | TrLoss: 0.0011 | VlLoss: 0.0190 | VlAcc: 0.9961 | VlF1: 0.9980
# [GPU 0]   Epoch  11/30 | TrLoss: 0.0012 | VlLoss: 0.0200 | VlAcc: 0.9963 | VlF1: 0.9981
# [GPU 1]   Epoch  12/30 | TrLoss: 0.0012 | VlLoss: 0.0197 | VlAcc: 0.9961 | VlF1: 0.9980
# [GPU 0]   Epoch  12/30 | TrLoss: 0.0010 | VlLoss: 0.0235 | VlAcc: 0.9957 | VlF1: 0.9978
# [GPU 1]   Epoch  13/30 | TrLoss: 0.0008 | VlLoss: 0.0252 | VlAcc: 0.9951 | VlF1: 0.9975
# [GPU 0]   Epoch  13/30 | TrLoss: 0.0009 | VlLoss: 0.0248 | VlAcc: 0.9950 | VlF1: 0.9974
# [GPU 0]   Early stopping at epoch 13 (patience=5)
# [GPU 0]   Best Val F1: 0.9984 (13 epochs, 1105.7s)
# [GPU 0]   💾 Model saved to: outputs/checkpoints/CICIDS2017_LSTM_seed42.pt
# [GPU 0] [4/5] Evaluating on test set...
# [GPU 0]   Test Acc: 0.9913 | Prec: 0.9903 | Rec: 0.9119 | F1: 0.9495 | AUC: 0.9873
# [GPU 0] [5/5] Measuring efficiency...
# [GPU 0]   Latency: 0.77ms | Throughput: 30418/s | Memory: 1.61MB
# [GPU 0]   Attack types analyzed: 3
# [GPU 0]
# [GPU 0] [3/18] Running experiment...
# [GPU 0]
# [GPU 0] ======================================================================
# [GPU 0]   Dataset: CICIDS2017 | Model: GRU | Seed: 42
# [GPU 0] ======================================================================
# [GPU 0] [Reproducibility] Setting all random seeds to 42
# [GPU 0] [Reproducibility] [OK] All seeds set and deterministic mode enabled
# [GPU 0] [1/5] Loading CICIDS2017 dataset...
# [GPU 0] [TRAIN] Loading from cache: outputs/cache/cicids2017_train.npz
# [GPU 0]   Cached shape: (863214, 77), labels: 863214
# [GPU 0] [TRAIN] Raw shape (before windowing): (863214, 77)
# [GPU 0] Fitting StandardScaler on Train split...
# [GPU 0] Saved scaler to outputs/scaler_cicids.pkl
# [GPU 0] [OK] Will generate 863165 windows lazily during training
# [GPU 0] [VAL] Loading from cache: outputs/cache/cicids2017_val.npz
# [GPU 0]   Cached shape: (123316, 77), labels: 123316
# [GPU 0] [VAL] Raw shape (before windowing): (123316, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 123267 windows lazily during training
# [GPU 0] [TEST] Loading from cache: outputs/cache/cicids2017_test.npz
# [GPU 0]   Cached shape: (246633, 77), labels: 246633
# [GPU 0] [TEST] Raw shape (before windowing): (246633, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 246584 windows lazily during training
# [GPU 0]   Features: 77, Train: 863165, Val: 123267, Test: 246584
# [GPU 0] [2/5] Initializing GRU (d_model=128, n_layers=2)...
# [GPU 0]   Parameters: 373,505
# [GPU 0] [3/5] Training GRU...
# [GPU 0]   Using class-weighted loss (pos_weight=1.00)
# [GPU 1]   Epoch  14/30 | TrLoss: 0.0006 | VlLoss: 0.0236 | VlAcc: 0.9965 | VlF1: 0.9982
# [GPU 1]   Early stopping at epoch 14 (patience=5)
# [GPU 1]   Best Val F1: 0.9983 (14 epochs, 1183.9s)
# [GPU 1]   💾 Model saved to: outputs/checkpoints/CICIDS2017_LSTM_seed789.pt
# [GPU 1] [4/5] Evaluating on test set...
# [GPU 1]   Test Acc: 0.9912 | Prec: 0.9974 | Rec: 0.9044 | F1: 0.9486 | AUC: 0.9949
# [GPU 1] [5/5] Measuring efficiency...
# [GPU 1]   Latency: 0.76ms | Throughput: 30970/s | Memory: 1.61MB
# [GPU 0]   Epoch   1/30 | TrLoss: 0.2477 | VlLoss: 0.1839 | VlAcc: 0.9642 | VlF1: 0.9818 *
# [GPU 1]   Attack types analyzed: 3
# [GPU 1]
# [GPU 1] [3/12] Running experiment...
# [GPU 1]
# [GPU 1] ======================================================================
# [GPU 1]   Dataset: CICIDS2017 | Model: GRU | Seed: 789
# [GPU 1] ======================================================================
# [GPU 1] [Reproducibility] Setting all random seeds to 789
# [GPU 1] [Reproducibility] [OK] All seeds set and deterministic mode enabled
# [GPU 1] [1/5] Loading CICIDS2017 dataset...
# [GPU 1] [TRAIN] Loading from cache: outputs/cache/cicids2017_train.npz
# [GPU 1]   Cached shape: (863214, 77), labels: 863214
# [GPU 1] [TRAIN] Raw shape (before windowing): (863214, 77)
# [GPU 1] Fitting StandardScaler on Train split...
# [GPU 1] Saved scaler to outputs/scaler_cicids.pkl
# [GPU 1] [OK] Will generate 863165 windows lazily during training
# [GPU 1] [VAL] Loading from cache: outputs/cache/cicids2017_val.npz
# [GPU 1]   Cached shape: (123316, 77), labels: 123316
# [GPU 1] [VAL] Raw shape (before windowing): (123316, 77)
# [GPU 1] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 1] [OK] Will generate 123267 windows lazily during training
# [GPU 1] [TEST] Loading from cache: outputs/cache/cicids2017_test.npz
# [GPU 1]   Cached shape: (246633, 77), labels: 246633
# [GPU 1] [TEST] Raw shape (before windowing): (246633, 77)
# [GPU 1] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 1] [OK] Will generate 246584 windows lazily during training
# [GPU 1]   Features: 77, Train: 863165, Val: 123267, Test: 246584
# [GPU 1] [2/5] Initializing GRU (d_model=128, n_layers=2)...
# [GPU 1]   Parameters: 373,505
# [GPU 1] [3/5] Training GRU...
# [GPU 1]   Using class-weighted loss (pos_weight=1.00)
# [GPU 0]   Epoch   2/30 | TrLoss: 0.0350 | VlLoss: 0.1779 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 1]   Epoch   1/30 | TrLoss: 0.0441 | VlLoss: 0.1823 | VlAcc: 0.9642 | VlF1: 0.9818 *
# [GPU 0]   Epoch   3/30 | TrLoss: 0.0304 | VlLoss: 0.0960 | VlAcc: 0.9853 | VlF1: 0.9924 *
# [GPU 1]   Epoch   2/30 | TrLoss: 0.0425 | VlLoss: 0.1799 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 0]   Epoch   4/30 | TrLoss: 0.0253 | VlLoss: 0.1789 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 1]   Epoch   3/30 | TrLoss: 0.0437 | VlLoss: 0.1814 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 0]   Epoch   5/30 | TrLoss: 0.0321 | VlLoss: 0.1799 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 1]   Epoch   4/30 | TrLoss: 0.0335 | VlLoss: 0.1821 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 0]   Epoch   6/30 | TrLoss: 0.0225 | VlLoss: 0.1419 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 1]   Epoch   5/30 | TrLoss: 0.0408 | VlLoss: 0.1838 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 0]   Epoch   7/30 | TrLoss: 0.0101 | VlLoss: 0.0434 | VlAcc: 0.9870 | VlF1: 0.9933 *
# [GPU 1]   Epoch   6/30 | TrLoss: 0.0222 | VlLoss: 0.1312 | VlAcc: 0.9729 | VlF1: 0.9861 *
# [GPU 0]   Epoch   8/30 | TrLoss: 0.0043 | VlLoss: 0.0270 | VlAcc: 0.9910 | VlF1: 0.9953 *
# [GPU 1]   Epoch   7/30 | TrLoss: 0.0090 | VlLoss: 0.1191 | VlAcc: 0.9733 | VlF1: 0.9863 *
# [GPU 0]   Epoch   9/30 | TrLoss: 0.0028 | VlLoss: 0.0129 | VlAcc: 0.9969 | VlF1: 0.9984 *
# [GPU 1]   Epoch   8/30 | TrLoss: 0.0038 | VlLoss: 0.0199 | VlAcc: 0.9963 | VlF1: 0.9981 *
# [GPU 0]   Epoch  10/30 | TrLoss: 0.0027 | VlLoss: 0.0143 | VlAcc: 0.9969 | VlF1: 0.9984 *
# [GPU 1]   Epoch   9/30 | TrLoss: 0.0022 | VlLoss: 0.0239 | VlAcc: 0.9945 | VlF1: 0.9972
# [GPU 0]   Epoch  11/30 | TrLoss: 0.0016 | VlLoss: 0.0175 | VlAcc: 0.9968 | VlF1: 0.9983
# [GPU 1]   Epoch  10/30 | TrLoss: 0.0016 | VlLoss: 0.0233 | VlAcc: 0.9950 | VlF1: 0.9974
# [GPU 0]   Epoch  12/30 | TrLoss: 0.0013 | VlLoss: 0.0147 | VlAcc: 0.9971 | VlF1: 0.9985 *
# [GPU 1]   Epoch  11/30 | TrLoss: 0.0015 | VlLoss: 0.0261 | VlAcc: 0.9921 | VlF1: 0.9959
# [GPU 0]   Epoch  13/30 | TrLoss: 0.0014 | VlLoss: 0.0121 | VlAcc: 0.9971 | VlF1: 0.9985 *
# [GPU 1]   Epoch  12/30 | TrLoss: 0.0013 | VlLoss: 0.0900 | VlAcc: 0.9681 | VlF1: 0.9832
# [GPU 0]   Epoch  14/30 | TrLoss: 0.0009 | VlLoss: 0.0158 | VlAcc: 0.9968 | VlF1: 0.9983
# [GPU 1]   Epoch  13/30 | TrLoss: 0.0008 | VlLoss: 0.1089 | VlAcc: 0.9680 | VlF1: 0.9831
# [GPU 1]   Early stopping at epoch 13 (patience=5)
# [GPU 1]   Best Val F1: 0.9981 (13 epochs, 906.5s)
# [GPU 1]   💾 Model saved to: outputs/checkpoints/CICIDS2017_GRU_seed789.pt
# [GPU 1] [4/5] Evaluating on test set...
# [GPU 1]   Test Acc: 0.9906 | Prec: 0.9709 | Rec: 0.9225 | F1: 0.9461 | AUC: 0.9796
# [GPU 1] [5/5] Measuring efficiency...
# [GPU 1]   Latency: 0.50ms | Throughput: 43815/s | Memory: 1.42MB
# [GPU 1]   Attack types analyzed: 3
# [GPU 1]
# [GPU 1] [4/12] Running experiment...
# [GPU 1]
# [GPU 1] ======================================================================
# [GPU 1]   Dataset: CICIDS2017 | Model: Transformer | Seed: 789
# [GPU 1] ======================================================================
# [GPU 1] [Reproducibility] Setting all random seeds to 789
# [GPU 1] [Reproducibility] [OK] All seeds set and deterministic mode enabled
# [GPU 1] [1/5] Loading CICIDS2017 dataset...
# [GPU 1] [TRAIN] Loading from cache: outputs/cache/cicids2017_train.npz
# [GPU 1]   Cached shape: (863214, 77), labels: 863214
# [GPU 1] [TRAIN] Raw shape (before windowing): (863214, 77)
# [GPU 1] Fitting StandardScaler on Train split...
# [GPU 1] Saved scaler to outputs/scaler_cicids.pkl
# [GPU 1] [OK] Will generate 863165 windows lazily during training
# [GPU 1] [VAL] Loading from cache: outputs/cache/cicids2017_val.npz
# [GPU 1]   Cached shape: (123316, 77), labels: 123316
# [GPU 1] [VAL] Raw shape (before windowing): (123316, 77)
# [GPU 1] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 1] [OK] Will generate 123267 windows lazily during training
# [GPU 1] [TEST] Loading from cache: outputs/cache/cicids2017_test.npz
# [GPU 1]   Cached shape: (246633, 77), labels: 246633
# [GPU 1] [TEST] Raw shape (before windowing): (246633, 77)
# [GPU 1] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 1] [OK] Will generate 246584 windows lazily during training
# [GPU 1]   Features: 77, Train: 863165, Val: 123267, Test: 246584
# [GPU 1] [2/5] Initializing Transformer (d_model=128, n_layers=2)...
# [GPU 1]   Parameters: 406,913
# [GPU 1] [3/5] Training Transformer...
# [GPU 1]   Using class-weighted loss (pos_weight=1.00)
# [GPU 0]   Epoch  15/30 | TrLoss: 0.0007 | VlLoss: 0.0244 | VlAcc: 0.9951 | VlF1: 0.9974
# [GPU 1]   Epoch   1/30 | TrLoss: 0.2164 | VlLoss: 0.1817 | VlAcc: 0.9642 | VlF1: 0.9818 *
# [GPU 0]   Epoch  16/30 | TrLoss: 0.0006 | VlLoss: 0.0324 | VlAcc: 0.9936 | VlF1: 0.9967
# [GPU 0]   Epoch  17/30 | TrLoss: 0.0004 | VlLoss: 0.0333 | VlAcc: 0.9945 | VlF1: 0.9971
# [GPU 1]   Epoch   2/30 | TrLoss: 0.0993 | VlLoss: 0.1826 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 0]   Epoch  18/30 | TrLoss: 0.0004 | VlLoss: 0.0554 | VlAcc: 0.9901 | VlF1: 0.9948
# [GPU 0]   Early stopping at epoch 18 (patience=5)
# [GPU 0]   Best Val F1: 0.9985 (18 epochs, 1271.0s)
# [GPU 0]   💾 Model saved to: outputs/checkpoints/CICIDS2017_GRU_seed42.pt
# [GPU 0] [4/5] Evaluating on test set...
# [GPU 0]   Test Acc: 0.9915 | Prec: 0.9923 | Rec: 0.9125 | F1: 0.9507 | AUC: 0.9851
# [GPU 0] [5/5] Measuring efficiency...
# [GPU 0]   Latency: 0.89ms | Throughput: 42320/s | Memory: 1.42MB
# [GPU 0]   Attack types analyzed: 3
# [GPU 0]
# [GPU 0] [4/18] Running experiment...
# [GPU 0]
# [GPU 0] ======================================================================
# [GPU 0]   Dataset: CICIDS2017 | Model: Transformer | Seed: 42
# [GPU 0] ======================================================================
# [GPU 0] [Reproducibility] Setting all random seeds to 42
# [GPU 0] [Reproducibility] [OK] All seeds set and deterministic mode enabled
# [GPU 0] [1/5] Loading CICIDS2017 dataset...
# [GPU 0] [TRAIN] Loading from cache: outputs/cache/cicids2017_train.npz
# [GPU 0]   Cached shape: (863214, 77), labels: 863214
# [GPU 0] [TRAIN] Raw shape (before windowing): (863214, 77)
# [GPU 0] Fitting StandardScaler on Train split...
# [GPU 0] Saved scaler to outputs/scaler_cicids.pkl
# [GPU 0] [OK] Will generate 863165 windows lazily during training
# [GPU 0] [VAL] Loading from cache: outputs/cache/cicids2017_val.npz
# [GPU 0]   Cached shape: (123316, 77), labels: 123316
# [GPU 0] [VAL] Raw shape (before windowing): (123316, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 123267 windows lazily during training
# [GPU 0] [TEST] Loading from cache: outputs/cache/cicids2017_test.npz
# [GPU 0]   Cached shape: (246633, 77), labels: 246633
# [GPU 0] [TEST] Raw shape (before windowing): (246633, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 246584 windows lazily during training
# [GPU 0]   Features: 77, Train: 863165, Val: 123267, Test: 246584
# [GPU 0] [2/5] Initializing Transformer (d_model=128, n_layers=2)...
# [GPU 0]   Parameters: 406,913
# [GPU 0] [3/5] Training Transformer...
# [GPU 0]   Using class-weighted loss (pos_weight=1.00)
# [GPU 1]   Epoch   3/30 | TrLoss: 0.0888 | VlLoss: 0.5361 | VlAcc: 0.8718 | VlF1: 0.9299
# [GPU 0]   Epoch   1/30 | TrLoss: 0.2346 | VlLoss: 0.1852 | VlAcc: 0.9642 | VlF1: 0.9818 *
# [GPU 1]   Epoch   4/30 | TrLoss: 0.0789 | VlLoss: 0.4441 | VlAcc: 0.8817 | VlF1: 0.9357
# [GPU 0]   Epoch   2/30 | TrLoss: 0.1278 | VlLoss: 0.1746 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 1]   Epoch   5/30 | TrLoss: 0.0549 | VlLoss: 0.4976 | VlAcc: 0.8962 | VlF1: 0.9440
# [GPU 0]   Epoch   3/30 | TrLoss: 0.0580 | VlLoss: 0.1907 | VlAcc: 0.9643 | VlF1: 0.9818 *
# [GPU 1]   Epoch   6/30 | TrLoss: 0.0268 | VlLoss: 0.5746 | VlAcc: 0.8650 | VlF1: 0.9257
# [GPU 1]   Early stopping at epoch 6 (patience=5)
# [GPU 1]   Best Val F1: 0.9818 (6 epochs, 612.3s)
# [GPU 1]   💾 Model saved to: outputs/checkpoints/CICIDS2017_Transformer_seed789.pt
# [GPU 1] [4/5] Evaluating on test set...
# [GPU 1]   Test Acc: 0.0893 | Prec: 0.0893 | Rec: 1.0000 | F1: 0.1640 | AUC: 0.7667
# [GPU 1] [5/5] Measuring efficiency...
# [GPU 1]   Latency: 2.01ms | Throughput: 16815/s | Memory: 1.55MB
# [GPU 1]   Attack types analyzed: 3
# [GPU 1]
# [GPU 1] [5/12] Running experiment...
# [GPU 1]
# [GPU 1] ======================================================================
# [GPU 1]   Dataset: CICIDS2017 | Model: CNN-LSTM | Seed: 789
# [GPU 1] ======================================================================
# [GPU 1] [Reproducibility] Setting all random seeds to 789
# [GPU 1] [Reproducibility] [OK] All seeds set and deterministic mode enabled
# [GPU 1] [1/5] Loading CICIDS2017 dataset...
# [GPU 1] [TRAIN] Loading from cache: outputs/cache/cicids2017_train.npz
# [GPU 1]   Cached shape: (863214, 77), labels: 863214
# [GPU 1] [TRAIN] Raw shape (before windowing): (863214, 77)
# [GPU 1] Fitting StandardScaler on Train split...
# [GPU 1] Saved scaler to outputs/scaler_cicids.pkl
# [GPU 1] [OK] Will generate 863165 windows lazily during training
# [GPU 1] [VAL] Loading from cache: outputs/cache/cicids2017_val.npz
# [GPU 1]   Cached shape: (123316, 77), labels: 123316
# [GPU 1] [VAL] Raw shape (before windowing): (123316, 77)
# [GPU 1] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 1] [OK] Will generate 123267 windows lazily during training
# [GPU 1] [TEST] Loading from cache: outputs/cache/cicids2017_test.npz
# [GPU 1]   Cached shape: (246633, 77), labels: 246633
# [GPU 1] [TEST] Raw shape (before windowing): (246633, 77)
# [GPU 1] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 1] [OK] Will generate 246584 windows lazily during training
# [GPU 1]   Features: 77, Train: 863165, Val: 123267, Test: 246584
# [GPU 1] [2/5] Initializing CNN-LSTM (d_model=128, n_layers=2)...
# [GPU 1]   Parameters: 409,601
# [GPU 1] [3/5] Training CNN-LSTM...
# [GPU 1]   Using class-weighted loss (pos_weight=1.00)
# [GPU 0]   Epoch   4/30 | TrLoss: 0.0648 | VlLoss: 0.1882 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 1]   Epoch   1/30 | TrLoss: 0.2512 | VlLoss: 0.1844 | VlAcc: 0.9642 | VlF1: 0.9818 *
# [GPU 0]   Epoch   5/30 | TrLoss: 0.0754 | VlLoss: 0.1859 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 1]   Epoch   2/30 | TrLoss: 0.0550 | VlLoss: 0.1817 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 0]   Epoch   6/30 | TrLoss: 0.0531 | VlLoss: 0.1858 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 1]   Epoch   3/30 | TrLoss: 0.0338 | VlLoss: 0.2927 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 1]   Epoch   4/30 | TrLoss: 0.0247 | VlLoss: 0.1568 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 0]   Epoch   7/30 | TrLoss: 0.0480 | VlLoss: 0.1878 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 1]   Epoch   5/30 | TrLoss: 0.0334 | VlLoss: 0.1902 | VlAcc: 0.9672 | VlF1: 0.9832 *
# [GPU 0]   Epoch   8/30 | TrLoss: 0.0668 | VlLoss: 0.1718 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 0]   Early stopping at epoch 8 (patience=5)
# [GPU 0]   Best Val F1: 0.9818 (8 epochs, 821.4s)
# [GPU 0]   💾 Model saved to: outputs/checkpoints/CICIDS2017_Transformer_seed42.pt
# [GPU 0] [4/5] Evaluating on test set...
# [GPU 0]   Test Acc: 0.0976 | Prec: 0.0900 | Rec: 0.9985 | F1: 0.1651 | AUC: 0.5754
# [GPU 0] [5/5] Measuring efficiency...
# [GPU 0]   Latency: 1.65ms | Throughput: 20345/s | Memory: 1.55MB
# [GPU 0]   Attack types analyzed: 3
# [GPU 0]
# [GPU 0] [5/18] Running experiment...
# [GPU 0]
# [GPU 0] ======================================================================
# [GPU 0]   Dataset: CICIDS2017 | Model: CNN-LSTM | Seed: 42
# [GPU 0] ======================================================================
# [GPU 0] [Reproducibility] Setting all random seeds to 42
# [GPU 0] [Reproducibility] [OK] All seeds set and deterministic mode enabled
# [GPU 0] [1/5] Loading CICIDS2017 dataset...
# [GPU 0] [TRAIN] Loading from cache: outputs/cache/cicids2017_train.npz
# [GPU 0]   Cached shape: (863214, 77), labels: 863214
# [GPU 0] [TRAIN] Raw shape (before windowing): (863214, 77)
# [GPU 0] Fitting StandardScaler on Train split...
# [GPU 0] Saved scaler to outputs/scaler_cicids.pkl
# [GPU 0] [OK] Will generate 863165 windows lazily during training
# [GPU 0] [VAL] Loading from cache: outputs/cache/cicids2017_val.npz
# [GPU 0]   Cached shape: (123316, 77), labels: 123316
# [GPU 0] [VAL] Raw shape (before windowing): (123316, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 123267 windows lazily during training
# [GPU 0] [TEST] Loading from cache: outputs/cache/cicids2017_test.npz
# [GPU 0]   Cached shape: (246633, 77), labels: 246633
# [GPU 0] [TEST] Raw shape (before windowing): (246633, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 246584 windows lazily during training
# [GPU 0]   Features: 77, Train: 863165, Val: 123267, Test: 246584
# [GPU 0] [2/5] Initializing CNN-LSTM (d_model=128, n_layers=2)...
# [GPU 0]   Parameters: 409,601
# [GPU 0] [3/5] Training CNN-LSTM...
# [GPU 0]   Using class-weighted loss (pos_weight=1.00)
# [GPU 1]   Epoch   6/30 | TrLoss: 0.0273 | VlLoss: 0.1371 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 0]   Epoch   1/30 | TrLoss: 0.2137 | VlLoss: 0.1841 | VlAcc: 0.9642 | VlF1: 0.9818 *
# [GPU 1]   Epoch   7/30 | TrLoss: 0.0171 | VlLoss: 0.0592 | VlAcc: 0.9915 | VlF1: 0.9956 *
# [GPU 0]   Epoch   2/30 | TrLoss: 0.0393 | VlLoss: 0.1790 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 1]   Epoch   8/30 | TrLoss: 0.0061 | VlLoss: 0.7121 | VlAcc: 0.6124 | VlF1: 0.7487
# [GPU 0]   Epoch   3/30 | TrLoss: 0.0385 | VlLoss: 0.1787 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 1]   Epoch   9/30 | TrLoss: 0.0021 | VlLoss: 0.3361 | VlAcc: 0.8325 | VlF1: 0.9049
# [GPU 0]   Epoch   4/30 | TrLoss: 0.0344 | VlLoss: 0.1717 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 1]   Epoch  10/30 | TrLoss: 0.0017 | VlLoss: 0.0814 | VlAcc: 0.9850 | VlF1: 0.9921
# [GPU 0]   Epoch   5/30 | TrLoss: 0.0363 | VlLoss: 0.1803 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 1]   Epoch  11/30 | TrLoss: 0.0013 | VlLoss: 0.2067 | VlAcc: 0.9770 | VlF1: 0.9879
# [GPU 0]   Epoch   6/30 | TrLoss: 0.0319 | VlLoss: 0.1618 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 0]   Early stopping at epoch 6 (patience=5)
# [GPU 0]   Best Val F1: 0.9818 (6 epochs, 512.9s)
# [GPU 0]   💾 Model saved to: outputs/checkpoints/CICIDS2017_CNN-LSTM_seed42.pt
# [GPU 0] [4/5] Evaluating on test set...
# [GPU 0]   Test Acc: 0.0893 | Prec: 0.0893 | Rec: 1.0000 | F1: 0.1640 | AUC: 0.1980
# [GPU 0] [5/5] Measuring efficiency...
# [GPU 0]   Latency: 0.94ms | Throughput: 33708/s | Memory: 1.56MB
# [GPU 0]   Attack types analyzed: 3
# [GPU 0]
# [GPU 0] [6/18] Running experiment...
# [GPU 0]
# [GPU 0] ======================================================================
# [GPU 0]   Dataset: CICIDS2017 | Model: TCN | Seed: 42
# [GPU 0] ======================================================================
# [GPU 0] [Reproducibility] Setting all random seeds to 42
# [GPU 0] [Reproducibility] [OK] All seeds set and deterministic mode enabled
# [GPU 0] [1/5] Loading CICIDS2017 dataset...
# [GPU 0] [TRAIN] Loading from cache: outputs/cache/cicids2017_train.npz
# [GPU 0]   Cached shape: (863214, 77), labels: 863214
# [GPU 0] [TRAIN] Raw shape (before windowing): (863214, 77)
# [GPU 0] Fitting StandardScaler on Train split...
# [GPU 0] Saved scaler to outputs/scaler_cicids.pkl
# [GPU 0] [OK] Will generate 863165 windows lazily during training
# [GPU 0] [VAL] Loading from cache: outputs/cache/cicids2017_val.npz
# [GPU 0]   Cached shape: (123316, 77), labels: 123316
# [GPU 0] [VAL] Raw shape (before windowing): (123316, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 123267 windows lazily during training
# [GPU 0] [TEST] Loading from cache: outputs/cache/cicids2017_test.npz
# [GPU 0]   Cached shape: (246633, 77), labels: 246633
# [GPU 0] [TEST] Raw shape (before windowing): (246633, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 246584 windows lazily during training
# [GPU 0]   Features: 77, Train: 863165, Val: 123267, Test: 246584
# [GPU 0] [2/5] Initializing TCN (d_model=128, n_layers=2)...
# [GPU 0]   Parameters: 423,169
# [GPU 0] [3/5] Training TCN...
# [GPU 0]   Using class-weighted loss (pos_weight=1.00)
# [GPU 1]   Epoch  12/30 | TrLoss: 0.0011 | VlLoss: 0.1090 | VlAcc: 0.9903 | VlF1: 0.9949
# [GPU 1]   Early stopping at epoch 12 (patience=5)
# [GPU 1]   Best Val F1: 0.9956 (12 epochs, 1043.9s)
# [GPU 1]   💾 Model saved to: outputs/checkpoints/CICIDS2017_CNN-LSTM_seed789.pt
# [GPU 1] [4/5] Evaluating on test set...
# [GPU 1]   Test Acc: 0.8786 | Prec: 0.4211 | Rec: 0.9567 | F1: 0.5848 | AUC: 0.9692
# [GPU 1] [5/5] Measuring efficiency...
# [GPU 1]   Latency: 0.89ms | Throughput: 33565/s | Memory: 1.56MB
# [GPU 1]   Attack types analyzed: 3
# [GPU 1]
# [GPU 1] [6/12] Running experiment...
# [GPU 1]
# [GPU 1] ======================================================================
# [GPU 1]   Dataset: CICIDS2017 | Model: TCN | Seed: 789
# [GPU 1] ======================================================================
# [GPU 1] [Reproducibility] Setting all random seeds to 789
# [GPU 1] [Reproducibility] [OK] All seeds set and deterministic mode enabled
# [GPU 1] [1/5] Loading CICIDS2017 dataset...
# [GPU 1] [TRAIN] Loading from cache: outputs/cache/cicids2017_train.npz
# [GPU 1]   Cached shape: (863214, 77), labels: 863214
# [GPU 1] [TRAIN] Raw shape (before windowing): (863214, 77)
# [GPU 1] Fitting StandardScaler on Train split...
# [GPU 1] Saved scaler to outputs/scaler_cicids.pkl
# [GPU 1] [OK] Will generate 863165 windows lazily during training
# [GPU 1] [VAL] Loading from cache: outputs/cache/cicids2017_val.npz
# [GPU 1]   Cached shape: (123316, 77), labels: 123316
# [GPU 1] [VAL] Raw shape (before windowing): (123316, 77)
# [GPU 1] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 1] [OK] Will generate 123267 windows lazily during training
# [GPU 1] [TEST] Loading from cache: outputs/cache/cicids2017_test.npz
# [GPU 1]   Cached shape: (246633, 77), labels: 246633
# [GPU 1] [TEST] Raw shape (before windowing): (246633, 77)
# [GPU 1] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 1] [OK] Will generate 246584 windows lazily during training
# [GPU 1]   Features: 77, Train: 863165, Val: 123267, Test: 246584
# [GPU 1] [2/5] Initializing TCN (d_model=128, n_layers=2)...
# [GPU 1]   Parameters: 423,169
# [GPU 1] [3/5] Training TCN...
# [GPU 1]   Using class-weighted loss (pos_weight=1.00)
# [GPU 0]   Epoch   1/30 | TrLoss: 0.0377 | VlLoss: 0.1176 | VlAcc: 0.9695 | VlF1: 0.9844 *
# [GPU 1]   Epoch   1/30 | TrLoss: 0.0340 | VlLoss: 0.0519 | VlAcc: 0.9848 | VlF1: 0.9921 *
# [GPU 0]   Epoch   2/30 | TrLoss: 0.0153 | VlLoss: 0.0438 | VlAcc: 0.9859 | VlF1: 0.9927 *
# [GPU 1]   Epoch   2/30 | TrLoss: 0.0115 | VlLoss: 0.0352 | VlAcc: 0.9896 | VlF1: 0.9946 *
# [GPU 0]   Epoch   3/30 | TrLoss: 0.0061 | VlLoss: 0.0316 | VlAcc: 0.9909 | VlF1: 0.9953 *
# [GPU 1]   Epoch   3/30 | TrLoss: 0.0062 | VlLoss: 0.0389 | VlAcc: 0.9882 | VlF1: 0.9939
# [GPU 0]   Epoch   4/30 | TrLoss: 0.0031 | VlLoss: 0.0281 | VlAcc: 0.9917 | VlF1: 0.9957 *
# [GPU 1]   Epoch   4/30 | TrLoss: 0.0033 | VlLoss: 0.0482 | VlAcc: 0.9816 | VlF1: 0.9905
# [GPU 0]   Epoch   5/30 | TrLoss: 0.0026 | VlLoss: 0.0318 | VlAcc: 0.9922 | VlF1: 0.9960 *
# [GPU 1]   Epoch   5/30 | TrLoss: 0.0025 | VlLoss: 0.0487 | VlAcc: 0.9886 | VlF1: 0.9941
# [GPU 0]   Epoch   6/30 | TrLoss: 0.0022 | VlLoss: 0.0454 | VlAcc: 0.9931 | VlF1: 0.9964 *
# [GPU 1]   Epoch   6/30 | TrLoss: 0.0021 | VlLoss: 0.0849 | VlAcc: 0.9863 | VlF1: 0.9929
# [GPU 0]   Epoch   7/30 | TrLoss: 0.0018 | VlLoss: 0.0366 | VlAcc: 0.9936 | VlF1: 0.9967 *
# [GPU 1]   Epoch   7/30 | TrLoss: 0.0016 | VlLoss: 0.2133 | VlAcc: 0.9839 | VlF1: 0.9917
# [GPU 1]   Early stopping at epoch 7 (patience=5)
# [GPU 1]   Best Val F1: 0.9946 (7 epochs, 764.1s)
# [GPU 1]   💾 Model saved to: outputs/checkpoints/CICIDS2017_TCN_seed789.pt
# [GPU 1] [4/5] Evaluating on test set...
# [GPU 1]   Test Acc: 0.9770 | Prec: 0.8336 | Rec: 0.9283 | F1: 0.8784 | AUC: 0.9773
# [GPU 1] [5/5] Measuring efficiency...
# [GPU 1]   Latency: 1.91ms | Throughput: 15873/s | Memory: 1.61MB
# [GPU 1]   Attack types analyzed: 3
# [GPU 1]
# [GPU 1] [7/12] Running experiment...
# [GPU 1]
# [GPU 1] ======================================================================
# [GPU 1]   Dataset: CICIDS2017 | Model: Mamba | Seed: 1024
# [GPU 1] ======================================================================
# [GPU 1] [Reproducibility] Setting all random seeds to 1024
# [GPU 1] [Reproducibility] [OK] All seeds set and deterministic mode enabled
# [GPU 1] [1/5] Loading CICIDS2017 dataset...
# [GPU 1] [TRAIN] Loading from cache: outputs/cache/cicids2017_train.npz
# [GPU 1]   Cached shape: (863214, 77), labels: 863214
# [GPU 1] [TRAIN] Raw shape (before windowing): (863214, 77)
# [GPU 1] Fitting StandardScaler on Train split...
# [GPU 1] Saved scaler to outputs/scaler_cicids.pkl
# [GPU 1] [OK] Will generate 863165 windows lazily during training
# [GPU 1] [VAL] Loading from cache: outputs/cache/cicids2017_val.npz
# [GPU 1]   Cached shape: (123316, 77), labels: 123316
# [GPU 1] [VAL] Raw shape (before windowing): (123316, 77)
# [GPU 1] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 1] [OK] Will generate 123267 windows lazily during training
# [GPU 1] [TEST] Loading from cache: outputs/cache/cicids2017_test.npz
# [GPU 1]   Cached shape: (246633, 77), labels: 246633
# [GPU 1] [TEST] Raw shape (before windowing): (246633, 77)
# [GPU 1] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 1] [OK] Will generate 246584 windows lazily during training
# [GPU 1]   Features: 77, Train: 863165, Val: 123267, Test: 246584
# [GPU 1] [2/5] Initializing Mamba (d_model=128, n_layers=2)...
# [GPU 1]   Parameters: 387,073
# [GPU 1] [3/5] Training Mamba...
# [GPU 1]   Using class-weighted loss (pos_weight=1.00)
# [GPU 0]   Epoch   8/30 | TrLoss: 0.0016 | VlLoss: 0.0351 | VlAcc: 0.9935 | VlF1: 0.9966
# [GPU 0]   Epoch   9/30 | TrLoss: 0.0016 | VlLoss: 0.0388 | VlAcc: 0.9901 | VlF1: 0.9949
# [GPU 0]   Epoch  10/30 | TrLoss: 0.0013 | VlLoss: 0.0498 | VlAcc: 0.9918 | VlF1: 0.9957
# [GPU 0]   Epoch  11/30 | TrLoss: 0.0012 | VlLoss: 0.0666 | VlAcc: 0.9923 | VlF1: 0.9960
# [GPU 0]   Epoch  12/30 | TrLoss: 0.0009 | VlLoss: 0.0695 | VlAcc: 0.9892 | VlF1: 0.9944
# [GPU 0]   Early stopping at epoch 12 (patience=5)
# [GPU 0]   Best Val F1: 0.9967 (12 epochs, 1312.0s)
# [GPU 0]   💾 Model saved to: outputs/checkpoints/CICIDS2017_TCN_seed42.pt
# [GPU 0] [4/5] Evaluating on test set...
# [GPU 0]   Test Acc: 0.8782 | Prec: 0.4203 | Rec: 0.9587 | F1: 0.5844 | AUC: 0.9729
# [GPU 0] [5/5] Measuring efficiency...
# [GPU 0]   Latency: 1.89ms | Throughput: 15120/s | Memory: 1.61MB
# [GPU 0]   Attack types analyzed: 3
# [GPU 0]
# [GPU 0] [7/18] Running experiment...
# [GPU 0]
# [GPU 0] ======================================================================
# [GPU 0]   Dataset: CICIDS2017 | Model: Mamba | Seed: 123
# [GPU 0] ======================================================================
# [GPU 0] [Reproducibility] Setting all random seeds to 123
# [GPU 0] [Reproducibility] [OK] All seeds set and deterministic mode enabled
# [GPU 0] [1/5] Loading CICIDS2017 dataset...
# [GPU 0] [TRAIN] Loading from cache: outputs/cache/cicids2017_train.npz
# [GPU 0]   Cached shape: (863214, 77), labels: 863214
# [GPU 0] [TRAIN] Raw shape (before windowing): (863214, 77)
# [GPU 0] Fitting StandardScaler on Train split...
# [GPU 0] Saved scaler to outputs/scaler_cicids.pkl
# [GPU 0] [OK] Will generate 863165 windows lazily during training
# [GPU 0] [VAL] Loading from cache: outputs/cache/cicids2017_val.npz
# [GPU 0]   Cached shape: (123316, 77), labels: 123316
# [GPU 0] [VAL] Raw shape (before windowing): (123316, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 123267 windows lazily during training
# [GPU 0] [TEST] Loading from cache: outputs/cache/cicids2017_test.npz
# [GPU 0]   Cached shape: (246633, 77), labels: 246633
# [GPU 0] [TEST] Raw shape (before windowing): (246633, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 246584 windows lazily during training
# [GPU 0]   Features: 77, Train: 863165, Val: 123267, Test: 246584
# [GPU 0] [2/5] Initializing Mamba (d_model=128, n_layers=2)...
# [GPU 0]   Parameters: 387,073
# [GPU 0] [3/5] Training Mamba...
# [GPU 0]   Using class-weighted loss (pos_weight=1.00)
# [GPU 1]   Epoch   1/30 | TrLoss: 0.1775 | VlLoss: 0.1708 | VlAcc: 0.9650 | VlF1: 0.9822 *
# [GPU 0]   Epoch   1/30 | TrLoss: 0.0852 | VlLoss: 0.1173 | VlAcc: 0.9766 | VlF1: 0.9880 *
# [GPU 1]   Epoch   2/30 | TrLoss: 0.1125 | VlLoss: 0.1522 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 0]   Epoch   2/30 | TrLoss: 0.0322 | VlLoss: 0.1538 | VlAcc: 0.9633 | VlF1: 0.9813
# [GPU 1]   Epoch   3/30 | TrLoss: 0.0381 | VlLoss: 0.1335 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 0]   Epoch   3/30 | TrLoss: 0.0344 | VlLoss: 0.1747 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 1]   Epoch   4/30 | TrLoss: 0.0352 | VlLoss: 0.1829 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 0]   Epoch   4/30 | TrLoss: 0.0342 | VlLoss: 0.1601 | VlAcc: 0.9604 | VlF1: 0.9796
# [GPU 1]   Epoch   5/30 | TrLoss: 0.0506 | VlLoss: 0.1878 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 0]   Epoch   5/30 | TrLoss: 0.0394 | VlLoss: 0.1689 | VlAcc: 0.9670 | VlF1: 0.9832
# [GPU 1]   Epoch   6/30 | TrLoss: 0.0379 | VlLoss: 0.1870 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 1]   Early stopping at epoch 6 (patience=5)
# [GPU 1]   Best Val F1: 0.9822 (6 epochs, 4002.0s)
# ...
# [GPU 0] [Reproducibility] [OK] All seeds set and deterministic mode enabled
# [GPU 0] [1/5] Loading CICIDS2017 dataset...
# [GPU 0] [TRAIN] Loading from cache: outputs/cache/cicids2017_train.npz
# [GPU 0]   Cached shape: (863214, 77), labels: 863214
# [GPU 0] [TRAIN] Raw shape (before windowing): (863214, 77)
# [GPU 0] Fitting StandardScaler on Train split...
# [GPU 0] Saved scaler to outputs/scaler_cicids.pkl
# [GPU 0] [OK] Will generate 863165 windows lazily during training
# [GPU 0] [VAL] Loading from cache: outputs/cache/cicids2017_val.npz
# [GPU 0]   Cached shape: (123316, 77), labels: 123316
# [GPU 0] [VAL] Raw shape (before windowing): (123316, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 123267 windows lazily during training
# [GPU 0] [TEST] Loading from cache: outputs/cache/cicids2017_test.npz
# [GPU 0]   Cached shape: (246633, 77), labels: 246633
# [GPU 0] [TEST] Raw shape (before windowing): (246633, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 246584 windows lazily during training
# [GPU 0]   Features: 77, Train: 863165, Val: 123267, Test: 246584
# [GPU 0] [2/5] Initializing GRU (d_model=128, n_layers=2)...
# [GPU 0]   Parameters: 373,505
# [GPU 0] [3/5] Training GRU...
# [GPU 0]   Using class-weighted loss (pos_weight=1.00)
# [GPU 0]   Epoch   1/30 | TrLoss: 0.0538 | VlLoss: 0.1752 | VlAcc: 0.9642 | VlF1: 0.9818 *
# [GPU 0]   Epoch   2/30 | TrLoss: 0.0440 | VlLoss: 0.1813 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 0]   Epoch   3/30 | TrLoss: 0.0355 | VlLoss: 0.1798 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 0]   Epoch   4/30 | TrLoss: 0.0295 | VlLoss: 0.1799 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 0]   Epoch   5/30 | TrLoss: 0.0431 | VlLoss: 0.1810 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 0]   Epoch   6/30 | TrLoss: 0.0282 | VlLoss: 0.1817 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 0]   Early stopping at epoch 6 (patience=5)
# [GPU 0]   Best Val F1: 0.9818 (6 epochs, 422.3s)
# [GPU 0]   💾 Model saved to: outputs/checkpoints/CICIDS2017_GRU_seed456.pt
# [GPU 0] [4/5] Evaluating on test set...
# [GPU 0]   Test Acc: 0.0894 | Prec: 0.0893 | Rec: 1.0000 | F1: 0.1640 | AUC: 0.0914
# [GPU 0] [5/5] Measuring efficiency...
# [GPU 0]   Latency: 0.51ms | Throughput: 44000/s | Memory: 1.42MB
# [GPU 0]   Attack types analyzed: 3
# [GPU 0]
# [GPU 0] [16/18] Running experiment...
# [GPU 0]
# [GPU 0] ======================================================================
# [GPU 0]   Dataset: CICIDS2017 | Model: Transformer | Seed: 456
# [GPU 0] ======================================================================
# [GPU 0] [Reproducibility] Setting all random seeds to 456
# [GPU 0] [Reproducibility] [OK] All seeds set and deterministic mode enabled
# [GPU 0] [1/5] Loading CICIDS2017 dataset...
# [GPU 0] [TRAIN] Loading from cache: outputs/cache/cicids2017_train.npz
# [GPU 0]   Cached shape: (863214, 77), labels: 863214
# [GPU 0] [TRAIN] Raw shape (before windowing): (863214, 77)
# [GPU 0] Fitting StandardScaler on Train split...
# [GPU 0] Saved scaler to outputs/scaler_cicids.pkl
# [GPU 0] [OK] Will generate 863165 windows lazily during training
# [GPU 0] [VAL] Loading from cache: outputs/cache/cicids2017_val.npz
# [GPU 0]   Cached shape: (123316, 77), labels: 123316
# [GPU 0] [VAL] Raw shape (before windowing): (123316, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 123267 windows lazily during training
# [GPU 0] [TEST] Loading from cache: outputs/cache/cicids2017_test.npz
# [GPU 0]   Cached shape: (246633, 77), labels: 246633
# [GPU 0] [TEST] Raw shape (before windowing): (246633, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 246584 windows lazily during training
# [GPU 0]   Features: 77, Train: 863165, Val: 123267, Test: 246584
# [GPU 0] [2/5] Initializing Transformer (d_model=128, n_layers=2)...
# [GPU 0]   Parameters: 406,913
# [GPU 0] [3/5] Training Transformer...
# [GPU 0]   Using class-weighted loss (pos_weight=1.00)
# [GPU 0]   Epoch   1/30 | TrLoss: 0.1211 | VlLoss: 0.1927 | VlAcc: 0.9642 | VlF1: 0.9818 *
# [GPU 0]   Epoch   2/30 | TrLoss: 0.0439 | VlLoss: 0.1473 | VlAcc: 0.9728 | VlF1: 0.9860 *
# [GPU 0]   Epoch   3/30 | TrLoss: 0.0616 | VlLoss: 0.1436 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 0]   Epoch   4/30 | TrLoss: 0.0366 | VlLoss: 0.2879 | VlAcc: 0.9188 | VlF1: 0.9570
# [GPU 0]   Epoch   5/30 | TrLoss: 0.0337 | VlLoss: 0.3617 | VlAcc: 0.9294 | VlF1: 0.9627
# [GPU 0]   Epoch   6/30 | TrLoss: 0.0212 | VlLoss: 0.1347 | VlAcc: 0.9705 | VlF1: 0.9849
# [GPU 0]   Epoch   7/30 | TrLoss: 0.0167 | VlLoss: 0.2355 | VlAcc: 0.8851 | VlF1: 0.9374
# [GPU 0]   Early stopping at epoch 7 (patience=5)
# [GPU 0]   Best Val F1: 0.9860 (7 epochs, 696.1s)
# [GPU 0]   💾 Model saved to: outputs/checkpoints/CICIDS2017_Transformer_seed456.pt
# [GPU 0] [4/5] Evaluating on test set...
# [GPU 0]   Test Acc: 0.4633 | Prec: 0.1424 | Rec: 0.9966 | F1: 0.2492 | AUC: 0.5369
# [GPU 0] [5/5] Measuring efficiency...
# [GPU 0]   Latency: 1.46ms | Throughput: 26556/s | Memory: 1.55MB
# [GPU 0]   Attack types analyzed: 3
# [GPU 0]
# [GPU 0] [17/18] Running experiment...
# [GPU 0]
# [GPU 0] ======================================================================
# [GPU 0]   Dataset: CICIDS2017 | Model: CNN-LSTM | Seed: 456
# [GPU 0] ======================================================================
# [GPU 0] [Reproducibility] Setting all random seeds to 456
# [GPU 0] [Reproducibility] [OK] All seeds set and deterministic mode enabled
# [GPU 0] [1/5] Loading CICIDS2017 dataset...
# [GPU 0] [TRAIN] Loading from cache: outputs/cache/cicids2017_train.npz
# [GPU 0]   Cached shape: (863214, 77), labels: 863214
# [GPU 0] [TRAIN] Raw shape (before windowing): (863214, 77)
# [GPU 0] Fitting StandardScaler on Train split...
# [GPU 0] Saved scaler to outputs/scaler_cicids.pkl
# [GPU 0] [OK] Will generate 863165 windows lazily during training
# [GPU 0] [VAL] Loading from cache: outputs/cache/cicids2017_val.npz
# [GPU 0]   Cached shape: (123316, 77), labels: 123316
# [GPU 0] [VAL] Raw shape (before windowing): (123316, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 123267 windows lazily during training
# [GPU 0] [TEST] Loading from cache: outputs/cache/cicids2017_test.npz
# [GPU 0]   Cached shape: (246633, 77), labels: 246633
# [GPU 0] [TEST] Raw shape (before windowing): (246633, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 246584 windows lazily during training
# [GPU 0]   Features: 77, Train: 863165, Val: 123267, Test: 246584
# [GPU 0] [2/5] Initializing CNN-LSTM (d_model=128, n_layers=2)...
# [GPU 0]   Parameters: 409,601
# [GPU 0] [3/5] Training CNN-LSTM...
# [GPU 0]   Using class-weighted loss (pos_weight=1.00)
# [GPU 0]   Epoch   1/30 | TrLoss: 0.2727 | VlLoss: 0.1851 | VlAcc: 0.9642 | VlF1: 0.9818 *
# [GPU 0]   Epoch   2/30 | TrLoss: 0.1166 | VlLoss: 0.1836 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 0]   Epoch   3/30 | TrLoss: 0.0377 | VlLoss: 0.1818 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 0]   Epoch   4/30 | TrLoss: 0.0441 | VlLoss: 0.1806 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 0]   Epoch   5/30 | TrLoss: 0.0350 | VlLoss: 0.1642 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 0]   Epoch   6/30 | TrLoss: 0.0171 | VlLoss: 0.1341 | VlAcc: 0.9649 | VlF1: 0.9821 *
# [GPU 0]   Epoch   7/30 | TrLoss: 0.0086 | VlLoss: 0.3340 | VlAcc: 0.9734 | VlF1: 0.9862 *
# [GPU 0]   Epoch   8/30 | TrLoss: 0.0103 | VlLoss: 0.2288 | VlAcc: 0.9723 | VlF1: 0.9858
# [GPU 0]   Epoch   9/30 | TrLoss: 0.0168 | VlLoss: 0.1622 | VlAcc: 0.9803 | VlF1: 0.9899 *
# [GPU 0]   Epoch  10/30 | TrLoss: 0.0048 | VlLoss: 0.7153 | VlAcc: 0.6607 | VlF1: 0.7876
# [GPU 0]   Epoch  11/30 | TrLoss: 0.0033 | VlLoss: 0.9422 | VlAcc: 0.4945 | VlF1: 0.6450
# [GPU 0]   Epoch  12/30 | TrLoss: 0.0027 | VlLoss: 0.0275 | VlAcc: 0.9935 | VlF1: 0.9966 *
# [GPU 0]   Epoch  13/30 | TrLoss: 0.0021 | VlLoss: 0.0202 | VlAcc: 0.9948 | VlF1: 0.9973 *
# [GPU 0]   Epoch  14/30 | TrLoss: 0.0018 | VlLoss: 0.0231 | VlAcc: 0.9951 | VlF1: 0.9975 *
# [GPU 0]   Epoch  15/30 | TrLoss: 0.0014 | VlLoss: 0.0350 | VlAcc: 0.9942 | VlF1: 0.9970
# [GPU 0]   Epoch  16/30 | TrLoss: 0.0011 | VlLoss: 0.0552 | VlAcc: 0.9944 | VlF1: 0.9971
# [GPU 0]   Epoch  17/30 | TrLoss: 0.0012 | VlLoss: 0.0414 | VlAcc: 0.9948 | VlF1: 0.9973
# [GPU 0]   Epoch  18/30 | TrLoss: 0.0009 | VlLoss: 0.0617 | VlAcc: 0.9961 | VlF1: 0.9980 *
# [GPU 0]   Epoch  19/30 | TrLoss: 0.0006 | VlLoss: 0.0532 | VlAcc: 0.9954 | VlF1: 0.9976
# [GPU 0]   Epoch  20/30 | TrLoss: 0.0006 | VlLoss: 0.0339 | VlAcc: 0.9963 | VlF1: 0.9981 *
# [GPU 0]   Epoch  21/30 | TrLoss: 0.0005 | VlLoss: 0.0314 | VlAcc: 0.9963 | VlF1: 0.9981 *
# [GPU 0]   Epoch  22/30 | TrLoss: 0.0006 | VlLoss: 0.0382 | VlAcc: 0.9955 | VlF1: 0.9976
# [GPU 0]   Epoch  23/30 | TrLoss: 0.0004 | VlLoss: 0.0348 | VlAcc: 0.9957 | VlF1: 0.9978
# [GPU 0]   Epoch  24/30 | TrLoss: 0.0003 | VlLoss: 0.0303 | VlAcc: 0.9955 | VlF1: 0.9977
# [GPU 0]   Epoch  25/30 | TrLoss: 0.0005 | VlLoss: 0.0328 | VlAcc: 0.9951 | VlF1: 0.9975
# [GPU 0]   Epoch  26/30 | TrLoss: 0.0004 | VlLoss: 0.0320 | VlAcc: 0.9951 | VlF1: 0.9974
# [GPU 0]   Early stopping at epoch 26 (patience=5)
# [GPU 0]   Best Val F1: 0.9981 (26 epochs, 2199.1s)
# [GPU 0]   💾 Model saved to: outputs/checkpoints/CICIDS2017_CNN-LSTM_seed456.pt
# [GPU 0] [4/5] Evaluating on test set...
# [GPU 0]   Test Acc: 0.9638 | Prec: 0.7258 | Rec: 0.9559 | F1: 0.8251 | AUC: 0.9733
# [GPU 0] [5/5] Measuring efficiency...
# [GPU 0]   Latency: 0.87ms | Throughput: 33971/s | Memory: 1.56MB
# [GPU 0]   Attack types analyzed: 3
# [GPU 0]
# [GPU 0] [18/18] Running experiment...
# [GPU 0]
# [GPU 0] ======================================================================
# [GPU 0]   Dataset: CICIDS2017 | Model: TCN | Seed: 456
# [GPU 0] ======================================================================
# [GPU 0] [Reproducibility] Setting all random seeds to 456
# [GPU 0] [Reproducibility] [OK] All seeds set and deterministic mode enabled
# [GPU 0] [1/5] Loading CICIDS2017 dataset...
# [GPU 0] [TRAIN] Loading from cache: outputs/cache/cicids2017_train.npz
# [GPU 0]   Cached shape: (863214, 77), labels: 863214
# [GPU 0] [TRAIN] Raw shape (before windowing): (863214, 77)
# [GPU 0] Fitting StandardScaler on Train split...
# [GPU 0] Saved scaler to outputs/scaler_cicids.pkl
# [GPU 0] [OK] Will generate 863165 windows lazily during training
# [GPU 0] [VAL] Loading from cache: outputs/cache/cicids2017_val.npz
# [GPU 0]   Cached shape: (123316, 77), labels: 123316
# [GPU 0] [VAL] Raw shape (before windowing): (123316, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 123267 windows lazily during training
# [GPU 0] [TEST] Loading from cache: outputs/cache/cicids2017_test.npz
# [GPU 0]   Cached shape: (246633, 77), labels: 246633
# [GPU 0] [TEST] Raw shape (before windowing): (246633, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 246584 windows lazily during training
# [GPU 0]   Features: 77, Train: 863165, Val: 123267, Test: 246584
# [GPU 0] [2/5] Initializing TCN (d_model=128, n_layers=2)...
# [GPU 0]   Parameters: 423,169
# [GPU 0] [3/5] Training TCN...
# [GPU 0]   Using class-weighted loss (pos_weight=1.00)
# [GPU 0]   Epoch   1/30 | TrLoss: 0.0315 | VlLoss: 0.0679 | VlAcc: 0.9739 | VlF1: 0.9866 *
# [GPU 0]   Epoch   2/30 | TrLoss: 0.0184 | VlLoss: 0.0360 | VlAcc: 0.9888 | VlF1: 0.9942 *
# [GPU 0]   Epoch   3/30 | TrLoss: 0.0054 | VlLoss: 0.0316 | VlAcc: 0.9911 | VlF1: 0.9954 *
# [GPU 0]   Epoch   4/30 | TrLoss: 0.0031 | VlLoss: 0.0422 | VlAcc: 0.9881 | VlF1: 0.9939
# [GPU 0]   Epoch   5/30 | TrLoss: 0.0024 | VlLoss: 0.0343 | VlAcc: 0.9904 | VlF1: 0.9950
# [GPU 0]   Epoch   6/30 | TrLoss: 0.0021 | VlLoss: 0.0349 | VlAcc: 0.9910 | VlF1: 0.9953
# [GPU 0]   Epoch   7/30 | TrLoss: 0.0019 | VlLoss: 0.0417 | VlAcc: 0.9888 | VlF1: 0.9942
# [GPU 0]   Epoch   8/30 | TrLoss: 0.0015 | VlLoss: 0.0448 | VlAcc: 0.9892 | VlF1: 0.9944
# [GPU 0]   Early stopping at epoch 8 (patience=5)
# [GPU 0]   Best Val F1: 0.9954 (8 epochs, 855.0s)
# [GPU 0]   💾 Model saved to: outputs/checkpoints/CICIDS2017_TCN_seed456.pt
# [GPU 0] [4/5] Evaluating on test set...
# [GPU 0]   Test Acc: 0.7967 | Prec: 0.3002 | Rec: 0.9584 | F1: 0.4572 | AUC: 0.9687
# [GPU 0] [5/5] Measuring efficiency...
# [GPU 0]   Latency: 1.76ms | Throughput: 16367/s | Memory: 1.61MB
# [GPU 0]   Attack types analyzed: 3
# [GPU 0]
# [GPU 0]
# [GPU 0] ======================================================================
# [GPU 0] BENCHMARK SUMMARY
# [GPU 0] ======================================================================
# [GPU 0]
# [GPU 0] 📊 CICIDS2017
# [GPU 0] Model                Acc     Prec      Rec       F1      AUC  Lat(ms)     Params
# [GPU 0] -----------------------------------------------------------------------------------
# [GPU 0] Mamba           0.9600  0.7467  0.9398  0.8208  0.9818   15.14     387,073
# [GPU 0] LSTM            0.9912  0.9914  0.9097  0.9488  0.9876    0.77     423,169
# [GPU 0] GRU             0.3901  0.3903  0.9708  0.4263  0.6273    0.64     373,505
# [GPU 0] Transformer     0.2168  0.1072  0.9984  0.1928  0.6152    1.47     406,913
# [GPU 0] CNN-LSTM        0.6756  0.5373  0.9675  0.6181  0.7155    0.94     409,601
# [GPU 0] TCN             0.8569  0.3934  0.9540  0.5534  0.9705    1.81     423,169
# [GPU 0]
# [GPU 0] ✅ Results saved to: outputs/benchmark_results/
# [GPU 0]    Run 'python generate_tables.py' to generate publication tables.
#
# ✅ GPU 0 finished (exit=0)
# ✅ GPU 1 finished (exit=0)
# ⏱️  Total time: 9h 19m
#
# ============================================================
# 🏁 All done! Total time: 9h 19m
# ============================================================
#
# 📊 Merging results from both GPUs...
#    ⚠ No results file found — check gpu0_log.txt and gpu1_log.txt for errors
# 📋 Generating publication tables...
# Loaded 18 experiment results.
#
# ## Table 1: Classification Results — CICIDS2017
# *Mean ± std across 3 seeds*
#
# | Model | Accuracy | Precision | Recall | F1-Score | AUC-ROC |
# |-------|----------|-----------|--------|----------|---------|
# | LSTM | 99.12 ± 0.01 | 99.14 ± 0.46 | 90.97 ± 0.45 | 94.88 ± 0.06 | 98.76 ± 0.02 |
# | Mamba | 96.00 ± 2.58 | 74.67 ± 16.28 | 93.98 ± 1.85 | 82.08 ± 9.62 | 98.18 ± 0.40 |
# | CNN-LSTM | 67.56 ± 41.46 | 53.73 ± 31.81 | 96.75 ± 2.33 | 61.81 ± 32.15 | 71.55 ± 36.59 |
# | TCN | 85.69 ± 4.32 | 39.34 ± 6.78 | 95.40 ± 0.65 | 55.34 ± 6.94 | 97.05 ± 0.17 |
# | GRU | 39.01 ± 42.53 | 39.03 ± 42.56 | 97.08 ± 4.12 | 42.63 ± 37.08 | 62.73 ± 38.59 |
# | Transformer | 21.68 ± 17.44 | 10.72 ± 2.49 | 99.84 ± 0.14 | 19.28 ± 3.99 | 61.52 ± 8.49 |
#
# ## Table 2: Efficiency Comparison — CICIDS2017
#
# | Model | Params | Memory (MB) | Latency (ms) | Throughput (/s) | Train Time (s) |
# |-------|--------|-------------|--------------|-----------------|----------------|
# | GRU | 373,505 | 1.42 | 0.64 ± 0.18 | 43408 | 705.9 |
# | LSTM | 423,169 | 1.61 | 0.77 ± 0.01 | 30460 | 1112.1 |
# | CNN-LSTM | 409,601 | 1.56 | 0.94 ± 0.05 | 33516 | 1223.4 |
# | Transformer | 406,913 | 1.55 | 1.47 ± 0.14 | 24570 | 704.4 |
# | TCN | 423,169 | 1.61 | 1.81 ± 0.06 | 15822 | 979.7 |
# | Mamba | 387,073 | 1.48 | 15.14 ± 1.12 | 2154 | 6220.6 |
#
# ## Table 3: Per-Attack-Type F1 (%) — CICIDS2017
#
# | Model | BENIGN | Bot | PortScan |
# |-------|--------|-----|----------|
# | Mamba | 98.0 | 55.0 | 99.6 |
# | LSTM | 100.0 | 13.4 | 99.6 |
# | GRU | 33.3 | 71.3 | 99.9 |
# | Transformer | 20.0 | 99.5 | 100.0 |
# | CNN-LSTM | 65.7 | 79.3 | 99.8 |
# | TCN | 91.7 | 69.8 | 99.7 |
#
# ## Table 4: Statistical Significance (Wilcoxon) — CICIDS2017
#
# | Model A | Model B | p-value | Significant (p<0.05) |
# |---------|---------|---------|----------------------|
# | Mamba | LSTM | N/A | N/A |
# | Mamba | GRU | N/A | N/A |
# | Mamba | Transformer | N/A | N/A |
# | Mamba | CNN-LSTM | N/A | N/A |
# | Mamba | TCN | N/A | N/A |
# | LSTM | GRU | N/A | N/A |
# | LSTM | Transformer | N/A | N/A |
# | LSTM | CNN-LSTM | N/A | N/A |
# | LSTM | TCN | N/A | N/A |
# | GRU | Transformer | N/A | N/A |
# | GRU | CNN-LSTM | N/A | N/A |
# | GRU | TCN | N/A | N/A |
# | Transformer | CNN-LSTM | N/A | N/A |
# | Transformer | TCN | N/A | N/A |
# | CNN-LSTM | TCN | N/A | N/A |
#
#
# ✅ Tables saved to outputs/benchmark_results/benchmark_tables.md
#
# ✅ Results saved to outputs/benchmark_results/
