# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/datasets/kk0105/cicids2017/Week_filtered.csv
# /kaggle/input/datasets/kk0105/cicids2017/MachineLearningCSV/MachineLearningCSV/MachineLearningCVE/Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv
# /kaggle/input/datasets/kk0105/cicids2017/MachineLearningCSV/MachineLearningCSV/MachineLearningCVE/Thursday-WorkingHours-Morning-WebAttacks.pcap_ISCX.csv
# /kaggle/input/datasets/kk0105/cicids2017/MachineLearningCSV/MachineLearningCSV/MachineLearningCVE/Tuesday-WorkingHours.pcap_ISCX.csv
# /kaggle/input/datasets/kk0105/cicids2017/MachineLearningCSV/MachineLearningCSV/MachineLearningCVE/Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv
# /kaggle/input/datasets/kk0105/cicids2017/MachineLearningCSV/MachineLearningCSV/MachineLearningCVE/Monday-WorkingHours.pcap_ISCX.csv
# /kaggle/input/datasets/kk0105/cicids2017/MachineLearningCSV/MachineLearningCSV/MachineLearningCVE/Friday-WorkingHours-Morning.pcap_ISCX.csv
# /kaggle/input/datasets/kk0105/cicids2017/MachineLearningCSV/MachineLearningCSV/MachineLearningCVE/Thursday-WorkingHours-Afternoon-Infilteration.pcap_ISCX.csv
# /kaggle/input/datasets/kk0105/cicids2017/MachineLearningCSV/MachineLearningCSV/MachineLearningCVE/Wednesday-workingHours.pcap_ISCX.csv

# %%
# !git clone https://github.com/ARUNTHOMAS3/The-Mamba-Powered-Real-time-Threat-Intelligence-Agent.git /kaggle/working/mamba
# %cd /kaggle/working/mamba
# !git pull
# !mkdir -p data/raw/CICIDS2017
# !cp /kaggle/input/datasets/kk0105/cicids2017/MachineLearningCSV/MachineLearningCSV/MachineLearningCVE/*.csv data/raw/CICIDS2017/
# !python -u kaggle_dual_gpu.py
# Out:
# Cloning into '/kaggle/working/mamba'...
# remote: Enumerating objects: 124, done.
# remote: Counting objects: 100% (124/124), done.
# remote: Compressing objects: 100% (94/94), done.
# remote: Total 124 (delta 26), reused 119 (delta 21), pack-reused 0 (from 0)
# Receiving objects: 100% (124/124), 148.73 KiB | 2.86 MiB/s, done.
# Resolving deltas: 100% (26/26), done.
# /kaggle/working/mamba
# Already up to date.
# 🔍 Detected 2 GPU(s):
#    GPU 0: Tesla T4 (15.6 GB)
#    GPU 1: Tesla T4 (15.6 GB)
#
# 🚀 Running on 2 GPUs in parallel!
#    GPU 0: Seeds [42, 123, 456]
#    GPU 1: Seeds [789, 1024]
# ============================================================
# ✅ GPU 0 started (PID 77) — seeds [42, 123, 456]
# ✅ GPU 1 started (PID 78) — seeds [789, 1024]
#
# ⏳ Both GPUs training in parallel — live output below:
#
# [GPU 0] ======================================================================
# [GPU 0] COMPREHENSIVE IDS BENCHMARK
# [GPU 0] ======================================================================
# [GPU 0] Datasets:  ['CICIDS2017']
# [GPU 0] Models:    ['Mamba', 'LSTM', 'GRU', 'Transformer', 'CNN-LSTM', 'TCN']
# [GPU 0] Seeds:     [42, 123, 456]
# [GPU 0] Device:    cuda
# [GPU 0] Epochs:    30
# [GPU 0] Batch:     128
# [GPU 0] Seq Len:   50
# [GPU 0] d_model:   128
# [GPU 0] n_layers:  2
# [GPU 0] ======================================================================
# [GPU 0]
# [GPU 0] [1/18] Running experiment...
# [GPU 0]
# [GPU 0] ======================================================================
# [GPU 0]   Dataset: CICIDS2017 | Model: Mamba | Seed: 42
# [GPU 0] ======================================================================
# [GPU 0] [Reproducibility] Setting all random seeds to 42
# [GPU 0] [Reproducibility] [OK] All seeds set and deterministic mode enabled
# [GPU 0] [1/5] Loading CICIDS2017 dataset...
# [GPU 0] [TRAIN] No cache found, parsing CSVs (this only happens once)...
# [GPU 0] [TRAIN] Loading CICIDS2017 (4 files)...
# [GPU 0] Files: ['Monday-WorkingHours.pcap_ISCX.csv', 'Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv', 'Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv', 'Friday-WorkingHours-Morning.pcap_ISCX.csv']
# [GPU 0]  -> Processing Monday-WorkingHours.pcap_ISCX.csv...
# [GPU 1] ======================================================================
# [GPU 1] COMPREHENSIVE IDS BENCHMARK
# [GPU 1] ======================================================================
# [GPU 1] Datasets:  ['CICIDS2017']
# [GPU 1] Models:    ['Mamba', 'LSTM', 'GRU', 'Transformer', 'CNN-LSTM', 'TCN']
# [GPU 1] Seeds:     [789, 1024]
# [GPU 1] Device:    cuda
# [GPU 1] Epochs:    30
# [GPU 1] Batch:     128
# [GPU 1] Seq Len:   50
# [GPU 1] d_model:   128
# [GPU 1] n_layers:  2
# [GPU 1] ======================================================================
# [GPU 1]
# [GPU 1] [1/12] Running experiment...
# [GPU 1]
# [GPU 1] ======================================================================
# [GPU 1]   Dataset: CICIDS2017 | Model: Mamba | Seed: 789
# [GPU 1] ======================================================================
# [GPU 1] [Reproducibility] Setting all random seeds to 789
# [GPU 1] [Reproducibility] [OK] All seeds set and deterministic mode enabled
# [GPU 1] [1/5] Loading CICIDS2017 dataset...
# [GPU 1] [TRAIN] No cache found, parsing CSVs (this only happens once)...
# [GPU 1] [TRAIN] Loading CICIDS2017 (4 files)...
# [GPU 1] Files: ['Monday-WorkingHours.pcap_ISCX.csv', 'Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv', 'Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv', 'Friday-WorkingHours-Morning.pcap_ISCX.csv']
# [GPU 1]  -> Processing Monday-WorkingHours.pcap_ISCX.csv...
# [GPU 0]  -> Processing Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv...
# [GPU 1]  -> Processing Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv...
# [GPU 0]  -> Processing Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv...
# [GPU 1]  -> Processing Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv...
# [GPU 0]  -> Processing Friday-WorkingHours-Morning.pcap_ISCX.csv...
# [GPU 1]  -> Processing Friday-WorkingHours-Morning.pcap_ISCX.csv...
# [GPU 0] Concatenating chunks...
# [GPU 0] Loaded 1233163 total rows.
# [GPU 0] Processing Labels...
# [GPU 1] Concatenating chunks...
# [GPU 1] Loaded 1233163 total rows.
# [GPU 1] Processing Labels...
# [GPU 0] Class Distribution: Benign=944240, Attack=288923
# [GPU 1] Class Distribution: Benign=944240, Attack=288923
# [GPU 0] Converting to numpy arrays...
# [GPU 0] Cleaning NaN/Inf values...
# [GPU 1] Converting to numpy arrays...
# [GPU 0] Total samples: 1233163
# [GPU 0] Train: 0-863214, Val: 863214-986530, Test: 986530-1233163
# [GPU 1] Cleaning NaN/Inf values...
# [GPU 0] Saving cache to outputs/cache/cicids2017_train.npz...
# [GPU 1] Total samples: 1233163
# [GPU 1] Train: 0-863214, Val: 863214-986530, Test: 986530-1233163
# [GPU 1] Saving cache to outputs/cache/cicids2017_train.npz...
# [GPU 0] [TRAIN] Raw shape (before windowing): (863214, 77)
# [GPU 0] [TRAIN] Raw shape (before windowing): (863214, 77)
# [GPU 0] Fitting StandardScaler on Train split...
# [GPU 1] [TRAIN] Raw shape (before windowing): (863214, 77)
# [GPU 1] [TRAIN] Raw shape (before windowing): (863214, 77)
# [GPU 1] Fitting StandardScaler on Train split...
# [GPU 0] Saved scaler to outputs/scaler_cicids.pkl
# [GPU 0] [OK] Will generate 863165 windows lazily during training
# [GPU 0] [VAL] No cache found, parsing CSVs (this only happens once)...
# [GPU 0] [VAL] Loading CICIDS2017 (4 files)...
# [GPU 0] Files: ['Monday-WorkingHours.pcap_ISCX.csv', 'Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv', 'Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv', 'Friday-WorkingHours-Morning.pcap_ISCX.csv']
# [GPU 0]  -> Processing Monday-WorkingHours.pcap_ISCX.csv...
# [GPU 1] Saved scaler to outputs/scaler_cicids.pkl
# [GPU 1] [OK] Will generate 863165 windows lazily during training
# [GPU 1] [VAL] No cache found, parsing CSVs (this only happens once)...
# [GPU 1] [VAL] Loading CICIDS2017 (4 files)...
# [GPU 1] Files: ['Monday-WorkingHours.pcap_ISCX.csv', 'Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv', 'Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv', 'Friday-WorkingHours-Morning.pcap_ISCX.csv']
# [GPU 1]  -> Processing Monday-WorkingHours.pcap_ISCX.csv...
# [GPU 0]  -> Processing Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv...
# [GPU 1]  -> Processing Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv...
# [GPU 0]  -> Processing Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv...
# [GPU 1]  -> Processing Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv...
# [GPU 0]  -> Processing Friday-WorkingHours-Morning.pcap_ISCX.csv...
# [GPU 1]  -> Processing Friday-WorkingHours-Morning.pcap_ISCX.csv...
# [GPU 0] Concatenating chunks...
# [GPU 0] Loaded 1233163 total rows.
# [GPU 0] Processing Labels...
# [GPU 1] Concatenating chunks...
# [GPU 1] Loaded 1233163 total rows.
# [GPU 1] Processing Labels...
# [GPU 0] Class Distribution: Benign=944240, Attack=288923
# [GPU 0] Converting to numpy arrays...
# [GPU 1] Class Distribution: Benign=944240, Attack=288923
# [GPU 0] Cleaning NaN/Inf values...
# [GPU 0] Total samples: 1233163
# [GPU 0] Train: 0-863214, Val: 863214-986530, Test: 986530-1233163
# [GPU 1] Converting to numpy arrays...
# [GPU 0] Saving cache to outputs/cache/cicids2017_val.npz...
# [GPU 1] Cleaning NaN/Inf values...
# [GPU 1] Total samples: 1233163
# [GPU 1] Train: 0-863214, Val: 863214-986530, Test: 986530-1233163
# [GPU 1] Saving cache to outputs/cache/cicids2017_val.npz...
# [GPU 0] [VAL] Raw shape (before windowing): (123316, 77)
# [GPU 0] [VAL] Raw shape (before windowing): (123316, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 123267 windows lazily during training
# [GPU 0] [TEST] No cache found, parsing CSVs (this only happens once)...
# [GPU 0] [TEST] Loading CICIDS2017 (4 files)...
# [GPU 0] Files: ['Monday-WorkingHours.pcap_ISCX.csv', 'Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv', 'Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv', 'Friday-WorkingHours-Morning.pcap_ISCX.csv']
# [GPU 0]  -> Processing Monday-WorkingHours.pcap_ISCX.csv...
# [GPU 1] [VAL] Raw shape (before windowing): (123316, 77)
# [GPU 1] [VAL] Raw shape (before windowing): (123316, 77)
# [GPU 1] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 1] [OK] Will generate 123267 windows lazily during training
# [GPU 1] [TEST] No cache found, parsing CSVs (this only happens once)...
# [GPU 1] [TEST] Loading CICIDS2017 (4 files)...
# [GPU 1] Files: ['Monday-WorkingHours.pcap_ISCX.csv', 'Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv', 'Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv', 'Friday-WorkingHours-Morning.pcap_ISCX.csv']
# [GPU 1]  -> Processing Monday-WorkingHours.pcap_ISCX.csv...
# [GPU 0]  -> Processing Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv...
# [GPU 1]  -> Processing Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv...
# [GPU 0]  -> Processing Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv...
# [GPU 1]  -> Processing Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv...
# [GPU 0]  -> Processing Friday-WorkingHours-Morning.pcap_ISCX.csv...
# [GPU 1]  -> Processing Friday-WorkingHours-Morning.pcap_ISCX.csv...
# [GPU 0] Concatenating chunks...
# [GPU 0] Loaded 1233163 total rows.
# [GPU 0] Processing Labels...
# [GPU 1] Concatenating chunks...
# [GPU 1] Loaded 1233163 total rows.
# [GPU 1] Processing Labels...
# [GPU 0] Class Distribution: Benign=944240, Attack=288923
# [GPU 0] Converting to numpy arrays...
# [GPU 1] Class Distribution: Benign=944240, Attack=288923
# [GPU 0] Cleaning NaN/Inf values...
# [GPU 1] Converting to numpy arrays...
# [GPU 0] Total samples: 1233163
# [GPU 0] Train: 0-863214, Val: 863214-986530, Test: 986530-1233163
# [GPU 0] Saving cache to outputs/cache/cicids2017_test.npz...
# [GPU 1] Cleaning NaN/Inf values...
# [GPU 1] Total samples: 1233163
# [GPU 1] Train: 0-863214, Val: 863214-986530, Test: 986530-1233163
# [GPU 1] Saving cache to outputs/cache/cicids2017_test.npz...
# [GPU 0] [TEST] Raw shape (before windowing): (246633, 77)
# [GPU 0] [TEST] Raw shape (before windowing): (246633, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 246584 windows lazily during training
# [GPU 0]   Features: 77, Train: 863165, Val: 123267, Test: 246584
# [GPU 0] [2/5] Initializing Mamba (d_model=128, n_layers=2)...
# [GPU 1] [TEST] Raw shape (before windowing): (246633, 77)
# [GPU 1] [TEST] Raw shape (before windowing): (246633, 77)
# [GPU 1] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 1] [OK] Will generate 246584 windows lazily during training
# [GPU 1]   Features: 77, Train: 863165, Val: 123267, Test: 246584
# [GPU 1] [2/5] Initializing Mamba (d_model=128, n_layers=2)...
# [GPU 0]   Parameters: 387,073
# [GPU 0] [3/5] Training Mamba...
# [GPU 0]   LR: 0.000300 (base=0.001 × 0.3 for Mamba), grad_clip=0.5
# [GPU 1]   Parameters: 387,073
# [GPU 1] [3/5] Training Mamba...
# [GPU 1]   LR: 0.000300 (base=0.001 × 0.3 for Mamba), grad_clip=0.5
# [GPU 0]   Using class-weighted loss (pos_weight=1.00)
# [GPU 1]   Using class-weighted loss (pos_weight=1.00)
# [GPU 0]   Epoch   1/30 | TrLoss: 0.0239 | VlLoss: 0.0402 | VlAcc: 0.9931 | VlF1: 0.9964 *
# [GPU 1]   Epoch   1/30 | TrLoss: 0.0239 | VlLoss: 0.0308 | VlAcc: 0.9954 | VlF1: 0.9976 *
# [GPU 0]   Epoch   2/30 | TrLoss: 0.0354 | VlLoss: 0.0902 | VlAcc: 0.9879 | VlF1: 0.9938
# [GPU 1]   Epoch   2/30 | TrLoss: 0.0083 | VlLoss: 0.0241 | VlAcc: 0.9957 | VlF1: 0.9978 *
# [GPU 0]   Epoch   3/30 | TrLoss: 0.0372 | VlLoss: 0.1834 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 1]   Epoch   3/30 | TrLoss: 0.0452 | VlLoss: 0.0237 | VlAcc: 0.9938 | VlF1: 0.9968
# [GPU 0]   Epoch   4/30 | TrLoss: 0.0365 | VlLoss: 0.0229 | VlAcc: 0.9968 | VlF1: 0.9983 *
# [GPU 1]   Epoch   4/30 | TrLoss: 0.0345 | VlLoss: 0.0190 | VlAcc: 0.9952 | VlF1: 0.9975
# [GPU 0]   Epoch   5/30 | TrLoss: 0.0228 | VlLoss: 0.0531 | VlAcc: 0.9907 | VlF1: 0.9952
# [GPU 1]   Epoch   5/30 | TrLoss: 0.0041 | VlLoss: 2.5060 | VlAcc: 0.4176 | VlF1: 0.5674
# [GPU 0]   Epoch   6/30 | TrLoss: 0.0088 | VlLoss: 0.0141 | VlAcc: 0.9961 | VlF1: 0.9980
# [GPU 1]   Epoch   6/30 | TrLoss: 0.0025 | VlLoss: 0.8371 | VlAcc: 0.4966 | VlF1: 0.6468
# [GPU 0]   Epoch   7/30 | TrLoss: 0.0027 | VlLoss: 0.0624 | VlAcc: 0.9827 | VlF1: 0.9909
# [GPU 1]   Epoch   7/30 | TrLoss: 0.0019 | VlLoss: 0.6769 | VlAcc: 0.5315 | VlF1: 0.6792
# [GPU 1]   Early stopping at epoch 7 (patience=5)
# [GPU 1]   Best Val F1: 0.9978 (7 epochs, 4785.6s)
# [GPU 1]   💾 Model saved to: outputs/checkpoints/CICIDS2017_Mamba_seed789.pt
# [GPU 1] [4/5] Evaluating on test set...
# [GPU 1]   Test Acc: 0.9699 | Prec: 0.7796 | Rec: 0.9240 | F1: 0.8457 | AUC: 0.9807
# [GPU 1] [5/5] Measuring efficiency...
# [GPU 1]   Latency: 14.17ms | Throughput: 2116/s | Memory: 1.48MB
# [GPU 1]   Attack types analyzed: 3
# [GPU 1]
# [GPU 1] [2/12] Running experiment...
# [GPU 1]
# [GPU 1] ======================================================================
# [GPU 1]   Dataset: CICIDS2017 | Model: LSTM | Seed: 789
# [GPU 1] ======================================================================
# [GPU 1] [Reproducibility] Setting all random seeds to 789
# [GPU 1] [Reproducibility] [OK] All seeds set and deterministic mode enabled
# [GPU 1] [1/5] Loading CICIDS2017 dataset...
# [GPU 1] [TRAIN] Loading from cache: outputs/cache/cicids2017_train.npz
# [GPU 1]   Cached shape: (863214, 77), labels: 863214
# [GPU 1] [TRAIN] Raw shape (before windowing): (863214, 77)
# [GPU 1] Fitting StandardScaler on Train split...
# [GPU 1] Saved scaler to outputs/scaler_cicids.pkl
# [GPU 1] [OK] Will generate 863165 windows lazily during training
# [GPU 1] [VAL] Loading from cache: outputs/cache/cicids2017_val.npz
# [GPU 1]   Cached shape: (123316, 77), labels: 123316
# [GPU 1] [VAL] Raw shape (before windowing): (123316, 77)
# [GPU 1] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 1] [OK] Will generate 123267 windows lazily during training
# [GPU 1] [TEST] Loading from cache: outputs/cache/cicids2017_test.npz
# [GPU 1]   Cached shape: (246633, 77), labels: 246633
# [GPU 1] [TEST] Raw shape (before windowing): (246633, 77)
# [GPU 1] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 1] [OK] Will generate 246584 windows lazily during training
# [GPU 1]   Features: 77, Train: 863165, Val: 123267, Test: 246584
# [GPU 1] [2/5] Initializing LSTM (d_model=128, n_layers=2)...
# [GPU 1]   Parameters: 423,169
# [GPU 1] [3/5] Training LSTM...
# [GPU 1]   LR: 0.001000 (base=0.001 × 1.0 for LSTM), grad_clip=1.0
# [GPU 1]   Using class-weighted loss (pos_weight=1.00)
# [GPU 1]   Epoch   1/30 | TrLoss: 0.0409 | VlLoss: 0.1850 | VlAcc: 0.9642 | VlF1: 0.9818 *
# [GPU 1]   Epoch   2/30 | TrLoss: 0.0327 | VlLoss: 0.1807 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 1]   Epoch   3/30 | TrLoss: 0.0337 | VlLoss: 0.1809 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 1]   Epoch   4/30 | TrLoss: 0.0345 | VlLoss: 0.1798 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 0]   Epoch   8/30 | TrLoss: 0.0018 | VlLoss: 0.0614 | VlAcc: 0.9775 | VlF1: 0.9882
# [GPU 1]   Epoch   5/30 | TrLoss: 0.0443 | VlLoss: 0.1840 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 1]   Epoch   6/30 | TrLoss: 0.0309 | VlLoss: 0.1132 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 1]   Early stopping at epoch 6 (patience=5)
# [GPU 1]   Best Val F1: 0.9818 (6 epochs, 552.6s)
# [GPU 1]   💾 Model saved to: outputs/checkpoints/CICIDS2017_LSTM_seed789.pt
# [GPU 1] [4/5] Evaluating on test set...
# [GPU 1]   Test Acc: 0.0893 | Prec: 0.0893 | Rec: 1.0000 | F1: 0.1640 | AUC: 0.6837
# [GPU 1] [5/5] Measuring efficiency...
# [GPU 1]   Latency: 0.75ms | Throughput: 28172/s | Memory: 1.61MB
# [GPU 1]   Attack types analyzed: 3
# [GPU 1]
# [GPU 1] [3/12] Running experiment...
# [GPU 1]
# [GPU 1] ======================================================================
# [GPU 1]   Dataset: CICIDS2017 | Model: GRU | Seed: 789
# [GPU 1] ======================================================================
# [GPU 1] [Reproducibility] Setting all random seeds to 789
# [GPU 1] [Reproducibility] [OK] All seeds set and deterministic mode enabled
# [GPU 1] [1/5] Loading CICIDS2017 dataset...
# [GPU 1] [TRAIN] Loading from cache: outputs/cache/cicids2017_train.npz
# [GPU 1]   Cached shape: (863214, 77), labels: 863214
# [GPU 1] [TRAIN] Raw shape (before windowing): (863214, 77)
# [GPU 1] Fitting StandardScaler on Train split...
# [GPU 1] Saved scaler to outputs/scaler_cicids.pkl
# [GPU 1] [OK] Will generate 863165 windows lazily during training
# [GPU 1] [VAL] Loading from cache: outputs/cache/cicids2017_val.npz
# [GPU 1]   Cached shape: (123316, 77), labels: 123316
# [GPU 1] [VAL] Raw shape (before windowing): (123316, 77)
# [GPU 1] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 1] [OK] Will generate 123267 windows lazily during training
# [GPU 1] [TEST] Loading from cache: outputs/cache/cicids2017_test.npz
# [GPU 1]   Cached shape: (246633, 77), labels: 246633
# [GPU 1] [TEST] Raw shape (before windowing): (246633, 77)
# [GPU 1] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 1] [OK] Will generate 246584 windows lazily during training
# [GPU 1]   Features: 77, Train: 863165, Val: 123267, Test: 246584
# [GPU 1] [2/5] Initializing GRU (d_model=128, n_layers=2)...
# [GPU 1]   Parameters: 373,505
# [GPU 1] [3/5] Training GRU...
# [GPU 1]   LR: 0.001000 (base=0.001 × 1.0 for GRU), grad_clip=1.0
# [GPU 1]   Using class-weighted loss (pos_weight=1.00)
# [GPU 1]   Epoch   1/30 | TrLoss: 0.0531 | VlLoss: 0.1852 | VlAcc: 0.9642 | VlF1: 0.9818 *
# [GPU 1]   Epoch   2/30 | TrLoss: 0.1224 | VlLoss: 0.1830 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 1]   Epoch   3/30 | TrLoss: 0.0460 | VlLoss: 0.1778 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 1]   Epoch   4/30 | TrLoss: 0.0323 | VlLoss: 0.1788 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 1]   Epoch   5/30 | TrLoss: 0.0427 | VlLoss: 0.1822 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 1]   Epoch   6/30 | TrLoss: 0.0334 | VlLoss: 0.1831 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 1]   Early stopping at epoch 6 (patience=5)
# [GPU 1]   Best Val F1: 0.9818 (6 epochs, 445.7s)
# [GPU 1]   💾 Model saved to: outputs/checkpoints/CICIDS2017_GRU_seed789.pt
# [GPU 1] [4/5] Evaluating on test set...
# [GPU 1]   Test Acc: 0.0894 | Prec: 0.0894 | Rec: 1.0000 | F1: 0.1640 | AUC: 0.7219
# [GPU 1] [5/5] Measuring efficiency...
# [GPU 1]   Latency: 0.50ms | Throughput: 41167/s | Memory: 1.42MB
# [GPU 1]   Attack types analyzed: 3
# [GPU 1]
# [GPU 1] [4/12] Running experiment...
# [GPU 1]
# [GPU 1] ======================================================================
# [GPU 1]   Dataset: CICIDS2017 | Model: Transformer | Seed: 789
# [GPU 1] ======================================================================
# [GPU 1] [Reproducibility] Setting all random seeds to 789
# [GPU 1] [Reproducibility] [OK] All seeds set and deterministic mode enabled
# [GPU 1] [1/5] Loading CICIDS2017 dataset...
# [GPU 1] [TRAIN] Loading from cache: outputs/cache/cicids2017_train.npz
# [GPU 1]   Cached shape: (863214, 77), labels: 863214
# [GPU 1] [TRAIN] Raw shape (before windowing): (863214, 77)
# [GPU 1] Fitting StandardScaler on Train split...
# [GPU 1] Saved scaler to outputs/scaler_cicids.pkl
# [GPU 1] [OK] Will generate 863165 windows lazily during training
# [GPU 1] [VAL] Loading from cache: outputs/cache/cicids2017_val.npz
# [GPU 1]   Cached shape: (123316, 77), labels: 123316
# [GPU 1] [VAL] Raw shape (before windowing): (123316, 77)
# [GPU 1] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 1] [OK] Will generate 123267 windows lazily during training
# [GPU 1] [TEST] Loading from cache: outputs/cache/cicids2017_test.npz
# [GPU 1]   Cached shape: (246633, 77), labels: 246633
# [GPU 1] [TEST] Raw shape (before windowing): (246633, 77)
# [GPU 1] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 1] [OK] Will generate 246584 windows lazily during training
# [GPU 1]   Features: 77, Train: 863165, Val: 123267, Test: 246584
# [GPU 1] [2/5] Initializing Transformer (d_model=128, n_layers=2)...
# [GPU 1]   Parameters: 406,913
# [GPU 1] [3/5] Training Transformer...
# [GPU 1]   LR: 0.000300 (base=0.001 × 0.3 for Transformer), grad_clip=0.5
# [GPU 1]   Using class-weighted loss (pos_weight=1.00)
# [GPU 0]   Epoch   9/30 | TrLoss: 0.0018 | VlLoss: 0.0280 | VlAcc: 0.9885 | VlF1: 0.9940
# [GPU 0]   Early stopping at epoch 9 (patience=5)
# [GPU 0]   Best Val F1: 0.9983 (9 epochs, 5959.2s)
# [GPU 0]   💾 Model saved to: outputs/checkpoints/CICIDS2017_Mamba_seed42.pt
# [GPU 0] [4/5] Evaluating on test set...
# [GPU 0]   Test Acc: 0.9726 | Prec: 0.7842 | Rec: 0.9573 | F1: 0.8621 | AUC: 0.9798
# [GPU 0] [5/5] Measuring efficiency...
# [GPU 0]   Latency: 16.73ms | Throughput: 1873/s | Memory: 1.48MB
# [GPU 1]   Epoch   1/30 | TrLoss: 0.1020 | VlLoss: 0.1808 | VlAcc: 0.9642 | VlF1: 0.9818 *
# [GPU 0]   Attack types analyzed: 3
# [GPU 0]
# [GPU 0] [2/18] Running experiment...
# [GPU 0]
# [GPU 0] ======================================================================
# [GPU 0]   Dataset: CICIDS2017 | Model: LSTM | Seed: 42
# [GPU 0] ======================================================================
# [GPU 0] [Reproducibility] Setting all random seeds to 42
# [GPU 0] [Reproducibility] [OK] All seeds set and deterministic mode enabled
# [GPU 0] [1/5] Loading CICIDS2017 dataset...
# [GPU 0] [TRAIN] Loading from cache: outputs/cache/cicids2017_train.npz
# [GPU 0]   Cached shape: (863214, 77), labels: 863214
# [GPU 0] [TRAIN] Raw shape (before windowing): (863214, 77)
# [GPU 0] Fitting StandardScaler on Train split...
# [GPU 0] Saved scaler to outputs/scaler_cicids.pkl
# [GPU 0] [OK] Will generate 863165 windows lazily during training
# [GPU 0] [VAL] Loading from cache: outputs/cache/cicids2017_val.npz
# [GPU 0]   Cached shape: (123316, 77), labels: 123316
# [GPU 0] [VAL] Raw shape (before windowing): (123316, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 123267 windows lazily during training
# [GPU 0] [TEST] Loading from cache: outputs/cache/cicids2017_test.npz
# [GPU 0]   Cached shape: (246633, 77), labels: 246633
# [GPU 0] [TEST] Raw shape (before windowing): (246633, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 246584 windows lazily during training
# [GPU 0]   Features: 77, Train: 863165, Val: 123267, Test: 246584
# [GPU 0] [2/5] Initializing LSTM (d_model=128, n_layers=2)...
# [GPU 0]   Parameters: 423,169
# [GPU 0] [3/5] Training LSTM...
# [GPU 0]   LR: 0.001000 (base=0.001 × 1.0 for LSTM), grad_clip=1.0
# [GPU 0]   Using class-weighted loss (pos_weight=1.00)
# [GPU 0]   Epoch   1/30 | TrLoss: 0.0367 | VlLoss: 0.1839 | VlAcc: 0.9642 | VlF1: 0.9818 *
# [GPU 1]   Epoch   2/30 | TrLoss: 0.0603 | VlLoss: 0.1899 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 0]   Epoch   2/30 | TrLoss: 0.0473 | VlLoss: 0.1846 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 1]   Epoch   3/30 | TrLoss: 0.0632 | VlLoss: 0.1951 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 0]   Epoch   3/30 | TrLoss: 0.0373 | VlLoss: 0.1810 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 1]   Epoch   4/30 | TrLoss: 0.0519 | VlLoss: 0.1937 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 0]   Epoch   4/30 | TrLoss: 0.0341 | VlLoss: 0.1802 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 1]   Epoch   5/30 | TrLoss: 0.0701 | VlLoss: 0.1965 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 0]   Epoch   5/30 | TrLoss: 0.0596 | VlLoss: 0.1866 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 1]   Epoch   6/30 | TrLoss: 0.0605 | VlLoss: 0.1833 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 1]   Early stopping at epoch 6 (patience=5)
# [GPU 1]   Best Val F1: 0.9818 (6 epochs, 659.4s)
# [GPU 1]   💾 Model saved to: outputs/checkpoints/CICIDS2017_Transformer_seed789.pt
# [GPU 1] [4/5] Evaluating on test set...
# [GPU 0]   Epoch   6/30 | TrLoss: 0.0390 | VlLoss: 0.1840 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 0]   Early stopping at epoch 6 (patience=5)
# [GPU 0]   Best Val F1: 0.9818 (6 epochs, 541.1s)
# [GPU 0]   💾 Model saved to: outputs/checkpoints/CICIDS2017_LSTM_seed42.pt
# [GPU 0] [4/5] Evaluating on test set...
# [GPU 1]   Test Acc: 0.0894 | Prec: 0.0894 | Rec: 1.0000 | F1: 0.1640 | AUC: 0.9216
# [GPU 1] [5/5] Measuring efficiency...
# [GPU 1]   Latency: 1.17ms | Throughput: 25918/s | Memory: 1.55MB
# [GPU 0]   Test Acc: 0.0895 | Prec: 0.0894 | Rec: 1.0000 | F1: 0.1641 | AUC: 0.4995
# [GPU 0] [5/5] Measuring efficiency...
# [GPU 0]   Latency: 0.75ms | Throughput: 30849/s | Memory: 1.61MB
# [GPU 1]   Attack types analyzed: 3
# [GPU 1]
# [GPU 1] [5/12] Running experiment...
# [GPU 1]
# [GPU 1] ======================================================================
# [GPU 1]   Dataset: CICIDS2017 | Model: CNN-LSTM | Seed: 789
# [GPU 1] ======================================================================
# [GPU 1] [Reproducibility] Setting all random seeds to 789
# [GPU 1] [Reproducibility] [OK] All seeds set and deterministic mode enabled
# [GPU 1] [1/5] Loading CICIDS2017 dataset...
# [GPU 1] [TRAIN] Loading from cache: outputs/cache/cicids2017_train.npz
# [GPU 1]   Cached shape: (863214, 77), labels: 863214
# [GPU 1] [TRAIN] Raw shape (before windowing): (863214, 77)
# [GPU 1] Fitting StandardScaler on Train split...
# [GPU 1] Saved scaler to outputs/scaler_cicids.pkl
# [GPU 1] [OK] Will generate 863165 windows lazily during training
# [GPU 1] [VAL] Loading from cache: outputs/cache/cicids2017_val.npz
# [GPU 1]   Cached shape: (123316, 77), labels: 123316
# [GPU 1] [VAL] Raw shape (before windowing): (123316, 77)
# [GPU 1] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 1] [OK] Will generate 123267 windows lazily during training
# [GPU 1] [TEST] Loading from cache: outputs/cache/cicids2017_test.npz
# [GPU 1]   Cached shape: (246633, 77), labels: 246633
# [GPU 1] [TEST] Raw shape (before windowing): (246633, 77)
# [GPU 1] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 1] [OK] Will generate 246584 windows lazily during training
# [GPU 1]   Features: 77, Train: 863165, Val: 123267, Test: 246584
# [GPU 1] [2/5] Initializing CNN-LSTM (d_model=128, n_layers=2)...
# [GPU 1]   Parameters: 409,601
# [GPU 1] [3/5] Training CNN-LSTM...
# [GPU 1]   LR: 0.000500 (base=0.001 × 0.5 for CNN-LSTM), grad_clip=0.5
# [GPU 1]   Using class-weighted loss (pos_weight=1.00)
# [GPU 0]   Attack types analyzed: 3
# [GPU 0]
# [GPU 0] [3/18] Running experiment...
# [GPU 0]
# [GPU 0] ======================================================================
# [GPU 0]   Dataset: CICIDS2017 | Model: GRU | Seed: 42
# [GPU 0] ======================================================================
# [GPU 0] [Reproducibility] Setting all random seeds to 42
# [GPU 0] [Reproducibility] [OK] All seeds set and deterministic mode enabled
# [GPU 0] [1/5] Loading CICIDS2017 dataset...
# [GPU 0] [TRAIN] Loading from cache: outputs/cache/cicids2017_train.npz
# [GPU 0]   Cached shape: (863214, 77), labels: 863214
# [GPU 0] [TRAIN] Raw shape (before windowing): (863214, 77)
# [GPU 0] Fitting StandardScaler on Train split...
# [GPU 0] Saved scaler to outputs/scaler_cicids.pkl
# [GPU 0] [OK] Will generate 863165 windows lazily during training
# [GPU 0] [VAL] Loading from cache: outputs/cache/cicids2017_val.npz
# [GPU 0]   Cached shape: (123316, 77), labels: 123316
# [GPU 0] [VAL] Raw shape (before windowing): (123316, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 123267 windows lazily during training
# [GPU 0] [TEST] Loading from cache: outputs/cache/cicids2017_test.npz
# [GPU 0]   Cached shape: (246633, 77), labels: 246633
# [GPU 0] [TEST] Raw shape (before windowing): (246633, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 246584 windows lazily during training
# [GPU 0]   Features: 77, Train: 863165, Val: 123267, Test: 246584
# [GPU 0] [2/5] Initializing GRU (d_model=128, n_layers=2)...
# [GPU 0]   Parameters: 373,505
# [GPU 0] [3/5] Training GRU...
# [GPU 0]   LR: 0.001000 (base=0.001 × 1.0 for GRU), grad_clip=1.0
# [GPU 0]   Using class-weighted loss (pos_weight=1.00)
# [GPU 0]   Epoch   1/30 | TrLoss: 0.0343 | VlLoss: 0.1800 | VlAcc: 0.9642 | VlF1: 0.9818 *
# [GPU 1]   Epoch   1/30 | TrLoss: 0.0825 | VlLoss: 0.4052 | VlAcc: 0.9575 | VlF1: 0.9778 *
# [GPU 0]   Epoch   2/30 | TrLoss: 0.0634 | VlLoss: 0.1867 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 1]   Epoch   2/30 | TrLoss: 0.0503 | VlLoss: 0.8013 | VlAcc: 0.3734 | VlF1: 0.5203
# [GPU 0]   Epoch   3/30 | TrLoss: 0.0377 | VlLoss: 0.1813 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 1]   Epoch   3/30 | TrLoss: 0.0167 | VlLoss: 0.2414 | VlAcc: 0.9844 | VlF1: 0.9919 *
# [GPU 0]   Epoch   4/30 | TrLoss: 0.0346 | VlLoss: 0.1825 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 0]   Epoch   5/30 | TrLoss: 0.0412 | VlLoss: 0.1497 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 1]   Epoch   4/30 | TrLoss: 0.0177 | VlLoss: 1.4736 | VlAcc: 0.3572 | VlF1: 0.5018
# [GPU 0]   Epoch   6/30 | TrLoss: 0.0230 | VlLoss: 0.1147 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 0]   Early stopping at epoch 6 (patience=5)
# [GPU 0]   Best Val F1: 0.9818 (6 epochs, 432.9s)
# [GPU 0]   💾 Model saved to: outputs/checkpoints/CICIDS2017_GRU_seed42.pt
# [GPU 0] [4/5] Evaluating on test set...
# [GPU 0]   Test Acc: 0.0894 | Prec: 0.0893 | Rec: 1.0000 | F1: 0.1640 | AUC: 0.5190
# [GPU 0] [5/5] Measuring efficiency...
# [GPU 0]   Latency: 0.50ms | Throughput: 43813/s | Memory: 1.42MB
# [GPU 0]   Attack types analyzed: 3
# [GPU 0]
# [GPU 0] [4/18] Running experiment...
# [GPU 0]
# [GPU 0] ======================================================================
# [GPU 0]   Dataset: CICIDS2017 | Model: Transformer | Seed: 42
# [GPU 0] ======================================================================
# [GPU 0] [Reproducibility] Setting all random seeds to 42
# [GPU 0] [Reproducibility] [OK] All seeds set and deterministic mode enabled
# [GPU 0] [1/5] Loading CICIDS2017 dataset...
# [GPU 0] [TRAIN] Loading from cache: outputs/cache/cicids2017_train.npz
# [GPU 0]   Cached shape: (863214, 77), labels: 863214
# [GPU 0] [TRAIN] Raw shape (before windowing): (863214, 77)
# [GPU 0] Fitting StandardScaler on Train split...
# [GPU 0] Saved scaler to outputs/scaler_cicids.pkl
# [GPU 0] [OK] Will generate 863165 windows lazily during training
# [GPU 0] [VAL] Loading from cache: outputs/cache/cicids2017_val.npz
# [GPU 0]   Cached shape: (123316, 77), labels: 123316
# [GPU 0] [VAL] Raw shape (before windowing): (123316, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 123267 windows lazily during training
# [GPU 0] [TEST] Loading from cache: outputs/cache/cicids2017_test.npz
# [GPU 0]   Cached shape: (246633, 77), labels: 246633
# [GPU 0] [TEST] Raw shape (before windowing): (246633, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 246584 windows lazily during training
# [GPU 0]   Features: 77, Train: 863165, Val: 123267, Test: 246584
# [GPU 0] [2/5] Initializing Transformer (d_model=128, n_layers=2)...
# [GPU 0]   Parameters: 406,913
# [GPU 0] [3/5] Training Transformer...
# [GPU 0]   LR: 0.000300 (base=0.001 × 0.3 for Transformer), grad_clip=0.5
# [GPU 0]   Using class-weighted loss (pos_weight=1.00)
# [GPU 1]   Epoch   5/30 | TrLoss: 0.0044 | VlLoss: 0.8847 | VlAcc: 0.4480 | VlF1: 0.6004
# [GPU 1]   Epoch   6/30 | TrLoss: 0.0036 | VlLoss: 0.0258 | VlAcc: 0.9942 | VlF1: 0.9970 *
# [GPU 0]   Epoch   1/30 | TrLoss: 0.1064 | VlLoss: 0.1935 | VlAcc: 0.9642 | VlF1: 0.9818 *
# [GPU 1]   Epoch   7/30 | TrLoss: 0.0023 | VlLoss: 0.0285 | VlAcc: 0.9941 | VlF1: 0.9970
# [GPU 0]   Epoch   2/30 | TrLoss: 0.0587 | VlLoss: 0.1925 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 1]   Epoch   8/30 | TrLoss: 0.0018 | VlLoss: 0.0298 | VlAcc: 0.9944 | VlF1: 0.9971 *
# [GPU 0]   Epoch   3/30 | TrLoss: 0.0501 | VlLoss: 0.1893 | VlAcc: 0.9642 | VlF1: 0.9818 *
# [GPU 1]   Epoch   9/30 | TrLoss: 0.0020 | VlLoss: 0.0339 | VlAcc: 0.9946 | VlF1: 0.9972 *
# [GPU 0]   Epoch   4/30 | TrLoss: 0.0450 | VlLoss: 0.1943 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 1]   Epoch  10/30 | TrLoss: 0.0018 | VlLoss: 0.0329 | VlAcc: 0.9950 | VlF1: 0.9974 *
# [GPU 0]   Epoch   5/30 | TrLoss: 0.0610 | VlLoss: 0.1951 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 1]   Epoch  11/30 | TrLoss: 0.0013 | VlLoss: 0.0306 | VlAcc: 0.9949 | VlF1: 0.9974
# [GPU 0]   Epoch   6/30 | TrLoss: 0.0445 | VlLoss: 0.1690 | VlAcc: 0.9636 | VlF1: 0.9815
# [GPU 1]   Epoch  12/30 | TrLoss: 0.0018 | VlLoss: 0.0234 | VlAcc: 0.9965 | VlF1: 0.9982 *
# [GPU 0]   Epoch   7/30 | TrLoss: 0.0381 | VlLoss: 0.7157 | VlAcc: 0.3522 | VlF1: 0.5010
# [GPU 1]   Epoch  13/30 | TrLoss: 0.0015 | VlLoss: 0.0303 | VlAcc: 0.9963 | VlF1: 0.9981
# [GPU 0]   Epoch   8/30 | TrLoss: 0.0422 | VlLoss: 0.2302 | VlAcc: 0.9641 | VlF1: 0.9817
# [GPU 0]   Early stopping at epoch 8 (patience=5)
# [GPU 0]   Best Val F1: 0.9818 (8 epochs, 835.0s)
# [GPU 0]   💾 Model saved to: outputs/checkpoints/CICIDS2017_Transformer_seed42.pt
# [GPU 0] [4/5] Evaluating on test set...
# [GPU 0]   Test Acc: 0.0893 | Prec: 0.0893 | Rec: 0.9992 | F1: 0.1639 | AUC: 0.3965
# [GPU 0] [5/5] Measuring efficiency...
# [GPU 0]   Latency: 1.30ms | Throughput: 25978/s | Memory: 1.55MB
# [GPU 0]   Attack types analyzed: 3
# [GPU 0]
# [GPU 0] [5/18] Running experiment...
# [GPU 0]
# [GPU 0] ======================================================================
# [GPU 0]   Dataset: CICIDS2017 | Model: CNN-LSTM | Seed: 42
# [GPU 0] ======================================================================
# [GPU 0] [Reproducibility] Setting all random seeds to 42
# [GPU 0] [Reproducibility] [OK] All seeds set and deterministic mode enabled
# [GPU 0] [1/5] Loading CICIDS2017 dataset...
# [GPU 0] [TRAIN] Loading from cache: outputs/cache/cicids2017_train.npz
# [GPU 0]   Cached shape: (863214, 77), labels: 863214
# [GPU 0] [TRAIN] Raw shape (before windowing): (863214, 77)
# [GPU 0] Fitting StandardScaler on Train split...
# [GPU 0] Saved scaler to outputs/scaler_cicids.pkl
# [GPU 0] [OK] Will generate 863165 windows lazily during training
# [GPU 0] [VAL] Loading from cache: outputs/cache/cicids2017_val.npz
# [GPU 0]   Cached shape: (123316, 77), labels: 123316
# [GPU 0] [VAL] Raw shape (before windowing): (123316, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 123267 windows lazily during training
# [GPU 0] [TEST] Loading from cache: outputs/cache/cicids2017_test.npz
# [GPU 0]   Cached shape: (246633, 77), labels: 246633
# [GPU 0] [TEST] Raw shape (before windowing): (246633, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 246584 windows lazily during training
# [GPU 0]   Features: 77, Train: 863165, Val: 123267, Test: 246584
# [GPU 0] [2/5] Initializing CNN-LSTM (d_model=128, n_layers=2)...
# [GPU 0]   Parameters: 409,601
# [GPU 0] [3/5] Training CNN-LSTM...
# [GPU 0]   LR: 0.000500 (base=0.001 × 0.5 for CNN-LSTM), grad_clip=0.5
# [GPU 0]   Using class-weighted loss (pos_weight=1.00)
# [GPU 1]   Epoch  14/30 | TrLoss: 0.0010 | VlLoss: 0.0266 | VlAcc: 0.9965 | VlF1: 0.9982 *
# [GPU 0]   Epoch   1/30 | TrLoss: 0.0809 | VlLoss: 0.1745 | VlAcc: 0.9642 | VlF1: 0.9818 *
# [GPU 1]   Epoch  15/30 | TrLoss: 0.0009 | VlLoss: 0.0204 | VlAcc: 0.9970 | VlF1: 0.9985 *
# [GPU 0]   Epoch   2/30 | TrLoss: 0.0457 | VlLoss: 0.1207 | VlAcc: 0.9804 | VlF1: 0.9899 *
# [GPU 1]   Epoch  16/30 | TrLoss: 0.0009 | VlLoss: 0.0274 | VlAcc: 0.9960 | VlF1: 0.9979
# [GPU 0]   Epoch   3/30 | TrLoss: 0.0395 | VlLoss: 0.1103 | VlAcc: 0.9816 | VlF1: 0.9905 *
# [GPU 1]   Epoch  17/30 | TrLoss: 0.0007 | VlLoss: 0.0324 | VlAcc: 0.9963 | VlF1: 0.9981
# [GPU 0]   Epoch   4/30 | TrLoss: 0.0151 | VlLoss: 0.0507 | VlAcc: 0.9931 | VlF1: 0.9964 *
# [GPU 1]   Epoch  18/30 | TrLoss: 0.0007 | VlLoss: 0.0349 | VlAcc: 0.9945 | VlF1: 0.9971
# [GPU 0]   Epoch   5/30 | TrLoss: 0.0099 | VlLoss: 0.2716 | VlAcc: 0.8886 | VlF1: 0.9389
# [GPU 1]   Epoch  19/30 | TrLoss: 0.0005 | VlLoss: 0.0334 | VlAcc: 0.9961 | VlF1: 0.9980
# [GPU 0]   Epoch   6/30 | TrLoss: 0.0032 | VlLoss: 0.0677 | VlAcc: 0.9946 | VlF1: 0.9972 *
# [GPU 1]   Epoch  20/30 | TrLoss: 0.0004 | VlLoss: 0.0333 | VlAcc: 0.9956 | VlF1: 0.9977
# [GPU 1]   Early stopping at epoch 20 (patience=5)
# [GPU 1]   Best Val F1: 0.9985 (20 epochs, 1896.9s)
# [GPU 1]   💾 Model saved to: outputs/checkpoints/CICIDS2017_CNN-LSTM_seed789.pt
# [GPU 1] [4/5] Evaluating on test set...
# [GPU 1]   Test Acc: 0.9729 | Prec: 0.7962 | Rec: 0.9361 | F1: 0.8605 | AUC: 0.9747
# [GPU 1] [5/5] Measuring efficiency...
# [GPU 1]   Latency: 0.90ms | Throughput: 31031/s | Memory: 1.56MB
# [GPU 1]   Attack types analyzed: 3
# [GPU 1]
# [GPU 1] [6/12] Running experiment...
# [GPU 1]
# [GPU 1] ======================================================================
# [GPU 1]   Dataset: CICIDS2017 | Model: TCN | Seed: 789
# [GPU 1] ======================================================================
# [GPU 1] [Reproducibility] Setting all random seeds to 789
# [GPU 1] [Reproducibility] [OK] All seeds set and deterministic mode enabled
# [GPU 1] [1/5] Loading CICIDS2017 dataset...
# [GPU 1] [TRAIN] Loading from cache: outputs/cache/cicids2017_train.npz
# [GPU 1]   Cached shape: (863214, 77), labels: 863214
# [GPU 1] [TRAIN] Raw shape (before windowing): (863214, 77)
# [GPU 1] Fitting StandardScaler on Train split...
# [GPU 1] Saved scaler to outputs/scaler_cicids.pkl
# [GPU 1] [OK] Will generate 863165 windows lazily during training
# [GPU 1] [VAL] Loading from cache: outputs/cache/cicids2017_val.npz
# [GPU 1]   Cached shape: (123316, 77), labels: 123316
# [GPU 1] [VAL] Raw shape (before windowing): (123316, 77)
# [GPU 1] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 1] [OK] Will generate 123267 windows lazily during training
# [GPU 1] [TEST] Loading from cache: outputs/cache/cicids2017_test.npz
# [GPU 1]   Cached shape: (246633, 77), labels: 246633
# [GPU 1] [TEST] Raw shape (before windowing): (246633, 77)
# [GPU 1] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 1] [OK] Will generate 246584 windows lazily during training
# [GPU 1]   Features: 77, Train: 863165, Val: 123267, Test: 246584
# [GPU 1] [2/5] Initializing TCN (d_model=128, n_layers=2)...
# [GPU 1]   Parameters: 423,169
# [GPU 1] [3/5] Training TCN...
# [GPU 1]   LR: 0.000500 (base=0.001 × 0.5 for TCN), grad_clip=1.0
# [GPU 1]   Using class-weighted loss (pos_weight=1.00)
# [GPU 0]   Epoch   7/30 | TrLoss: 0.0023 | VlLoss: 0.0264 | VlAcc: 0.9948 | VlF1: 0.9973 *
# [GPU 0]   Epoch   8/30 | TrLoss: 0.0020 | VlLoss: 0.0281 | VlAcc: 0.9948 | VlF1: 0.9973
# [GPU 1]   Epoch   1/30 | TrLoss: 0.0382 | VlLoss: 0.0512 | VlAcc: 0.9790 | VlF1: 0.9890 *
# [GPU 0]   Epoch   9/30 | TrLoss: 0.0018 | VlLoss: 0.0222 | VlAcc: 0.9959 | VlF1: 0.9979 *
# [GPU 1]   Epoch   2/30 | TrLoss: 0.0189 | VlLoss: 0.0428 | VlAcc: 0.9879 | VlF1: 0.9937 *
# [GPU 0]   Epoch  10/30 | TrLoss: 0.0014 | VlLoss: 0.0221 | VlAcc: 0.9963 | VlF1: 0.9981 *
# [GPU 1]   Epoch   3/30 | TrLoss: 0.0124 | VlLoss: 0.1423 | VlAcc: 0.9893 | VlF1: 0.9944 *
# [GPU 0]   Epoch  11/30 | TrLoss: 0.0013 | VlLoss: 0.0273 | VlAcc: 0.9959 | VlF1: 0.9979
# [GPU 0]   Epoch  12/30 | TrLoss: 0.0011 | VlLoss: 0.0297 | VlAcc: 0.9957 | VlF1: 0.9978
# [GPU 1]   Epoch   4/30 | TrLoss: 0.0054 | VlLoss: 0.0624 | VlAcc: 0.9893 | VlF1: 0.9944 *
# [GPU 0]   Epoch  13/30 | TrLoss: 0.0010 | VlLoss: 0.0202 | VlAcc: 0.9966 | VlF1: 0.9982 *
# [GPU 1]   Epoch   5/30 | TrLoss: 0.0031 | VlLoss: 0.0819 | VlAcc: 0.9773 | VlF1: 0.9884
# [GPU 0]   Epoch  14/30 | TrLoss: 0.0010 | VlLoss: 0.0218 | VlAcc: 0.9961 | VlF1: 0.9980
# [GPU 1]   Epoch   6/30 | TrLoss: 0.0027 | VlLoss: 0.1042 | VlAcc: 0.9893 | VlF1: 0.9944 *
# [GPU 0]   Epoch  15/30 | TrLoss: 0.0009 | VlLoss: 0.0412 | VlAcc: 0.9939 | VlF1: 0.9968
# [GPU 0]   Epoch  16/30 | TrLoss: 0.0008 | VlLoss: 0.0265 | VlAcc: 0.9950 | VlF1: 0.9974
# [GPU 1]   Epoch   7/30 | TrLoss: 0.0020 | VlLoss: 0.0879 | VlAcc: 0.9831 | VlF1: 0.9913
# [GPU 0]   Epoch  17/30 | TrLoss: 0.0005 | VlLoss: 0.0226 | VlAcc: 0.9961 | VlF1: 0.9980
# [GPU 1]   Epoch   8/30 | TrLoss: 0.0016 | VlLoss: 0.0653 | VlAcc: 0.9785 | VlF1: 0.9889
# [GPU 0]   Epoch  18/30 | TrLoss: 0.0004 | VlLoss: 0.0205 | VlAcc: 0.9962 | VlF1: 0.9980
# [GPU 0]   Early stopping at epoch 18 (patience=5)
# [GPU 0]   Best Val F1: 0.9982 (18 epochs, 1572.5s)
# [GPU 0]   💾 Model saved to: outputs/checkpoints/CICIDS2017_CNN-LSTM_seed42.pt
# [GPU 0] [4/5] Evaluating on test set...
# [GPU 0]   Test Acc: 0.9721 | Prec: 0.7871 | Rec: 0.9429 | F1: 0.8580 | AUC: 0.9770
# [GPU 0] [5/5] Measuring efficiency...
# [GPU 0]   Latency: 0.99ms | Throughput: 33118/s | Memory: 1.56MB
# [GPU 0]   Attack types analyzed: 3
# [GPU 0]
# [GPU 0] [6/18] Running experiment...
# [GPU 0]
# [GPU 0] ======================================================================
# [GPU 0]   Dataset: CICIDS2017 | Model: TCN | Seed: 42
# [GPU 0] ======================================================================
# [GPU 0] [Reproducibility] Setting all random seeds to 42
# [GPU 0] [Reproducibility] [OK] All seeds set and deterministic mode enabled
# [GPU 0] [1/5] Loading CICIDS2017 dataset...
# [GPU 0] [TRAIN] Loading from cache: outputs/cache/cicids2017_train.npz
# [GPU 0]   Cached shape: (863214, 77), labels: 863214
# [GPU 0] [TRAIN] Raw shape (before windowing): (863214, 77)
# [GPU 0] Fitting StandardScaler on Train split...
# [GPU 0] Saved scaler to outputs/scaler_cicids.pkl
# [GPU 0] [OK] Will generate 863165 windows lazily during training
# [GPU 0] [VAL] Loading from cache: outputs/cache/cicids2017_val.npz
# [GPU 0]   Cached shape: (123316, 77), labels: 123316
# [GPU 0] [VAL] Raw shape (before windowing): (123316, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 123267 windows lazily during training
# [GPU 0] [TEST] Loading from cache: outputs/cache/cicids2017_test.npz
# [GPU 0]   Cached shape: (246633, 77), labels: 246633
# [GPU 0] [TEST] Raw shape (before windowing): (246633, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 246584 windows lazily during training
# [GPU 0]   Features: 77, Train: 863165, Val: 123267, Test: 246584
# [GPU 0] [2/5] Initializing TCN (d_model=128, n_layers=2)...
# [GPU 0]   Parameters: 423,169
# [GPU 0] [3/5] Training TCN...
# [GPU 0]   LR: 0.000500 (base=0.001 × 0.5 for TCN), grad_clip=1.0
# [GPU 0]   Using class-weighted loss (pos_weight=1.00)
# [GPU 1]   Epoch   9/30 | TrLoss: 0.0013 | VlLoss: 0.0768 | VlAcc: 0.9755 | VlF1: 0.9874
# [GPU 0]   Epoch   1/30 | TrLoss: 0.0327 | VlLoss: 0.0974 | VlAcc: 0.9751 | VlF1: 0.9873 *
# [GPU 1]   Epoch  10/30 | TrLoss: 0.0012 | VlLoss: 0.0603 | VlAcc: 0.9796 | VlF1: 0.9895
# [GPU 0]   Epoch   2/30 | TrLoss: 0.0259 | VlLoss: 0.0587 | VlAcc: 0.9786 | VlF1: 0.9890 *
# [GPU 1]   Epoch  11/30 | TrLoss: 0.0009 | VlLoss: 0.0729 | VlAcc: 0.9792 | VlF1: 0.9893
# [GPU 1]   Early stopping at epoch 11 (patience=5)
# [GPU 1]   Best Val F1: 0.9944 (11 epochs, 1279.4s)
# [GPU 1]   💾 Model saved to: outputs/checkpoints/CICIDS2017_TCN_seed789.pt
# [GPU 1] [4/5] Evaluating on test set...
# [GPU 1]   Test Acc: 0.8992 | Prec: 0.4684 | Rec: 0.9504 | F1: 0.6275 | AUC: 0.9683
# [GPU 1] [5/5] Measuring efficiency...
# [GPU 1]   Latency: 2.23ms | Throughput: 14846/s | Memory: 1.61MB
# [GPU 1]   Attack types analyzed: 3
# [GPU 1]
# [GPU 1] [7/12] Running experiment...
# [GPU 1]
# [GPU 1] ======================================================================
# [GPU 1]   Dataset: CICIDS2017 | Model: Mamba | Seed: 1024
# [GPU 1] ======================================================================
# [GPU 1] [Reproducibility] Setting all random seeds to 1024
# [GPU 1] [Reproducibility] [OK] All seeds set and deterministic mode enabled
# [GPU 1] [1/5] Loading CICIDS2017 dataset...
# [GPU 1] [TRAIN] Loading from cache: outputs/cache/cicids2017_train.npz
# [GPU 1]   Cached shape: (863214, 77), labels: 863214
# [GPU 1] [TRAIN] Raw shape (before windowing): (863214, 77)
# [GPU 1] Fitting StandardScaler on Train split...
# [GPU 1] Saved scaler to outputs/scaler_cicids.pkl
# [GPU 1] [OK] Will generate 863165 windows lazily during training
# [GPU 1] [VAL] Loading from cache: outputs/cache/cicids2017_val.npz
# [GPU 1]   Cached shape: (123316, 77), labels: 123316
# [GPU 1] [VAL] Raw shape (before windowing): (123316, 77)
# [GPU 1] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 1] [OK] Will generate 123267 windows lazily during training
# [GPU 1] [TEST] Loading from cache: outputs/cache/cicids2017_test.npz
# [GPU 1]   Cached shape: (246633, 77), labels: 246633
# [GPU 1] [TEST] Raw shape (before windowing): (246633, 77)
# [GPU 1] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 1] [OK] Will generate 246584 windows lazily during training
# [GPU 1]   Features: 77, Train: 863165, Val: 123267, Test: 246584
# [GPU 1] [2/5] Initializing Mamba (d_model=128, n_layers=2)...
# [GPU 1]   Parameters: 387,073
# [GPU 1] [3/5] Training Mamba...
# [GPU 1]   LR: 0.000300 (base=0.001 × 0.3 for Mamba), grad_clip=0.5
# [GPU 1]   Using class-weighted loss (pos_weight=1.00)
# [GPU 0]   Epoch   3/30 | TrLoss: 0.0116 | VlLoss: 0.1579 | VlAcc: 0.9784 | VlF1: 0.9888
# [GPU 0]   Epoch   4/30 | TrLoss: 0.0053 | VlLoss: 0.0573 | VlAcc: 0.9806 | VlF1: 0.9900 *
# [GPU 0]   Epoch   5/30 | TrLoss: 0.0040 | VlLoss: 0.0934 | VlAcc: 0.9776 | VlF1: 0.9885
# [GPU 0]   Epoch   6/30 | TrLoss: 0.0029 | VlLoss: 0.1239 | VlAcc: 0.9762 | VlF1: 0.9877
# [GPU 0]   Epoch   7/30 | TrLoss: 0.0026 | VlLoss: 0.1445 | VlAcc: 0.9773 | VlF1: 0.9883
# [GPU 0]   Epoch   8/30 | TrLoss: 0.0021 | VlLoss: 0.1522 | VlAcc: 0.9766 | VlF1: 0.9879
# [GPU 1]   Epoch   1/30 | TrLoss: 0.0209 | VlLoss: 0.0357 | VlAcc: 0.9952 | VlF1: 0.9975 *
# [GPU 0]   Epoch   9/30 | TrLoss: 0.0014 | VlLoss: 0.1563 | VlAcc: 0.9778 | VlF1: 0.9886
# [GPU 0]   Early stopping at epoch 9 (patience=5)
# [GPU 0]   Best Val F1: 0.9900 (9 epochs, 986.9s)
# [GPU 0]   💾 Model saved to: outputs/checkpoints/CICIDS2017_TCN_seed42.pt
# [GPU 0] [4/5] Evaluating on test set...
# [GPU 0]   Test Acc: 0.5014 | Prec: 0.1493 | Rec: 0.9748 | F1: 0.2589 | AUC: 0.9688
# [GPU 0] [5/5] Measuring efficiency...
# [GPU 0]   Latency: 1.73ms | Throughput: 16754/s | Memory: 1.61MB
# [GPU 0]   Attack types analyzed: 3
# [GPU 0]
# [GPU 0] [7/18] Running experiment...
# [GPU 0]
# [GPU 0] ======================================================================
# [GPU 0]   Dataset: CICIDS2017 | Model: Mamba | Seed: 123
# [GPU 0] ======================================================================
# [GPU 0] [Reproducibility] Setting all random seeds to 123
# [GPU 0] [Reproducibility] [OK] All seeds set and deterministic mode enabled
# [GPU 0] [1/5] Loading CICIDS2017 dataset...
# [GPU 0] [TRAIN] Loading from cache: outputs/cache/cicids2017_train.npz
# [GPU 0]   Cached shape: (863214, 77), labels: 863214
# [GPU 0] [TRAIN] Raw shape (before windowing): (863214, 77)
# [GPU 0] Fitting StandardScaler on Train split...
# [GPU 0] Saved scaler to outputs/scaler_cicids.pkl
# [GPU 0] [OK] Will generate 863165 windows lazily during training
# [GPU 0] [VAL] Loading from cache: outputs/cache/cicids2017_val.npz
# [GPU 0]   Cached shape: (123316, 77), labels: 123316
# [GPU 0] [VAL] Raw shape (before windowing): (123316, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 123267 windows lazily during training
# [GPU 0] [TEST] Loading from cache: outputs/cache/cicids2017_test.npz
# [GPU 0]   Cached shape: (246633, 77), labels: 246633
# [GPU 0] [TEST] Raw shape (before windowing): (246633, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 246584 windows lazily during training
# [GPU 0]   Features: 77, Train: 863165, Val: 123267, Test: 246584
# [GPU 0] [2/5] Initializing Mamba (d_model=128, n_layers=2)...
# [GPU 0]   Parameters: 387,073
# [GPU 0] [3/5] Training Mamba...
# [GPU 0]   LR: 0.000300 (base=0.001 × 0.3 for Mamba), grad_clip=0.5
# [GPU 0]   Using class-weighted loss (pos_weight=1.00)
# [GPU 1]   Epoch   2/30 | TrLoss: 0.0076 | VlLoss: 0.0192 | VlAcc: 0.9962 | VlF1: 0.9980 *
# [GPU 0]   Epoch   1/30 | TrLoss: 0.0183 | VlLoss: 0.0184 | VlAcc: 0.9972 | VlF1: 0.9986 *
# [GPU 0]   Epoch   2/30 | TrLoss: 0.0201 | VlLoss: 0.0651 | VlAcc: 0.9884 | VlF1: 0.9940
# [GPU 1]   Epoch   3/30 | TrLoss: 0.0140 | VlLoss: 0.0263 | VlAcc: 0.9949 | VlF1: 0.9973
# [GPU 0]   Epoch   3/30 | TrLoss: 0.0407 | VlLoss: 0.0154 | VlAcc: 0.9957 | VlF1: 0.9978
# [GPU 1]   Epoch   4/30 | TrLoss: 0.0056 | VlLoss: 0.0220 | VlAcc: 0.9946 | VlF1: 0.9972
# [GPU 0]   Epoch   4/30 | TrLoss: 0.0126 | VlLoss: 0.0404 | VlAcc: 0.9897 | VlF1: 0.9947
# [GPU 1]   Epoch   5/30 | TrLoss: 0.0053 | VlLoss: 0.0161 | VlAcc: 0.9972 | VlF1: 0.9985 *
# [GPU 0]   Epoch   5/30 | TrLoss: 0.0042 | VlLoss: 0.0255 | VlAcc: 0.9945 | VlF1: 0.9971
# [GPU 1]   Epoch   6/30 | TrLoss: 0.0026 | VlLoss: 0.1425 | VlAcc: 0.9524 | VlF1: 0.9747
# [GPU 0]   Epoch   6/30 | TrLoss: 0.0041 | VlLoss: 0.0219 | VlAcc: 0.9943 | VlF1: 0.9970
# [GPU 0]   Early stopping at epoch 6 (patience=5)
# [GPU 0]   Best Val F1: 0.9986 (6 epochs, 3992.8s)
# [GPU 0]   💾 Model saved to: outputs/checkpoints/CICIDS2017_Mamba_seed123.pt
# [GPU 0] [4/5] Evaluating on test set...
# [GPU 0]   Test Acc: 0.9815 | Prec: 0.8560 | Rec: 0.9530 | F1: 0.9019 | AUC: 0.9847
# [GPU 0] [5/5] Measuring efficiency...
# [GPU 0]   Latency: 15.20ms | Throughput: 2075/s | Memory: 1.48MB
# ...
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 123267 windows lazily during training
# [GPU 0] [TEST] Loading from cache: outputs/cache/cicids2017_test.npz
# [GPU 0]   Cached shape: (246633, 77), labels: 246633
# [GPU 0] [TEST] Raw shape (before windowing): (246633, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 246584 windows lazily during training
# [GPU 0]   Features: 77, Train: 863165, Val: 123267, Test: 246584
# [GPU 0] [2/5] Initializing GRU (d_model=128, n_layers=2)...
# [GPU 0]   Parameters: 373,505
# [GPU 0] [3/5] Training GRU...
# [GPU 0]   LR: 0.001000 (base=0.001 × 1.0 for GRU), grad_clip=1.0
# [GPU 0]   Using class-weighted loss (pos_weight=1.00)
# [GPU 0]   Epoch   1/30 | TrLoss: 0.0700 | VlLoss: 0.1849 | VlAcc: 0.9642 | VlF1: 0.9818 *
# [GPU 0]   Epoch   2/30 | TrLoss: 0.1349 | VlLoss: 0.1879 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 0]   Epoch   3/30 | TrLoss: 0.0437 | VlLoss: 0.1825 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 0]   Epoch   4/30 | TrLoss: 0.0376 | VlLoss: 0.1771 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 0]   Epoch   5/30 | TrLoss: 0.0400 | VlLoss: 0.1779 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 0]   Epoch   6/30 | TrLoss: 0.0265 | VlLoss: 0.0988 | VlAcc: 0.9692 | VlF1: 0.9843 *
# [GPU 0]   Epoch   7/30 | TrLoss: 0.0136 | VlLoss: 0.1061 | VlAcc: 0.9757 | VlF1: 0.9876 *
# [GPU 0]   Epoch   8/30 | TrLoss: 0.0084 | VlLoss: 0.0940 | VlAcc: 0.9780 | VlF1: 0.9887 *
# [GPU 0]   Epoch   9/30 | TrLoss: 0.0053 | VlLoss: 1.2659 | VlAcc: 0.5725 | VlF1: 0.7163
# [GPU 0]   Epoch  10/30 | TrLoss: 0.0036 | VlLoss: 1.6794 | VlAcc: 0.4435 | VlF1: 0.5949
# [GPU 0]   Epoch  11/30 | TrLoss: 0.0016 | VlLoss: 0.0411 | VlAcc: 0.9892 | VlF1: 0.9944 *
# [GPU 0]   Epoch  12/30 | TrLoss: 0.0015 | VlLoss: 0.0493 | VlAcc: 0.9846 | VlF1: 0.9920
# [GPU 0]   Epoch  13/30 | TrLoss: 0.0013 | VlLoss: 0.2201 | VlAcc: 0.8817 | VlF1: 0.9347
# [GPU 0]   Epoch  14/30 | TrLoss: 0.0009 | VlLoss: 0.1056 | VlAcc: 0.9571 | VlF1: 0.9773
# [GPU 0]   Epoch  15/30 | TrLoss: 0.0007 | VlLoss: 0.0436 | VlAcc: 0.9923 | VlF1: 0.9960 *
# [GPU 0]   Epoch  16/30 | TrLoss: 0.0005 | VlLoss: 0.0524 | VlAcc: 0.9907 | VlF1: 0.9951
# [GPU 0]   Epoch  17/30 | TrLoss: 0.0005 | VlLoss: 0.1201 | VlAcc: 0.9716 | VlF1: 0.9851
# [GPU 0]   Epoch  18/30 | TrLoss: 0.0004 | VlLoss: 0.1156 | VlAcc: 0.9741 | VlF1: 0.9864
# [GPU 0]   Epoch  19/30 | TrLoss: 0.0003 | VlLoss: 0.1107 | VlAcc: 0.9822 | VlF1: 0.9907
# [GPU 0]   Epoch  20/30 | TrLoss: 0.0003 | VlLoss: 0.0687 | VlAcc: 0.9903 | VlF1: 0.9949
# [GPU 0]   Early stopping at epoch 20 (patience=5)
# [GPU 0]   Best Val F1: 0.9960 (20 epochs, 1460.9s)
# [GPU 0]   💾 Model saved to: outputs/checkpoints/CICIDS2017_GRU_seed456.pt
# [GPU 0] [4/5] Evaluating on test set...
# [GPU 0]   Test Acc: 0.9912 | Prec: 0.9959 | Rec: 0.9050 | F1: 0.9483 | AUC: 0.9900
# [GPU 0] [5/5] Measuring efficiency...
# [GPU 0]   Latency: 0.49ms | Throughput: 43990/s | Memory: 1.42MB
# [GPU 0]   Attack types analyzed: 3
# [GPU 0]
# [GPU 0] [16/18] Running experiment...
# [GPU 0]
# [GPU 0] ======================================================================
# [GPU 0]   Dataset: CICIDS2017 | Model: Transformer | Seed: 456
# [GPU 0] ======================================================================
# [GPU 0] [Reproducibility] Setting all random seeds to 456
# [GPU 0] [Reproducibility] [OK] All seeds set and deterministic mode enabled
# [GPU 0] [1/5] Loading CICIDS2017 dataset...
# [GPU 0] [TRAIN] Loading from cache: outputs/cache/cicids2017_train.npz
# [GPU 0]   Cached shape: (863214, 77), labels: 863214
# [GPU 0] [TRAIN] Raw shape (before windowing): (863214, 77)
# [GPU 0] Fitting StandardScaler on Train split...
# [GPU 0] Saved scaler to outputs/scaler_cicids.pkl
# [GPU 0] [OK] Will generate 863165 windows lazily during training
# [GPU 0] [VAL] Loading from cache: outputs/cache/cicids2017_val.npz
# [GPU 0]   Cached shape: (123316, 77), labels: 123316
# [GPU 0] [VAL] Raw shape (before windowing): (123316, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 123267 windows lazily during training
# [GPU 0] [TEST] Loading from cache: outputs/cache/cicids2017_test.npz
# [GPU 0]   Cached shape: (246633, 77), labels: 246633
# [GPU 0] [TEST] Raw shape (before windowing): (246633, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 246584 windows lazily during training
# [GPU 0]   Features: 77, Train: 863165, Val: 123267, Test: 246584
# [GPU 0] [2/5] Initializing Transformer (d_model=128, n_layers=2)...
# [GPU 0]   Parameters: 406,913
# [GPU 0] [3/5] Training Transformer...
# [GPU 0]   LR: 0.000300 (base=0.001 × 0.3 for Transformer), grad_clip=0.5
# [GPU 0]   Using class-weighted loss (pos_weight=1.00)
# [GPU 0]   Epoch   1/30 | TrLoss: 0.0739 | VlLoss: 0.0892 | VlAcc: 0.9748 | VlF1: 0.9871 *
# [GPU 0]   Epoch   2/30 | TrLoss: 0.0263 | VlLoss: 0.1041 | VlAcc: 0.9727 | VlF1: 0.9860
# [GPU 0]   Epoch   3/30 | TrLoss: 0.0428 | VlLoss: 0.1440 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 0]   Epoch   4/30 | TrLoss: 0.0317 | VlLoss: 0.5090 | VlAcc: 0.9009 | VlF1: 0.9467
# [GPU 0]   Epoch   5/30 | TrLoss: 0.0245 | VlLoss: 0.5694 | VlAcc: 0.8881 | VlF1: 0.9394
# [GPU 0]   Epoch   6/30 | TrLoss: 0.0098 | VlLoss: 3.9530 | VlAcc: 0.3323 | VlF1: 0.4708
# [GPU 0]   Early stopping at epoch 6 (patience=5)
# [GPU 0]   Best Val F1: 0.9871 (6 epochs, 613.4s)
# [GPU 0]   💾 Model saved to: outputs/checkpoints/CICIDS2017_Transformer_seed456.pt
# [GPU 0] [4/5] Evaluating on test set...
# [GPU 0]   Test Acc: 0.1441 | Prec: 0.0945 | Rec: 0.9991 | F1: 0.1726 | AUC: 0.9583
# [GPU 0] [5/5] Measuring efficiency...
# [GPU 0]   Latency: 1.26ms | Throughput: 27149/s | Memory: 1.55MB
# [GPU 0]   Attack types analyzed: 3
# [GPU 0]
# [GPU 0] [17/18] Running experiment...
# [GPU 0]
# [GPU 0] ======================================================================
# [GPU 0]   Dataset: CICIDS2017 | Model: CNN-LSTM | Seed: 456
# [GPU 0] ======================================================================
# [GPU 0] [Reproducibility] Setting all random seeds to 456
# [GPU 0] [Reproducibility] [OK] All seeds set and deterministic mode enabled
# [GPU 0] [1/5] Loading CICIDS2017 dataset...
# [GPU 0] [TRAIN] Loading from cache: outputs/cache/cicids2017_train.npz
# [GPU 0]   Cached shape: (863214, 77), labels: 863214
# [GPU 0] [TRAIN] Raw shape (before windowing): (863214, 77)
# [GPU 0] Fitting StandardScaler on Train split...
# [GPU 0] Saved scaler to outputs/scaler_cicids.pkl
# [GPU 0] [OK] Will generate 863165 windows lazily during training
# [GPU 0] [VAL] Loading from cache: outputs/cache/cicids2017_val.npz
# [GPU 0]   Cached shape: (123316, 77), labels: 123316
# [GPU 0] [VAL] Raw shape (before windowing): (123316, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 123267 windows lazily during training
# [GPU 0] [TEST] Loading from cache: outputs/cache/cicids2017_test.npz
# [GPU 0]   Cached shape: (246633, 77), labels: 246633
# [GPU 0] [TEST] Raw shape (before windowing): (246633, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 246584 windows lazily during training
# [GPU 0]   Features: 77, Train: 863165, Val: 123267, Test: 246584
# [GPU 0] [2/5] Initializing CNN-LSTM (d_model=128, n_layers=2)...
# [GPU 0]   Parameters: 409,601
# [GPU 0] [3/5] Training CNN-LSTM...
# [GPU 0]   LR: 0.000500 (base=0.001 × 0.5 for CNN-LSTM), grad_clip=0.5
# [GPU 0]   Using class-weighted loss (pos_weight=1.00)
# [GPU 0]   Epoch   1/30 | TrLoss: 0.0909 | VlLoss: 0.1791 | VlAcc: 0.9642 | VlF1: 0.9818 *
# [GPU 0]   Epoch   2/30 | TrLoss: 0.0477 | VlLoss: 0.1471 | VlAcc: 0.9816 | VlF1: 0.9905 *
# [GPU 0]   Epoch   3/30 | TrLoss: 0.0401 | VlLoss: 0.7822 | VlAcc: 0.3608 | VlF1: 0.5133
# [GPU 0]   Epoch   4/30 | TrLoss: 0.0449 | VlLoss: 0.1466 | VlAcc: 0.9728 | VlF1: 0.9859
# [GPU 0]   Epoch   5/30 | TrLoss: 0.0570 | VlLoss: 0.1749 | VlAcc: 0.9642 | VlF1: 0.9818
# [GPU 0]   Epoch   6/30 | TrLoss: 0.0284 | VlLoss: 0.8538 | VlAcc: 0.3898 | VlF1: 0.5396
# [GPU 0]   Epoch   7/30 | TrLoss: 0.0035 | VlLoss: 0.1066 | VlAcc: 0.9913 | VlF1: 0.9955 *
# [GPU 0]   Epoch   8/30 | TrLoss: 0.0026 | VlLoss: 0.1518 | VlAcc: 0.9919 | VlF1: 0.9958 *
# [GPU 0]   Epoch   9/30 | TrLoss: 0.0023 | VlLoss: 0.0365 | VlAcc: 0.9938 | VlF1: 0.9968 *
# [GPU 0]   Epoch  10/30 | TrLoss: 0.0018 | VlLoss: 0.0318 | VlAcc: 0.9945 | VlF1: 0.9971 *
# [GPU 0]   Epoch  11/30 | TrLoss: 0.0016 | VlLoss: 0.0284 | VlAcc: 0.9954 | VlF1: 0.9976 *
# [GPU 0]   Epoch  12/30 | TrLoss: 0.0015 | VlLoss: 0.0246 | VlAcc: 0.9961 | VlF1: 0.9980 *
# [GPU 0]   Epoch  13/30 | TrLoss: 0.0014 | VlLoss: 0.0250 | VlAcc: 0.9960 | VlF1: 0.9979
# [GPU 0]   Epoch  14/30 | TrLoss: 0.0010 | VlLoss: 0.0269 | VlAcc: 0.9964 | VlF1: 0.9981 *
# [GPU 0]   Epoch  15/30 | TrLoss: 0.0009 | VlLoss: 0.0296 | VlAcc: 0.9960 | VlF1: 0.9979
# [GPU 0]   Epoch  16/30 | TrLoss: 0.0008 | VlLoss: 0.0245 | VlAcc: 0.9959 | VlF1: 0.9979
# [GPU 0]   Epoch  17/30 | TrLoss: 0.0009 | VlLoss: 0.0262 | VlAcc: 0.9942 | VlF1: 0.9970
# [GPU 0]   Epoch  18/30 | TrLoss: 0.0005 | VlLoss: 0.0260 | VlAcc: 0.9963 | VlF1: 0.9981
# [GPU 0]   Epoch  19/30 | TrLoss: 0.0004 | VlLoss: 0.0291 | VlAcc: 0.9964 | VlF1: 0.9981
# [GPU 0]   Early stopping at epoch 19 (patience=5)
# [GPU 0]   Best Val F1: 0.9981 (19 epochs, 1646.5s)
# [GPU 0]   💾 Model saved to: outputs/checkpoints/CICIDS2017_CNN-LSTM_seed456.pt
# [GPU 0] [4/5] Evaluating on test set...
# [GPU 0]   Test Acc: 0.9643 | Prec: 0.7350 | Rec: 0.9386 | F1: 0.8244 | AUC: 0.9718
# [GPU 0] [5/5] Measuring efficiency...
# [GPU 0]   Latency: 0.88ms | Throughput: 34323/s | Memory: 1.56MB
# [GPU 0]   Attack types analyzed: 3
# [GPU 0]
# [GPU 0] [18/18] Running experiment...
# [GPU 0]
# [GPU 0] ======================================================================
# [GPU 0]   Dataset: CICIDS2017 | Model: TCN | Seed: 456
# [GPU 0] ======================================================================
# [GPU 0] [Reproducibility] Setting all random seeds to 456
# [GPU 0] [Reproducibility] [OK] All seeds set and deterministic mode enabled
# [GPU 0] [1/5] Loading CICIDS2017 dataset...
# [GPU 0] [TRAIN] Loading from cache: outputs/cache/cicids2017_train.npz
# [GPU 0]   Cached shape: (863214, 77), labels: 863214
# [GPU 0] [TRAIN] Raw shape (before windowing): (863214, 77)
# [GPU 0] Fitting StandardScaler on Train split...
# [GPU 0] Saved scaler to outputs/scaler_cicids.pkl
# [GPU 0] [OK] Will generate 863165 windows lazily during training
# [GPU 0] [VAL] Loading from cache: outputs/cache/cicids2017_val.npz
# [GPU 0]   Cached shape: (123316, 77), labels: 123316
# [GPU 0] [VAL] Raw shape (before windowing): (123316, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 123267 windows lazily during training
# [GPU 0] [TEST] Loading from cache: outputs/cache/cicids2017_test.npz
# [GPU 0]   Cached shape: (246633, 77), labels: 246633
# [GPU 0] [TEST] Raw shape (before windowing): (246633, 77)
# [GPU 0] Loading scaler from outputs/scaler_cicids.pkl...
# [GPU 0] [OK] Will generate 246584 windows lazily during training
# [GPU 0]   Features: 77, Train: 863165, Val: 123267, Test: 246584
# [GPU 0] [2/5] Initializing TCN (d_model=128, n_layers=2)...
# [GPU 0]   Parameters: 423,169
# [GPU 0] [3/5] Training TCN...
# [GPU 0]   LR: 0.000500 (base=0.001 × 0.5 for TCN), grad_clip=1.0
# [GPU 0]   Using class-weighted loss (pos_weight=1.00)
# [GPU 0]   Epoch   1/30 | TrLoss: 0.0410 | VlLoss: 0.0465 | VlAcc: 0.9825 | VlF1: 0.9910 *
# [GPU 0]   Epoch   2/30 | TrLoss: 0.0105 | VlLoss: 0.0885 | VlAcc: 0.9731 | VlF1: 0.9862
# [GPU 0]   Epoch   3/30 | TrLoss: 0.0174 | VlLoss: 0.0721 | VlAcc: 0.9757 | VlF1: 0.9875
# [GPU 0]   Epoch   4/30 | TrLoss: 0.0076 | VlLoss: 0.1476 | VlAcc: 0.9806 | VlF1: 0.9898
# [GPU 0]   Epoch   5/30 | TrLoss: 0.0035 | VlLoss: 0.0631 | VlAcc: 0.9787 | VlF1: 0.9891
# [GPU 0]   Epoch   6/30 | TrLoss: 0.0023 | VlLoss: 0.0605 | VlAcc: 0.9800 | VlF1: 0.9897
# [GPU 0]   Early stopping at epoch 6 (patience=5)
# [GPU 0]   Best Val F1: 0.9910 (6 epochs, 651.9s)
# [GPU 0]   💾 Model saved to: outputs/checkpoints/CICIDS2017_TCN_seed456.pt
# [GPU 0] [4/5] Evaluating on test set...
# [GPU 0]   Test Acc: 0.7790 | Prec: 0.2834 | Rec: 0.9640 | F1: 0.4380 | AUC: 0.9749
# [GPU 0] [5/5] Measuring efficiency...
# [GPU 0]   Latency: 1.63ms | Throughput: 17465/s | Memory: 1.61MB
# [GPU 0]   Attack types analyzed: 3
# [GPU 0]
# [GPU 0]
# [GPU 0] ======================================================================
# [GPU 0] BENCHMARK SUMMARY
# [GPU 0] ======================================================================
# [GPU 0]
# [GPU 0] 📊 CICIDS2017
# [GPU 0] Model                Acc     Prec      Rec       F1      AUC  Lat(ms)     Params
# [GPU 0] -----------------------------------------------------------------------------------
# [GPU 0] Mamba           0.9815  0.8726  0.9414  0.9029  0.9830   15.53     387,073
# [GPU 0] LSTM            0.6850  0.6271  0.9552  0.6609  0.8231    0.76     423,169
# [GPU 0] GRU             0.3900  0.3915  0.9683  0.4255  0.7518    0.52     373,505
# [GPU 0] Transformer     0.1077  0.0910  0.9994  0.1669  0.6991    1.33     406,913
# [GPU 0] CNN-LSTM        0.9645  0.7360  0.9460  0.8271  0.9736    0.96     409,601
# [GPU 0] TCN             0.7223  0.2902  0.9648  0.4325  0.9710    1.73     423,169
# [GPU 0]
# [GPU 0] ✅ Results saved to: outputs/benchmark_results/
# [GPU 0]    Run 'python generate_tables.py' to generate publication tables.
#
# ✅ GPU 0 finished (exit=0)
# ✅ GPU 1 finished (exit=0)
# ⏱️  Total time: 8h 50m
#
# ============================================================
# 🏁 All done! Total time: 8h 50m
# ============================================================
#
# 📊 Merging results from both GPUs...
#    ✅ Merged 30 experiments from 30 files into all_results.json
# 📋 Generating publication tables...
# Loaded 30 experiment results.
#
# ## Table 1: Classification Results — CICIDS2017
# *Mean ± std across 5 seeds*
#
# | Model | Accuracy | Precision | Recall | F1-Score | AUC-ROC |
# |-------|----------|-----------|--------|----------|---------|
# | Mamba | 98.11 ± 0.88 | 87.64 ± 8.98 | 93.27 ± 1.87 | 90.06 ± 4.18 | 98.21 ± 0.20 |
# | CNN-LSTM | 96.84 ± 0.68 | 76.49 ± 4.83 | 94.07 ± 0.89 | 84.26 ± 2.69 | 97.42 ± 0.20 |
# | GRU | 45.02 ± 44.18 | 45.07 ± 44.25 | 96.41 ± 4.41 | 47.83 ± 38.48 | 79.40 ± 17.95 |
# | LSTM | 44.68 ± 43.77 | 41.20 ± 40.02 | 97.31 ± 3.75 | 46.22 ± 36.60 | 71.89 ± 23.15 |
# | TCN | 75.08 ± 14.66 | 31.15 ± 12.36 | 96.26 ± 0.87 | 45.63 ± 14.10 | 97.07 ± 0.25 |
# | Transformer | 10.73 ± 2.27 | 9.09 ± 0.20 | 99.78 ± 0.35 | 16.66 ± 0.34 | 78.26 ± 20.66 |
#
# ## Table 2: Efficiency Comparison — CICIDS2017
#
# | Model | Params | Memory (MB) | Latency (ms) | Throughput (/s) | Train Time (s) |
# |-------|--------|-------------|--------------|-----------------|----------------|
# | GRU | 373,505 | 1.42 | 0.54 ± 0.05 | 42406 | 776.7 |
# | LSTM | 423,169 | 1.61 | 0.77 ± 0.03 | 29679 | 861.9 |
# | CNN-LSTM | 409,601 | 1.56 | 0.93 ± 0.06 | 32864 | 1535.7 |
# | Transformer | 406,913 | 1.55 | 1.30 ± 0.09 | 25627 | 692.5 |
# | TCN | 423,169 | 1.61 | 1.81 ± 0.23 | 16503 | 946.7 |
# | Mamba | 387,073 | 1.48 | 16.41 ± 2.59 | 1963 | 5675.6 |
#
# ## Table 3: Per-Attack-Type F1 (%) — CICIDS2017
#
# | Model | BENIGN | Bot | PortScan |
# |-------|--------|-----|----------|
# | CNN-LSTM | 98.5 | 55.0 | 99.8 |
# | GRU | 40.0 | 64.6 | 99.9 |
# | LSTM | 39.8 | 74.9 | 99.9 |
# | Mamba | 99.3 | 46.9 | 99.6 |
# | TCN | 83.3 | 75.6 | 99.8 |
# | Transformer | 3.8 | 99.4 | 99.9 |
#
# ## Table 4: Statistical Significance (Wilcoxon) — CICIDS2017
#
# | Model A | Model B | p-value | Significant (p<0.05) |
# |---------|---------|---------|----------------------|
# | CNN-LSTM | GRU | 0.3125 | ✗ |
# | CNN-LSTM | LSTM | 0.3125 | ✗ |
# | CNN-LSTM | Mamba | 0.1875 | ✗ |
# | CNN-LSTM | TCN | 0.0625 | ✗ |
# | CNN-LSTM | Transformer | 0.0625 | ✗ |
# | GRU | LSTM | 0.8125 | ✗ |
# | GRU | Mamba | 0.3125 | ✗ |
# | GRU | TCN | 0.8125 | ✗ |
# | GRU | Transformer | 0.1875 | ✗ |
# | LSTM | Mamba | 0.1250 | ✗ |
# | LSTM | TCN | 1.0000 | ✗ |
# | LSTM | Transformer | 0.4375 | ✗ |
# | Mamba | TCN | 0.0625 | ✗ |
# | Mamba | Transformer | 0.0625 | ✗ |
# | TCN | Transformer | 0.0625 | ✗ |
#
#
# ✅ Tables saved to outputs/benchmark_results/benchmark_tables.md
#
# ✅ Results saved to outputs/benchmark_results/
